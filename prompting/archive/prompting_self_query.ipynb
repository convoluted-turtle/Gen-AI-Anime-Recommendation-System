# %%
import sys 
sys.path.append('/Users/justinvhuang/Desktop/CSE-6242-Group-Project')

# %%
import guidance

from guidance import gen, models
from tqdm import tqdm

from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores import Chroma
from tqdm import tqdm
from utils.textpreprocessing import TextPreprocessor

# %%
textprepo = TextPreprocessor()

# %%
encode_kwargs = {"normalize_embeddings": True}
embedding_function = HuggingFaceEmbeddings(
    model_name='sentence-transformers/all-MiniLM-L6-v2',
    model_kwargs={"device": "cpu"},
    encode_kwargs=encode_kwargs,
)

# %%
db_chroma = Chroma(persist_directory="./Users/justinvhuang/Desktop/CSE-6242-Group-Project/vector_database_creation/chroma_db", embedding_function=embedding_function)
db_faiss = FAISS.load_local("/Users/justinvhuang/Desktop/CSE-6242-Group-Project/vector_database_creation/faiss_anime_index_v3", embeddings = embedding_function)

# %%
query = "i like space adventures"
query_token = textprepo.preprocess_text(query)

def filter_tokens(metadata):
        metadata_tokens = metadata.get("tokens", [])
        return any(token in metadata_tokens for token in query_token) or metadata["score"] > 5.0


results = db_faiss.similarity_search(query, filter=filter_tokens, k=50)
results
# Out:
# [Document(page_content='space ghost is a fictional superhero created by hanna-barbera productions in the 1960s for tv network cbs. he was designed by alex toth.in his original incarnation, he was a superhero who, with his teen sidekicks, jan and jace, and blip the monkey, fought supervillains in outer space. in the 1990s, space ghost was brought back as a host for his own fictional late-night talk show, space ghost coast to coast, on cartoon network, adult swim and gametap. in the 2000s, he was revamped as a serious superhero once again in a mini-series by dc comics.\n\n\n== television series ==\n\n\n', metadata={'anime_id': 40159, 'cast': 'UNKNOWN', 'episodes': 1, 'genre': 'Avant Garde', 'source': 'Original', 'Duration': '1 min', 'name': 'The Ghost of Cartoon', 'tokens': "['space', 'ghost', 'fictional', 'superhero', 'create', 'hanna', 'barbera', 'production', '1960', 'tv', 'network', 'cbs', 'design', 'alex', 'toth.in', 'original', 'incarnation', 'superhero', 'teen', 'sidekick', 'jan', 'jace', 'blip', 'monkey', 'fight', 'supervillain', 'outer', 'space', '1990s', 'space', 'ghost', 'bring', 'host', 'fictional', 'late', 'night', 'talk', 'space', 'ghost', 'coast', 'coast', 'cartoon', 'network', 'adult', 'swim', 'gametap', '2000s', 'revamp', 'superhero', 'mini', 'series', 'dc', 'comic_strip', '\\n\\n\\n', '=', '=', 'television', 'series', '=', '=', '\\n\\n\\n ', 'avant', 'garde', 'original', 'unknown', 'unknown', 'unknown', 'space', 'shower', 'tv', 'station', 'd', 'direct', 'ryuu', 'ookubo', 'music', 'mndsgn', 'unknown', 'ghost', 'cartoon']", 'score': 5.01, 'producer': 'UNKNOWN', 'studio': 'UNKNOWN', 'licensors': 'UNKNOWN', 'cf_recs': 'Hakodate Musical, Union Union, Break Go!Ga!, Kyoto Gakuen Daigaku, Hirooka Asako, Race Eizou-hen, Nameless Flipbook, Curly, Tanoshii Saki Uta Animation, MaxValu Kyushu', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'G - All Ages', 'air_date': 'Sep 24, 2015'}),
#  Document(page_content="astra lost in space (japanese: 彼方のアストラ, hepburn: kanata no asutora) is a japanese manga series written and illustrated by kenta shinohara. it was serialized online from may 2016 to december 2017 via shueisha's shōnen jump+ website/app. it was collected in five tankōbon volume. viz media published the series in english. an anime television series adaptation by lerche aired from july to september 2019.\n\n\n\nin 2063, space travel has become possible and commercially viable; a group of students from caird high school departs to the nearby planet of mcpa for their planetary camp. soon after the group arrives on the planet, the nine children encounter a mysterious and unforeseen intelligent sphere of light; it attacks them, transporting them into the distant depths of space. floating in orbit around an unknown planet, they discover an old abandoned spacecraft nearby. finding it in working order, they resolve to use the ship to return home. to do so, they must cross the 5,012-light-year gulf of space separating them from home by visiting alien planets, the names of which are all anagrams, harboring life to replenish and manage their limited resources.\nthe long and dangerous journey home aboard their vessel, which they name astra, brings with it new character revelations, strengthening the bonds they share, and the eventual realization that the stakes of their journey are far higher than any of them could ever have realized.\n\n\n", metadata={'anime_id': 39198, 'cast': 'Sakyiwaa Baah, Megan Shipman, Dani Chambers, Christopher Dontrell Piper, Dawn M. Bennett, Shawn Gann, Aaron Roberts, Ciarán Strange, Jason Liebrecht, Jessie James Grelle', 'episodes': 12, 'genre': 'Adventure, Award Winning, Mystery, Sci-Fi', 'source': 'Manga', 'Duration': '28 min per ep', 'name': 'Kanata no Astra', 'tokens': "['astra', 'lose', 'space', 'japanese', 'Bi', 'Fang', 'noasutora', 'hepburn', 'kanata', 'asutora', 'japanese', 'manga', 'series', 'write', 'illustrate', 'kenta', 'shinohara', 'serialize', 'online', '2016', 'december', '2017', 'shueisha', 'shonen', 'jump+', 'website', 'app', 'collect', 'tankobon', 'volume', 'viz', 'medium', 'publish', 'series', 'english', 'anime', 'television', 'series', 'adaptation', 'lerche', 'air', 'july', 'september', '2019', '\\n\\n\\n\\n', '2063', 'space', 'travel', 'possible', 'commercially', 'viable', 'group', 'student', 'caird', 'high', 'school', 'depart', 'nearby', 'planet', 'mcpa', 'planetary', 'camp', 'soon', 'group', 'arrive', 'planet', 'child', 'encounter', 'mysterious', 'unforeseen', 'intelligent', 'sphere', 'light', 'attack', 'transport', 'distant', 'depth', 'space', 'float', 'orbit', 'unknown', 'planet', 'discover', 'old', 'abandon', 'spacecraft', 'nearby', 'find', 'work', 'order', 'resolve', 'use', 'ship', 'return', 'home', 'cross', '5,012', 'light', 'year', 'gulf', 'space', 'separate', 'home', 'visit', 'alien', 'planet', 'anagram', 'harbor', 'life', 'replenish', 'manage', 'limited', 'resource', '\\n', 'long', 'dangerous', 'journey', 'home', 'aboard', 'vessel', 'astra', 'bring', 'new', 'character', 'revelation', 'strengthen', 'bond', 'share', 'eventual', 'realization', 'stake', 'journey', 'far', 'high', 'realize', '\\n\\n\\n ', 'adventure', 'award', 'win', 'mystery', 'sci', 'fi', 'manga', 'interstellar', 'travel', 'base', 'manga', 'action', 'scene', 'rescue', 'friendship', 'x', 'docomo', 'anime', 'store', 'shueisha', 'kadokawa', 'medium', 'house', 'kadokawa', 'sakyiwaa', 'baah', 'megan', 'shipman', 'dani', 'chamber', 'christopher', 'dontrell', 'piper', 'dawn', 'm.', 'bennett', 'shawn', 'gann', 'aaron', 'roberts', 'ciaran', 'strange', 'jason', 'liebrecht', 'jessie', 'james', 'grelle', 'year', '2063', 'space', 'travel', 'feasible', 'commercially', 'available', 'cheerful', 'arie', 'spring', 'arrive', 'spaceport', 'attend', 'camp', 'distant', 'planet', 'mcpa', 'purse', 'suddenly', 'snatch', 'reckless', 'thief', 'luckily', 'athletic', 'kanata', 'hoshijima', 'able', 'retrieve', 'arie', 'soon',  ...
#  Document(page_content='welcome to the space show (japanese: 宇宙ショーへようこそ, hepburn: uchū shō e yōkoso) is a 2010 japanese animated science fiction film produced by a-1 pictures and distributed by aniplex. it was directed by koji masunari from a script by hideyuki kurata, and stars the voices of tomoyo kurosawa, honoka ikezuki, shōtarō uzawa, tamaki matsumoto, takuto yoshinaga, and keiji fujiwara. in the film, five children rescue an alien dog, and are rewarded a trip to the moon in response. after events cause the group to become stranded in space, they must find a way to return to earth before the kids\' parents arrive.\n\n\n\nwelcome to the space show, whose story "surpasses star wars in its scale" according to its producers, tells of the four adventures of five schoolmates and an alien dog in space during summer vacation.the plot revolves around five elementary school kids on their "school trip". in the process of looking for their missing class pet (a rabbit named pyon-kichi), the children rescue a dog they find injured in a corn field. the dog turns out to be an alien called pochi rickman, and he invites them to visit the moon as a reward for helping him. however, through a series of strange events, they become stranded and must make their way across the galaxy to get to pochi\'s homeworld, wan, so that they may return to earth. along the way they are pursued by the aliens responsible for pochi being injured in the first place. the aliens work for the host (called neppo) of the universe\'s most popular entertainment, "the space show", which appears to be a variety act broadcast from a mysterious moving spaceship.\nneppo is bent on using the power of the ship, called the pet star, to become a god. however, the ship requires a particular power source to run; namely a substance called zughan, which turns out to be a close relative of the wasabi root. as natsuki is carrying some of the root with them in her bag, neppo has thus targeted the group. when his thugs fail to retrieve the bag, neppo goes himself; arriving just as the children and pochi reach wan. the pet star\'s tractor beams steal the bag, but they also take amane as well.\nthis leads to a show down at an interstellar festival, where with the help of friends they\'ve made along the way, the children manage not only to defeat neppo and rescue amane but also save the entire universe. the children are then able to return home (along with pyon-kichi, who had been kidnapped by neppo\'s henchmen as well) and arrive at the school just before their parents show up to retrieve them.\n\n\n', metadata={'anime_id': 8115, 'cast': 'Takuto Yoshinaga, Atsuhiro Iwakami, Tomoyo Kurosawa, Hideyuki Kurata, Tomonori Ochikoshi, Masaaki Yuasa, Honoka Ikezuki, Tamaki Matsumoto, Stephanie Sheh, Kôji Masunari', 'episodes': 1, 'genre': 'Adventure, Fantasy', 'source': 'Original', 'Duration': '2 hr 16 min', 'name': 'Uchuu Show e Youkoso', 'tokens': "['welcome', 'space', 'japanese', 'Yu', 'Zhou', 'shiyo', 'heyoukoso', 'hepburn', 'uchu', 'sho', 'e', 'yokoso', '2010', 'japanese', 'animate', 'science', 'fiction', 'film', 'produce', 'a-1', 'picture', 'distribute', 'aniplex', 'direct', 'koji', 'masunari', 'script', 'hideyuki', 'kurata', 'star', 'voice', 'tomoyo', 'kurosawa', 'honoka', 'ikezuki', 'shotaro', 'uzawa', 'tamaki', 'matsumoto', 'takuto', 'yoshinaga', 'keiji', 'fujiwara', 'film', 'child', 'rescue', 'alien', 'dog', 'reward', 'trip', 'moon', 'response', 'event', 'cause', 'group', 'strand', 'space', 'find', 'way', 'return', 'earth', 'kid', 'parent', 'arrive', '\\n\\n\\n\\n', 'welcome', 'space', 'story', 'surpass', 'star', 'war', 'scale', 'accord', 'producer', 'tell', 'adventure', 'schoolmate', 'alien', 'dog', 'space', 'summer', 'vacation.the', 'plot', 'revolve', 'elementary', 'school', 'kid', 'school', 'trip', 'process', 'look', 'miss', 'class', 'pet', 'rabbit', 'pyon', 'kichi', 'child', 'rescue', 'dog', 'find', 'injure', 'corn', 'field', 'dog', 'turn', 'alien', 'pochi', 'rickman', 'invite', 'vi ...
#  Document(page_content='science adventure is a multimedia series consisting of interconnected science fiction stories, created mainly by mages, nitroplus (for the first three games), and chiyomaru studio. the main entries mostly take the form of visual novel video games, but side entries span across several different mediums.\nthe series currently consists of six mainline entries: the first part of the series, chaos;head, was a visual novel released in 2008, and it is followed by the visual novels steins;gate, robotics;notes, chaos;child, occultic;nine, anonymous;code, as well as the upcoming steins;???. the series also includes several spin-off games based on chaos;head, steins;gate, robotics;notes, and chaos;child, as well as many spinoffs in other mediums including anime, manga, light novels, audio dramas, and stage plays.\nthe main entries and their spin-offs all take place in the same fictional universe, with focuses on several different science fiction themes. chaos;head and chaos;child focus on perception, steins;gate focuses on time travel and science, and robotics;notes focuses on robotics and augmented reality. the player can affect the course of the story by making certain choices: in chaos;head and chaos;child this is done by choosing what kind of delusions the player characters experience. the choices in the steins;gate games and robotics;notes are made via messages set by the player via an in-game cell phone and tablet computer, respectively.\nthe series is planned by chiyomaru shikura, the ceo of mages, composed by takeshi abo and zizz studio, written by naotaka hayashi along with other writers, and features character designs by artists including mutsumi sasaki, huke, and tomonori fukuda. the developers aimed to make the series set within reality, as shikura felt it made it more relatable and believable. the series has been commercially and critically successful both in japan and internationally, selling more than expected for the genre and helping establishing mages (previously 5pb.) as a game developer.\nthe series is published by mages and nitroplus in japan, and by jast usa, pqube, mages, and spike chunsoft internationally. the visual novels steins;gate, steins;gate 0, chaos;child, steins;gate elite, steins;gate: linear bounded phenogram, 8-bit adv steins;gate, steins;gate: my darling\'s embrace, robotics;notes elite, robotics;notes dash, and chaos;head noah have been released officially in english. anonymous;code has also been announced for an english release.\n\n\n== main entries ==\nthe science adventure series consists of six core entries, along with a seventh in development. the game adaptation of the occultic;nine novel series, and anonymous;code were referred to internally as part of the science visual novel series, which was originally announced to be separate from science adventure, but has since been incorporated into the series. occultic;nine was planned to be updated with new story content tying it more closely with science adventure. some of the games have received updated editions with added content, and there are compilations collecting several games, such as chaos;head dual (collecting both chaos;head games) and steins;gate: divergencies assort (collecting steins;gate 0, darling of loving vows, and linear bounded phenogram).the main entries are as follows:\n\nchaos;head is the first entry in the series. it was originally released for microsoft windows in 2008; the complete version, chaos;head noah, was released for the xbox 360 in 2009, and later ported to playstation portable, ios, android, playstation 3, playstation vita, nintendo switch, and microsoft windows. the game follows takumi, a shut-in who starts experiencing delusions after witnessing a murder, and becomes suspected by the police for the series of "new generation madness" killings.\nsteins;gate is the second entry in the series. it was originally released for the xbox 360 in 2009, and later ported to microsoft windows, playstatio ...
#  Document(page_content="space brothers (japanese: 宇宙兄弟, hepburn: uchū kyōdai) is a japanese manga series written and illustrated by chūya koyama. it has been serialized in kodansha's seinen manga magazine morning since december 2007. a 99-episode anime television series adaptation by a-1 pictures aired from april 2012 to march 2014. the manga was also adapted into a live-action film that premiered in may 2012. an anime film, space brothers #0, premiered in august 2014.\nin 2011, space brothers won the general category at both, the 56th shogakukan manga award and the 35th kodansha manga award. by march 2022, the manga had 28 million copies in circulation, making it one of the best-selling manga series.\n\n\n== story ==\n\nin the summer of 2006, mutta nanba and his younger brother, hibito, witness what they believe to be a ufo, which flies off towards the moon. hibito decides he will go onto the moon whilst mutta decides he will aim for mars. nineteen years later, in the year 2025, hibito has become a fully fledged jaxa astronaut assigned to go on a mission towards the moon. mutta, on the other hand, has not been so successful in achieving his dreams. as mutta eventually recalls his past ambitions, he receives a letter stating he has been accepted to join a jaxa training program for new astronauts. the series follows mutta as he seeks to become an astronaut and achieve his longtime dream just like his brother did.\n\n\n", metadata={'anime_id': 12431, 'cast': 'Shô Ryûzanji, Miyuki Sawashiro, Yûko Sanpei, Hiroaki Hirata, Masayuki Katô, Masako Ikeda, Kenichiro Ohashi', 'episodes': 99, 'genre': 'Comedy, Sci-Fi', 'source': 'Manga', 'Duration': '24 min per ep', 'name': 'Uchuu Kyoudai', 'tokens': "['space', 'brother', 'japanese', 'Yu', 'Zhou', 'Xiong', 'Di', 'hepburn', 'uchu', 'kyodai', 'japanese', 'manga', 'series', 'write', 'illustrate', 'chuya', 'koyama', 'serialize', 'kodansha', 'seinen', 'manga', 'magazine', 'morning', 'december', '2007', '99', 'episode', 'anime', 'television', 'series', 'adaptation', 'a-1', 'picture', 'air', 'april', '2012', 'march', '2014', 'manga', 'adapt', 'live', 'action', 'film', 'premiere', '2012', 'anime', 'film', 'space', 'brother', '0', 'premiere', 'august', '2014', '\\n', '2011', 'space', 'brother', 'win', 'general', 'category', '56th', 'shogakukan', 'manga', 'award', '35th', 'kodansha', 'manga', 'award', 'march', '2022', 'manga', '28', 'million', 'copy', 'circulation', 'sell', 'manga', 'series', '\\n\\n\\n', '=', '=', 'story', '=', '=', '\\n\\n', 'summer', '2006', 'mutta', 'nanba', 'young', 'brother', 'hibito', 'witness', 'believe', 'ufo', 'fly', 'moon', 'hibito', 'decide', 'moon', 'whilst', 'mutta', 'decide', 'aim', 'mar', 'nineteen', 'year', 'later', 'year', '2025', 'hibito', 'fully', 'fledged', 'jaxa', 'astronaut', 'assign', 'mission', 'moon', 'mutta', 'hand', 'successful', 'achieve', 'dream', 'mutta', 'eventually', 'recall', 'past', 'ambition', 'receive', 'letter', 'state', 'accept', 'join', 'jaxa', 'training', 'program', 'new', 'astronaut', 'series', 'follow', 'mutta', 'seek', 'astronaut', 'achieve', 'longtime', 'dream', 'like', 'brother', '\\n\\n\\n ', 'comedy', 'sci', 'fi', 'manga', 'nasa', 'base', 'manga', 'science', 'fiction', 'comedy', 'astronaut', 'brother', 'yomiuri', 'telecasting', 'trinity', 'sound', 'sho', 'ryuzanji', 'miyuki', 'sawashiro', 'yuko', 'sanpei', 'hiroaki', 'hirata', 'masayuki', 'kato', 'masako', 'ikeda', 'kenichiro', 'ohashi', 'fateful', 'summer', 'night', '2006', 'mutta', 'nanba', 'young', 'brother', 'hibito', 'witness', 'believe', 'ufo', 'fly', 'moon', 'impressing', 'unusual', 'phenomenon', 'lead', 'sibling', 'vow', 'astronaut', 'hibito', 'aim', 'moon', 'mutta', 'convince', 'eld', 'brother', 'step', 'ahead', 'mar', 'a-1', 'picture', 'uchuu', 'kyoudai']", 'score': 8.5, 'producer': 'Yomiuri Telecasting, Trinity Sound', 'studio': 'A-1 Pictures', 'licensors': 'Sentai Filmworks', 'cf_recs': 'Sakamichi no Apollon, Tsuritama, Usagi Drop, Yowamushi Pedal, Natsuyuki Rendezvous, Gin ...
#  Document(page_content="space travelers: the animation (スペース・トラベラーズ the animation, supesutoraberaz the animation) is a 2000 science fiction and action japanese straight to video full-length animated film produced by fuji television network and robot films. the anime ties back to 2000's live action comedy film space travelers directed by katsuyuki motohiro, also produced by fuji television network and robot films.\n\n\n\nin the new cosmic century 038, humanity is suddenly attacked by a mysterious alien civilization known as the orbital ring system. soon, the entire earth civilization sphere has been cut off from the space colonies, and is under the control of the ors. only hayabusa jetter, along with his band of misfit space pirates and smugglers, can break through ors lines.\naiding an underground resistance movement, the space travellers risk their lives to transport vital supplies to and from earth. one day, however, a mysterious gentleman hires them to deliver an unmarked spherical container. hayabusa accepts the mission, with no idea that this simple package may hold the key to mankind's destiny!\n\n\n", metadata={'anime_id': 3817, 'cast': 'UNKNOWN', 'episodes': 1, 'genre': 'Sci-Fi', 'source': 'Unknown', 'Duration': '59 min', 'name': 'Space Travelers The Animation', 'tokens': "['space', 'traveler', 'animation', 'supe', 'su*torabera', 'zu', 'animation', 'supesutoraberaz', 'animation', '2000', 'science', 'fiction', 'action', 'japanese', 'straight', 'video', 'length', 'animate', 'film', 'produce', 'fuji', 'television', 'network', 'robot', 'film', 'anime', 'tie', '2000', 'live', 'action', 'comedy', 'film', 'space', 'traveler', 'direct', 'katsuyuki', 'motohiro', 'produce', 'fuji', 'television', 'network', 'robot', 'film', '\\n\\n\\n\\n', 'new', 'cosmic', 'century', '038', 'humanity', 'suddenly', 'attack', 'mysterious', 'alien', 'civilization', 'know', 'orbital', 'ring', 'system', 'soon', 'entire', 'earth', 'civilization', 'sphere', 'cut', 'space', 'colony', 'control', 'hayabusa', 'jetter', 'band', 'misfit', 'space', 'pirate', 'smuggler', 'break', 'line', '\\n', 'aid', 'underground', 'resistance', 'movement', 'space', 'traveller', 'risk', 'life', 'transport', 'vital', 'supply', 'earth', 'day', 'mysterious', 'gentleman', 'hire', 'deliver', 'unmarked', 'spherical', 'container', 'hayabusa', 'accept', 'mission', 'idea', 'simple', 'package', 'hold', 'key', 'mankind', 'destiny', '\\n\\n\\n ', 'sci', 'fi', 'unknown', 'unknown', 'fuji', 'tv', 'robot', 'communication', 'unknown', 'new', 'cosmic', 'century', '038', 'humanity', 'suddenly', 'attack', 'unknown', 'alien', 'civilization', 'know', 'orbital', 'ring', 'system', 'soon', 'entire', 'earth', 'civilization', 'sphere', 'cut', 'space', 'colony', 'control', 'hayabusha', 'jetter', 'band', 'misfit', 'space', 'pirate', 'smuggler', 'break', 'line', '\\n\\n', 'source', 'wikipedia', 'unknown', 'space', 'traveler', 'animation']", 'score': 5.23, 'producer': 'Fuji TV, Robot Communications', 'studio': 'UNKNOWN', 'licensors': 'Media Blasters', 'cf_recs': 'Gu-Gu Ganmo (Movie), Guitar, Onigiri ni Naritai Cogimyun, Man with a Mission Animated Short Movie, Hayabusa: Back to the Earth - Kikan, Robot King, Zhu Zhu Xia: Wu Xia 2008, Capsule Samurai, Steady x Study, Controller of Controller', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'PG-13 - Teens 13 or older', 'air_date': 'Jun 23, 2000'}),
#  Document(page_content='space dandy, stylized as space☆dandy (japanese: スペース☆ダンディ, hepburn: supēsu dandi), is a 2014 japanese comic science fiction anime television series produced by bones. the series follows the misadventures of dandy, an alien hunter who is "a dandy guy in space", in search for undiscovered and rare aliens with his robot assistant qt and his feline-like friend named meow.the anime has been licensed by funimation in north america, madman entertainment in australia and by anime limited in the united kingdom. the series first aired in the united states on january 4, 2014 at 11:30 p.m. et/pt on adult swim\'s toonami programming block. the series began airing in japan on tokyo mx at 11 p.m. jst on january 5, 2014, followed by tv osaka, tv aichi, bs fuji and at-x. the series is simulcasted in south east asia at the same time as japan on animax asia. the series has also been broadcast in australia on sbs 2 since 3 october 2015. following sony\'s acquisition of crunchyroll, the series was moved to crunchyroll.a manga adaptation ran in square enix\'s young gangan magazine from december 20, 2013 to october 3, 2014. the manga is licensed in english by yen press. the first season aired from january to march 2014, and the second season aired from july to september 2014.\n\n\n\nthe space opera follows the misadventures of dandy, an alien bounty hunter who is "a dandy guy in space", in search for undiscovered and rare aliens with his robot assistant qt and his feline friend named meow. though he and his crew act with the best intentions, despite being normally dimwitted and next to useless, dandy is unaware that he is being pursued by dr. gel of the gogol empire.\nthe series has loose continuity, with several episodes featuring the main protagonists and antagonists dying, getting turned into zombies, or getting trapped in different dimensions for periods of time, only for them to show up as normal in the next episode. there are also many references to older science fiction, music, anime and internet culture.\n\n\n', metadata={'anime_id': 20057, 'cast': "J. Michael Tatum, Jun'ichi Suwabe, Masaaki Yajima, Uki Satake, Alison Viktorin, Hiroyuki Yoshino, Ian Sinclair, Joel McDonald, R. Bruce Elliott, Hiroki Gotô", 'episodes': 13, 'genre': 'Comedy, Sci-Fi', 'source': 'Original', 'Duration': '24 min per ep', 'name': 'Space☆Dandy', 'tokens': '[\'space\', \'dandy\', \'stylize\', \'spacedandy\', \'japanese\', \'supe\', \'sudandei\', \'hepburn\', \'supesu\', \'dandi\', \'2014\', \'japanese\', \'comic\', \'science\', \'fiction\', \'anime\', \'television\', \'series\', \'produce\', \'bone\', \'series\', \'follow\', \'misadventure\', \'dandy\', \'alien\', \'hunter\', \'dandy\', \'guy\', \'space\', \'search\', \'undiscovered\', \'rare\', \'alien\', \'robot\', \'assistant\', \'qt\', \'feline\', \'like\', \'friend\', \'meow.the\', \'anime\', \'license\', \'funimation\', \'north\', \'america\', \'madman\', \'entertainment\', \'australia\', \'anime\', \'limit\', \'united\', \'kingdom\', \'series\', \'air\', \'united\', \'states\', \'january\', \'4\', \'2014\', \'11:30\', \'p.m.\', \'et\', \'pt\', \'adult\', \'swim\', \'toonami\', \'programming\', \'block\', \'series\', \'begin\', \'air\', \'japan\', \'tokyo\', \'mx\', \'11\', \'p.m.\', \'jst\', \'january\', \'5\', \'2014\', \'follow\', \'tv\', \'osaka\', \'tv\', \'aichi\', \'bs\', \'fuji\', \'x.\', \'series\', \'simulcaste\', \'south\', \'east\', \'asia\', \'time\', \'japan\', \'animax\', \'asia\', \'series\', \'broadcast\', \'australia\', \'sbs\', \'2\', \'3\', \'october\', \'2015\', \'follow\', \'sony\', \'acquisition\', \'crunchyroll\', \'series\', \'crunchyroll.a\', \'manga\', \'adaptation\', \'run\', \'square\', \'enix\', \'young\', \'gangan\', \'magazine\', \'december\', \'20\', \'2013\', \'october\', \'3\', \'2014\', \'manga\', \'license\', \'english\', \'yen\', \'press\', \'season\', \'air\', \'january\', \'march\', \'2014\', \'second\', \'season\', \'air\', \'july\', \'september\', ...
#  Document(page_content="uchūsen sagittarius (宇宙船サジタリウス, uchūsen sajitariusu, lit. spaceship sagittarius) is a 77-episode japanese science fiction anime television series directed by kazuyoshi yokota and created by nippon animation and tv asahi. it aired between january 10, 1986 and october 3, 1987. the series is based on comics created by italian physicist andrea romoli. the series was a huge success in japan and even won the osamu tezuka's atom award at the tokyo film festival.\n\n\n== story ==\nthe series depicts the adventures of four astronauts who travel through space and visit many planets. on each planet they have an adventure. each adventure seems to have a moral, such as the value of friendship or the protection of endangered species.\n\n\n", metadata={'anime_id': 3317, 'cast': "Eriko Hara, Atsuko Mine, Ken'ichi Ogata, Ken Yamaguchi, Maya Okamoto, Yoku Shioya, Bin Shimada, Mitsuko Horie, Andrea Romoli, Gara Takashima", 'episodes': 77, 'genre': 'Adventure, Sci-Fi', 'source': 'Picture book', 'Duration': '24 min per ep', 'name': 'Uchuusen Sagittarius', 'tokens': '[\'uchusen\', \'sagittarius\', \'Yu\', \'Zhou\', \'Chuan\', \'sazitariusu\', \'uchusen\', \'sajitariusu\', \'light\', \'spaceship\', \'sagittarius\', \'77\', \'episode\', \'japanese\', \'science\', \'fiction\', \'anime\', \'television\', \'series\', \'direct\', \'kazuyoshi\', \'yokota\', \'create\', \'nippon\', \'animation\', \'tv\', \'asahi\', \'air\', \'january\', \'10\', \'1986\', \'october\', \'3\', \'1987\', \'series\', \'base\', \'comic_strip\', \'create\', \'italian\', \'physicist\', \'andrea\', \'romoli\', \'series\', \'huge\', \'success\', \'japan\', \'win\', \'osamu\', \'tezuka\', \'atom\', \'award\', \'tokyo\', \'film\', \'festival\', \'\\n\\n\\n\', \'=\', \'=\', \'story\', \'=\', \'=\', \'\\n\', \'series\', \'depict\', \'adventure\', \'astronaut\', \'travel\', \'space\', \'visit\', \'planet\', \'planet\', \'adventure\', \'adventure\', \'moral\', \'value\', \'friendship\', \'protection\', \'endanger\', \'specie\', \'\\n\\n\\n \', \'adventure\', \'sci\', \'fi\', \'picture\', \'book\', \'unknown\', \'unknown\', \'eriko\', \'hara\', \'atsuko\', "ken\'ichi", \'ogata\', \'ken\', \'yamaguchi\', \'maya\', \'okamoto\', \'yoku\', \'shioya\', \'bin\', \'shimada\', \'mitsuko\', \'horie\', \'andrea\', \'romoli\', \'gara\', \'takashima\', \'work\', \'multi\', \'purpose\', \'space\', \'agency\', \'toppy\', \'rana\', \'friend\', \'giraffe\', \'scientist\', \'adventure\', \'space\', \'encounter\', \'danger\', \'time\', \'friendship\', \'save\', \'nick\', \'time\', \'nippon\', \'animation\', \'uchuusen\', \'sagittarius\']', 'score': 7.42, 'producer': 'UNKNOWN', 'studio': 'Nippon Animation', 'licensors': 'UNKNOWN', 'cf_recs': 'Jungle Kurobee, Okawari-Boy Starzan-S, Lan Mao, Fuwa Aoyun Manyouji, Hajime Ningen Gyatoruz, Solar I.II.III, Kankara Sanshin, Cheol-in 007, Space Gundam V, Zhu Zhu Xia: Da Nao Huang Gong', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'UNKNOWN', 'air_date': 'Jan 10, 1986 to Oct 3, 1987'}),
#  Document(page_content="uchūsen sagittarius (宇宙船サジタリウス, uchūsen sajitariusu, lit. spaceship sagittarius) is a 77-episode japanese science fiction anime television series directed by kazuyoshi yokota and created by nippon animation and tv asahi. it aired between january 10, 1986 and october 3, 1987. the series is based on comics created by italian physicist andrea romoli. the series was a huge success in japan and even won the osamu tezuka's atom award at the tokyo film festival.\n\n\n== story ==\nthe series depicts the adventures of four astronauts who travel through space and visit many planets. on each planet they have an adventure. each adventure seems to have a moral, such as the value of friendship or the protection of endangered species.\n\n\n", metadata={'anime_id': 26447, 'cast': "Eriko Hara, Atsuko Mine, Ken'ichi Ogata, Ken Yamaguchi, Maya Okamoto, Yoku Shioya, Bin Shimada, Mitsuko Horie, Andrea Romoli, Gara Takashima", 'episodes': 1, 'genre': 'Adventure, Sci-Fi', 'source': 'Original', 'Duration': '5 min', 'name': 'Uchuusen Sagittarius Pilot', 'tokens': '[\'uchusen\', \'sagittarius\', \'Yu\', \'Zhou\', \'Chuan\', \'sazitariusu\', \'uchusen\', \'sajitariusu\', \'light\', \'spaceship\', \'sagittarius\', \'77\', \'episode\', \'japanese\', \'science\', \'fiction\', \'anime\', \'television\', \'series\', \'direct\', \'kazuyoshi\', \'yokota\', \'create\', \'nippon\', \'animation\', \'tv\', \'asahi\', \'air\', \'january\', \'10\', \'1986\', \'october\', \'3\', \'1987\', \'series\', \'base\', \'comic_strip\', \'create\', \'italian\', \'physicist\', \'andrea\', \'romoli\', \'series\', \'huge\', \'success\', \'japan\', \'win\', \'osamu\', \'tezuka\', \'atom\', \'award\', \'tokyo\', \'film\', \'festival\', \'\\n\\n\\n\', \'=\', \'=\', \'story\', \'=\', \'=\', \'\\n\', \'series\', \'depict\', \'adventure\', \'astronaut\', \'travel\', \'space\', \'visit\', \'planet\', \'planet\', \'adventure\', \'adventure\', \'moral\', \'value\', \'friendship\', \'protection\', \'endanger\', \'specie\', \'\\n\\n\\n \', \'adventure\', \'sci\', \'fi\', \'original\', \'unknown\', \'unknown\', \'eriko\', \'hara\', \'atsuko\', "ken\'ichi", \'ogata\', \'ken\', \'yamaguchi\', \'maya\', \'okamoto\', \'yoku\', \'shioya\', \'bin\', \'shimada\', \'mitsuko\', \'horie\', \'andrea\', \'romoli\', \'gara\', \'takashima\', \'pilot\', \'episode\', \'uchuusen\', \'sagittarius\', \'feature\', \'original\', \'comic\', \'book\', \'art\', \'voice\', \'act\', \'unknown\', \'uchuusen\', \'sagittarius\', \'pilot\']', 'score': 5.63, 'producer': 'UNKNOWN', 'studio': 'UNKNOWN', 'licensors': 'UNKNOWN', 'cf_recs': 'Fuwa Aoyun Manyouji, Lan Mao, Solar I.II.III, Cheol-in 007, Space Gundam V, Zhu Zhu Xia: Da Nao Huang Gong, Slide, Zhu Zhu Xia: Wu Xia 2008, Capsule Samurai, Gu-Gu Ganmo (Movie)', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'UNKNOWN', 'air_date': '1982'}),
#  Document(page_content="sci-fi west saga starzinger (sf西遊記スタージンガー, esu efu saiyūki sutājingā), known as spaceketeers in the united states, is an anime series produced by toei animation. it is a sci-fi remake/adaptation of wu cheng'en's fantasy novel journey to the west. it was directed by yugo serikawa and written by leiji matsumoto. it aired in fuji tv in japan from april 2, 1978, to august 24, 1979. in the united states, it was referred to as spaceketeers and was part of jim terry's force five series. in the united kingdom, it was referred to as sci-bots on vhs releases. in latin america, it was known as el galáctico.\n\n\n== story ==\nthe story revolves around the princess of the moon, aurora and her three cyborg companions (kugo, djorgo, and hakka) who must travel to the great king planet and restore the galaxy energy in the year 2072. the universe was becoming more and more unbalanced as the queen of the great planet grows older. their adventure includes battling the starmen who are transformed from the unbalanced minerals and planets.\n\n\n", metadata={'anime_id': 1236, 'cast': 'Kei Tomiyama, Kazuko Sugiyama, Eiko Masuyama, Hiroya Ishimaru, Kôsei Tomita', 'episodes': 73, 'genre': 'Action, Adventure, Sci-Fi', 'source': 'Original', 'Duration': '25 min per ep', 'name': 'SF Saiyuuki Starzinger', 'tokens': '[\'sci\', \'fi\', \'west\', \'saga\', \'starzinger\', \'sfxi\', \'Ji\', \'suta\', \'zinga-\', \'esu\', \'efu\', \'saiyuki\', \'sutajinga\', \'know\', \'spaceketeer\', \'united\', \'states\', \'anime\', \'series\', \'produce\', \'toei\', \'animation\', \'sci\', \'fi\', \'remake\', \'adaptation\', \'wu\', "cheng\'en", \'fantasy\', \'novel\', \'journey\', \'west\', \'direct\', \'yugo\', \'serikawa\', \'write\', \'leiji\', \'matsumoto\', \'air\', \'fuji\', \'tv\', \'japan\', \'april\', \'2\', \'1978\', \'august\', \'24\', \'1979\', \'united\', \'states\', \'refer\', \'spaceketeer\', \'jim\', \'terry\', \'force\', \'series\', \'united\', \'kingdom\', \'refer\', \'sci\', \'bot\', \'vhs\', \'release\', \'latin\', \'america\', \'know\', \'el\', \'galactico\', \'\\n\\n\\n\', \'=\', \'=\', \'story\', \'=\', \'=\', \'\\n\', \'story\', \'revolve\', \'princess\', \'moon\', \'aurora\', \'cyborg\', \'companion\', \'kugo\', \'djorgo\', \'hakka\', \'travel\', \'great\', \'king\', \'planet\', \'restore\', \'galaxy\', \'energy\', \'year\', \'2072\', \'universe\', \'unbalanced\', \'queen\', \'great\', \'planet\', \'grow\', \'old\', \'adventure\', \'include\', \'battle\', \'starman\', \'transform\', \'unbalanced\', \'mineral\', \'planet\', \'\\n\\n\\n \', \'action\', \'adventure\', \'sci\', \'fi\', \'original\', \'anime\', \'animation\', \'journey\', \'west\', \'princess\', \'professor\', \'alien\', \'race\', \'unknown\', \'kei\', \'tomiyama\', \'kazuko\', \'sugiyama\', \'eiko\', \'masuyama\', \'hiroya\', \'ishimaru\', \'kosei\', \'tomita\', \'great\', \'planet\', \'die\', \'queen\', \'old\', \'powerless\', \'universe\', \'perish\', \'princess\', \'aurora\', \'moon\', \'volunteer\', \'new\', \'queen\', \'set\', \'dangerous\', \'travel\', \'friend\', \'escort\', \'powerful\', \'cyborgs\', \'jan\', \'kogo\', \'sa\', \'jogo\', \'don\', \'hakka\', \'toei\', \'animation\', \'sf\', \'saiyuuki\', \'starzinger\']', 'score': 6.96, 'producer': 'UNKNOWN', 'studio': 'Toei Animation', 'licensors': 'UNKNOWN', 'cf_recs': 'Ore no Sora Keiji-hen, Magnerobo Ga-Keen, Ookami Shounen Ken, Cybot Robocchi, Fuwa Aoyun Manyouji, Manga Naruhodo Monogatari, Lan Mao, Solar I.II.III, Marine Snow no Densetsu, Space Gundam V', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'UNKNOWN', 'air_date': 'Apr 2, 1978 to Aug 26, 1979'}),
#  Document(page_content='yat untroubled space tours (yat安心!宇宙旅行, yatto anshin! uchū ryokō) is an anime series produced by group tac.\nit aired on nhk in japan from october 1996 to september 1997; a second series aired from april to october 1998.\n\n\n\nthe series is set in the year 5808; human civilization has taken gigantic steps in the conquest of the space, and with the creation of the three-dimensional tunnel, people can travel to any galaxy in the universe. "the gentleman of the cosmos" is a company that manages the tunnel and has come to dominate the tourism industry.\nthe main characters of the series are part of yamamoto anshin travel (yat), with the plot revolving around goro hoshiwatari, an adolescent who has left his home to travel by the space and to find the whereabouts of his father, who disappeared fifteen years ago during the explosion of the main transporting center of the three-dimensional tunnel that he created. goro falls in love with katsura, the commander\'s daughter; and becomes the yat mechanic/janitor after an accident that he was responsible for, so he tags along to pay for the damage and to find his father as well. finding his father turns out not to be his only problem, since kanea, a young lady whose mother is the owner of "the gentleman of the cosmos", is in love with him. in addition, kanea\'s mother had a mysterious and conflicting past with yamamoto.\nthe second series takes place six months after the first. yat ships and crew are transported to a very far universe. they soon discover that the person responsible is professor nota, a scientific who is working on a teletransportation device, helped by a cat-like girl with psychic powers called "pinky". then, the professor is kidnapped by emperor ganon, who wants to use the device to rule the universe. the aim of the yat crew is finding the kidnapped professor and going back to earth.\n\n\n', metadata={'anime_id': 1891, 'cast': 'UNKNOWN', 'episodes': 50, 'genre': 'Adventure, Comedy, Sci-Fi', 'source': 'Original', 'Duration': '25 min per ep', 'name': 'YAT Anshin! Uchuu Ryokou', 'tokens': "['yat', 'untroubled', 'space', 'tour', 'yatAn', 'Xin', 'Yu', 'Zhou', 'Lu', 'Xing', 'yatto', 'anshin', 'uchu', 'ryoko', 'anime', 'series', 'produce', 'group', 'tac', '\\n', 'air', 'nhk', 'japan', 'october', '1996', 'september', '1997', 'second', 'series', 'air', 'april', 'october', '1998', '\\n\\n\\n\\n', 'series', 'set', 'year', '5808', 'human', 'civilization', 'gigantic', 'step', 'conquest', 'space', 'creation', 'dimensional', 'tunnel', 'people', 'travel', 'galaxy', 'universe', 'gentleman', 'cosmo', 'company', 'manage', 'tunnel', 'come', 'dominate', 'tourism', 'industry', '\\n', 'main', 'character', 'series', 'yamamoto', 'anshin', 'travel', 'yat', 'plot', 'revolve', 'goro', 'hoshiwatari', 'adolescent', 'leave', 'home', 'travel', 'space', 'find', 'whereabouts', 'father', 'disappear', 'year', 'ago', 'explosion', 'main', 'transporting', 'center', 'dimensional', 'tunnel', 'create', 'goro', 'fall', 'love', 'katsura', 'commander', 'daughter', 'yat', 'mechanic', 'janitor', 'accident', 'responsible', 'tag', 'pay', 'damage', 'find', 'father', 'find', 'father', 'turn', 'problem', 'kanea', 'young', 'lady', 'mother', 'owner', 'gentleman', 'cosmo', 'love', 'addition', 'kanea', 'mother', 'mysterious', 'conflicting', 'past', 'yamamoto', '\\n', 'second', 'series', 'place', 'month', 'yat', 'ship', 'crew', 'transport', 'far', 'universe', 'soon', 'discover', 'person', 'responsible', 'professor', 'nota', 'scientific', 'work', 'teletransportation', 'device', 'help', 'cat', 'like', 'girl', 'psychic', 'power', 'pinky', 'professor', 'kidnap', 'emperor', 'ganon', 'want', 'use', 'device', 'rule', 'universe', 'aim', 'yat', 'crew', 'find', 'kidnapped', 'professor', 'earth', '\\n\\n\\n ', 'adventure', 'comedy', 'sci', 'fi', 'original', 'unknown', 'nhk', 'unknown', 'emergence', 'dimensional', 'tunnel', 'set', 'background', 'new', 'space', 'era', 'space', 'travel', 'designate', 'planet', 'outsi ...
#  Document(page_content='yat untroubled space tours (yat安心!宇宙旅行, yatto anshin! uchū ryokō) is an anime series produced by group tac.\nit aired on nhk in japan from october 1996 to september 1997; a second series aired from april to october 1998.\n\n\n\nthe series is set in the year 5808; human civilization has taken gigantic steps in the conquest of the space, and with the creation of the three-dimensional tunnel, people can travel to any galaxy in the universe. "the gentleman of the cosmos" is a company that manages the tunnel and has come to dominate the tourism industry.\nthe main characters of the series are part of yamamoto anshin travel (yat), with the plot revolving around goro hoshiwatari, an adolescent who has left his home to travel by the space and to find the whereabouts of his father, who disappeared fifteen years ago during the explosion of the main transporting center of the three-dimensional tunnel that he created. goro falls in love with katsura, the commander\'s daughter; and becomes the yat mechanic/janitor after an accident that he was responsible for, so he tags along to pay for the damage and to find his father as well. finding his father turns out not to be his only problem, since kanea, a young lady whose mother is the owner of "the gentleman of the cosmos", is in love with him. in addition, kanea\'s mother had a mysterious and conflicting past with yamamoto.\nthe second series takes place six months after the first. yat ships and crew are transported to a very far universe. they soon discover that the person responsible is professor nota, a scientific who is working on a teletransportation device, helped by a cat-like girl with psychic powers called "pinky". then, the professor is kidnapped by emperor ganon, who wants to use the device to rule the universe. the aim of the yat crew is finding the kidnapped professor and going back to earth.\n\n\n', metadata={'anime_id': 1892, 'cast': 'UNKNOWN', 'episodes': 25, 'genre': 'Adventure, Comedy, Sci-Fi', 'source': 'Original', 'Duration': '25 min per ep', 'name': 'YAT Anshin! Uchuu Ryokou 2', 'tokens': "['yat', 'untroubled', 'space', 'tour', 'yatAn', 'Xin', 'Yu', 'Zhou', 'Lu', 'Xing', 'yatto', 'anshin', 'uchu', 'ryoko', 'anime', 'series', 'produce', 'group', 'tac', '\\n', 'air', 'nhk', 'japan', 'october', '1996', 'september', '1997', 'second', 'series', 'air', 'april', 'october', '1998', '\\n\\n\\n\\n', 'series', 'set', 'year', '5808', 'human', 'civilization', 'gigantic', 'step', 'conquest', 'space', 'creation', 'dimensional', 'tunnel', 'people', 'travel', 'galaxy', 'universe', 'gentleman', 'cosmo', 'company', 'manage', 'tunnel', 'come', 'dominate', 'tourism', 'industry', '\\n', 'main', 'character', 'series', 'yamamoto', 'anshin', 'travel', 'yat', 'plot', 'revolve', 'goro', 'hoshiwatari', 'adolescent', 'leave', 'home', 'travel', 'space', 'find', 'whereabouts', 'father', 'disappear', 'year', 'ago', 'explosion', 'main', 'transporting', 'center', 'dimensional', 'tunnel', 'create', 'goro', 'fall', 'love', 'katsura', 'commander', 'daughter', 'yat', 'mechanic', 'janitor', 'accident', 'responsible', 'tag', 'pay', 'damage', 'find', 'father', 'find', 'father', 'turn', 'problem', 'kanea', 'young', 'lady', 'mother', 'owner', 'gentleman', 'cosmo', 'love', 'addition', 'kanea', 'mother', 'mysterious', 'conflicting', 'past', 'yamamoto', '\\n', 'second', 'series', 'place', 'month', 'yat', 'ship', 'crew', 'transport', 'far', 'universe', 'soon', 'discover', 'person', 'responsible', 'professor', 'nota', 'scientific', 'work', 'teletransportation', 'device', 'help', 'cat', 'like', 'girl', 'psychic', 'power', 'pinky', 'professor', 'kidnap', 'emperor', 'ganon', 'want', 'use', 'device', 'rule', 'universe', 'aim', 'yat', 'crew', 'find', 'kidnapped', 'professor', 'earth', '\\n\\n\\n ', 'adventure', 'comedy', 'sci', 'fi', 'original', 'unknown', 'nhk', 'unknown', 'space', 'travel', 'company', 'yat', 'throw', 'unknown', 'realm', 'outer', 'space', 'time', 'group', 'encounter', 'psychic', 'ma ...
#  Document(page_content='the girl who leapt through space (japanese: 宇宙をかける少女, hepburn: sora o kakeru shōjo, lit. "the spacefaring girl" and also abbreviated as "sora kake girl") is a japanese anime television series, created and produced by sunrise. based on the original concept by the sunrise animation staff, the series is directed by masakazu obara and written by jukki hanada, overseeing a team of animators noted for their previous work on my-hime and my-otome.\nthe anime began airing in japan on the tv tokyo television network on january 5, 2009. the series is set in the far future where humans now live in space colonies orbiting far from earth. a manga adaptation, sora kake girl r, began serialization in the march 2009 issue of ichijinsha\'s comic rex, and another manga, sora kake girl d, began serialization in the april 2009 issue of ascii media works\' dengeki daioh. a light novel adaptation began serialization in ichijinsha\'s chara mel in december 2008, and an internet radio show has also been created.\n\n\n\nin the year 311 of the orbital calendar, humanity has migrated to countless colony clusters in space. akiha shishido encounters a malevolent artificial intelligence, leopard, who has been installed on a colony. she is joined by inter-colony-police officer itsuki kannagi, taciturn young girl honoka kawai, and a robot-potato, imoko "imo-chan" shishido.\n\n\n', metadata={'anime_id': 5307, 'cast': 'Ai Nonaka, Hajime Yatate, Takaya Kuroda, Mako, Yui Makino, Daisuke Ono, Jun Fukuyama, Akiko Kimura, Yukari Tamura, Aya Endô', 'episodes': 26, 'genre': 'Adventure, Comedy, Sci-Fi', 'source': 'Original', 'Duration': '24 min per ep', 'name': 'Sora wo Kakeru Shoujo', 'tokens': "['girl', 'leapt', 'space', 'japanese', 'Yu', 'Zhou', 'wokakeruShao', 'Nu', 'hepburn', 'sora', 'o', 'kakeru', 'shojo', 'light', 'spacefare', 'girl', 'abbreviate', 'sora', 'kake', 'girl', 'japanese', 'anime', 'television', 'series', 'create', 'produce', 'sunrise', 'base', 'original', 'concept', 'sunrise', 'animation', 'staff', 'series', 'direct', 'masakazu', 'obara', 'write', 'jukki', 'hanada', 'oversee', 'team', 'animator', 'note', 'previous', 'work', 'hime', 'otome', '\\n', 'anime', 'begin', 'air', 'japan', 'tv', 'tokyo', 'television', 'network', 'january', '5', '2009', 'series', 'set', 'far', 'future', 'human', 'live', 'space', 'colony', 'orbit', 'far', 'earth', 'manga', 'adaptation', 'sora', 'kake', 'girl', 'r', 'begin', 'serialization', 'march', '2009', 'issue', 'ichijinsha', 'comic', 'rex', 'manga', 'sora', 'kake', 'girl', 'd', 'begin', 'serialization', 'april', '2009', 'issue', 'ascii', 'medium', 'work', 'dengeki', 'daioh', 'light', 'novel', 'adaptation', 'begin', 'serialization', 'ichijinsha', 'chara', 'mel', 'december', '2008', 'internet', 'radio', 'create', '\\n\\n\\n\\n', 'year', '311', 'orbital', 'calendar', 'humanity', 'migrate', 'countless', 'colony', 'cluster', 'space', 'akiha', 'shishido', 'encounter', 'malevolent', 'artificial', 'intelligence', 'leopard', 'instal', 'colony', 'join', 'inter', 'colony', 'police', 'officer', 'itsuki', 'kannagi', 'taciturn', 'young', 'girl', 'honoka', 'kawai', 'robot', 'potato', 'imoko', 'imo', 'chan', 'shishido', '\\n\\n\\n ', 'adventure', 'comedy', 'sci', 'fi', 'original', 'anime', 'animation', 'scantily', 'clothe', 'female', 'unknown', 'ai', 'nonaka', 'hajime', 'yatate', 'takaya', 'kuroda', 'mako', 'yui', 'makino', 'daisuke', 'ono', 'jun', 'fukuyama', 'akiko', 'kimura', 'yukari', 'tamura', 'aya', 'endo', 'story', 'set', 'year', '311', 'orbital', 'calendar', 'humanity', 'migrate', 'countless', 'colony', 'cluster', 'space', 'space', 'colony', 'girl', 'akiha', 'shishidou', 'encounter', 'malevolent', 'artificial', 'intelligence', 'leopard', 'instal', 'colony', 'sunrise', 'sora', 'kakeru', 'shoujo']", 'score': 7.01, 'producer': 'UNKNOWN', 'studio': 'Sunrise', 'licensors': 'Bandai Entertainment, Sentai Filmworks', 'cf_recs': 'Yoku Wakaru Gendai Mahou, Umi Monogatari: Anata ga Ite Kureta Koto, Sky Girls, Zettai Ka ...
# ...
#  Document(page_content='take the characters from a number of sci-fi based animes, a stage not unlike \\wacky races,\\" super deformed madness, and general insanity and what you get is scramble wars. while scramble wars does include characters from the original bubblegum crisis, gall force and genesis survivor gaiarth, it also has a few other characters from other animes such as ad police and riding bean. it doesn\'t matter if you loved or hated any of these series, as long as you\'ve seen at least one of them you\'ll have a great time watching this, though the insanity is so generic that it really doesn\'t matter if you haven\'t seen any of the animes featured in scramble wars."', metadata={'anime_id': 2466, 'cast': 'Hideki Kakinuma, Eriko Hara, Maria Kawamura, Hiromi Tsuru, Akiko Hiramatsu, Robert J. Woodhead, Kenichi Sonoda, Katsuhito Akiyama, Tatsuya Masaki, Hideyuki Umezu', 'episodes': 1, 'genre': 'Comedy', 'source': 'Original', 'Duration': '26 min', 'name': 'Scramble Wars: Tsuppashire! Genom Trophy Rally', 'tokens': "['character', 'number', 'sci', 'fi', 'base', 'anime', 'stage', 'unlike', '\\\\wacky', 'races,\\\\', 'super', 'deform', 'madness', 'general', 'insanity', 'scramble', 'war', 'scramble', 'war', 'include', 'character', 'original', 'bubblegum', 'crisis', 'gall', 'force', 'genesis', 'survivor', 'gaiarth', 'character', 'anime', 'ad', 'police', 'ride', 'bean', 'matter', 'love', 'hate', 'series', 'long', 'great', 'time', 'watch', 'insanity', 'generic', 'matter', 'anime', 'feature', 'scramble', 'war', 'comedy', 'original', 'anime', 'animation', 'parody', 'comedy', 'animate', 'spoof', 'scene', 'toshiba', 'emi', 'hideki', 'kakinuma', 'eriko', 'hara', 'maria', 'kawamura', 'hiromi', 'tsuru', 'akiko', 'hiramatsu', 'robert', 'j.', 'woodhead', 'kenichi', 'sonoda', 'katsuhito', 'akiyama', 'tatsuya', 'masaki', 'hideyuki', 'umezu', 'character', 'number', 'sci', 'fi', 'base', 'anime', 'stage', 'unlike', '\\\\wacky', 'races,\\\\', 'super', 'deform', 'madness', 'general', 'insanity', 'scramble', 'war', 'scramble', 'war', 'include', 'character', 'original', 'bubblegum', 'crisis', 'gall', 'force', 'genesis', 'survivor', 'gaiarth', 'character', 'anime', 'ad', 'police', 'ride', 'bean', 'matter', 'love', 'hate', 'series', 'long', 'great', 'time', 'watch', 'insanity', 'generic', 'matter', 'anime', 'feature', 'scramble', 'war', 'artmic', 'scramble', 'war', 'tsuppashire', 'genom', 'trophy', 'rally']", 'score': 6.05, 'producer': 'Toshiba EMI', 'studio': 'Artmic', 'licensors': 'AnimEigo', 'cf_recs': 'Ten Little Gall Force, Super Titans 15, Kamo ga Suki, Sennen no Yakusoku, Shoko Nakagawa Prism Tour Special, Guitar Shoujo!, S=13, Zero Tester: Chikyuu wo Mamore!, Prison Bear, Junkers Come Here Pilot Film', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'UNKNOWN', 'air_date': 'Oct 28, 1992'}),
#  Document(page_content="arei's mirror: way to the virgin space (アレイの鏡 〜ウェイ・トゥ・ザ・バージン・スペース〜, arei no kagami ~wei tu za bājin spēsu~, also known as mirror of halley) was originally created by leiji matsumoto as an educational-like video aimed more at children. it used information about earth and outer space which lead many to believe it as an educational video. it was first shown only as a film in the expo '85 as part of the world fair.  it was also leiji matsumoto's first work with computer graphics in it. the same year it was published a single-volume comic adaptation cured by sekai bunkasha.\n\n\n\nthe story follows daichi meguru and mayu, a young boy and a pilot, as they flee their war torn planet and into space. upon their ship a stowaway android named zero joins their quest as they travel through halley's mirror.\n\n\n", metadata={'anime_id': 7156, 'cast': 'UNKNOWN', 'episodes': 1, 'genre': 'Action, Adventure, Sci-Fi', 'source': 'Unknown', 'Duration': '26 min', 'name': 'Arei no Kagami: Way to the Virgin Space', 'tokens': "['arei', 'mirror', 'way', 'virgin', 'space', 'areinojing', ' ', '~', 'uei*tou*za*ba', 'zin*supe', 'su~', 'arei', 'kagami', '~wei', 'tu', 'za', 'bajin', 'spesu~', 'know', 'mirror', 'halley', 'originally', 'create', 'leiji', 'matsumoto', 'educational', 'like', 'video', 'aim', 'child', 'use', 'information', 'earth', 'outer', 'space', 'lead', 'believe', 'educational', 'video', 'film', 'expo', '85', 'world', 'fair', ' ', 'leiji', 'matsumoto', 'work', 'computer', 'graphic', 'year', 'publish', 'single', 'volume', 'comic', 'adaptation', 'cure', 'sekai', 'bunkasha', '\\n\\n\\n\\n', 'story', 'follow', 'daichi', 'meguru', 'mayu', 'young', 'boy', 'pilot', 'flee', 'war', 'tear', 'planet', 'space', 'ship', 'stowaway', 'android', 'zero', 'join', 'quest', 'travel', 'halley', 'mirror', '\\n\\n\\n ', 'action', 'adventure', 'sci', 'fi', 'unknown', 'unknown', 'unknown', 'unknown', 'story', 'follow', 'daichi', 'meguru', 'mayu', 'young', 'boy', 'pilot', 'flee', 'war', 'tear', 'planet', 'space', 'ship', 'stowaway', 'android', 'zero', 'join', 'quest', 'travel', 'halley', 'mirror', '\\n\\n', 'source', 'wikipedia', 'toei', 'animation', 'arei', 'kagami', 'way', 'virgin', 'space']", 'score': 5.4, 'producer': 'UNKNOWN', 'studio': 'Toei Animation', 'licensors': 'UNKNOWN', 'cf_recs': 'Marine Snow no Densetsu, Manga Naruhodo Monogatari, Fusuma no Oku, Chalk-iro no People, Super Titans 15, Zero Tester: Chikyuu wo Mamore!, Kamo ga Suki, S=13, Shin Gakkou no Yuurei, Bulsajo Robot Phoenix King', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'G - All Ages', 'air_date': 'Mar 16, 1985'}),
#  Document(page_content='eureka seven, known in japan as psalms of planets eureka seven (japanese: 交響詩篇エウレカセブン, hepburn: kōkyōshihen eureka sebun, lit. "symphonic psalms eureka seven"), is a 2005 japanese anime series created by bones. the series was directed by tomoki kyoda, with series composition by dai satō, character designs by kenichi yoshida and music by naoki satō. eureka seven tells the story of renton thurston and the outlaw group gekkostate, his relationship with the enigmatic mecha pilot eureka, and the mystery of the coralians. the fifty-episode series aired on mbs between april 2005 and april 2006. it was licensed by funimation in north america, madman entertainment in australia and new zealand and by anime limited in the united kingdom for english home video releases.\nthe series spawned six manga adaptations, a light novel, three video games and a feature-length anime film which was released in april 2009. one of the manga titled eureka seven: ao which was serialized in monthly shōnen ace between january 2012 and october 2013, was further adapted into an anime series which aired twenty-four episodes between april and november 2012. eureka seven was well received by critics and earned several awards at numerous award shows in japan, most notably the 2006 tokyo international anime fair.\n\n\n== overview ==\n\n\n', metadata={'anime_id': 12471, 'cast': 'Tetsuo Gotô, Ayaka Ohashi, Jamie Marchi, Sainty Nelsen, Micah Solusod, Nao Tôyama, Takuya Kirimoto, Chiaki Omigawa, Yûtarô Honjô, Chie Nakamura', 'episodes': 24, 'genre': 'Action, Adventure, Drama, Sci-Fi', 'source': 'Manga', 'Duration': '24 min per ep', 'name': 'Eureka Seven AO', 'tokens': '[\'eureka\', \'seven\', \'know\', \'japan\', \'psalm\', \'planet\', \'eureka\', \'seven\', \'japanese\', \'Jiao\', \'Xiang\', \'Shi\', \'Pian\', \'eurekasebun\', \'hepburn\', \'kokyoshihen\', \'eureka\', \'sebun\', \'light\', \'symphonic\', \'psalm\', \'eureka\', \'seven\', \'2005\', \'japanese\', \'anime\', \'series\', \'create\', \'bone\', \'series\', \'direct\', \'tomoki\', \'kyoda\', \'series\', \'composition\', \'dai\', \'sato\', \'character\', \'design\', \'kenichi\', \'yoshida\', \'music\', \'naoki\', \'sato\', \'eureka\', \'seven\', \'tell\', \'story\', \'renton\', \'thurston\', \'outlaw\', \'group\', \'gekkostate\', \'relationship\', \'enigmatic\', \'mecha\', \'pilot\', \'eureka\', \'mystery\', \'coralian\', \'episode\', \'series\', \'air\', \'mb\', \'april\', \'2005\', \'april\', \'2006\', \'license\', \'funimation\', \'north\', \'america\', \'madman\', \'entertainment\', \'australia\', \'new\', \'zealand\', \'anime\', \'limit\', \'united\', \'kingdom\', \'english\', \'home\', \'video\', \'release\', \'\\n\', \'series\', \'spawn\', \'manga\', \'adaptation\', \'light\', \'novel\', \'video\', \'game\', \'feature\', \'length\', \'anime\', \'film\', \'release\', \'april\', \'2009\', \'manga\', \'title\', \'eureka\', \'seven\', \'ao\', \'serialize\', \'monthly\', \'shonen\', \'ace\', \'january\', \'2012\', \'october\', \'2013\', \'far\', \'adapt\', \'anime\', \'series\', \'air\', \'episode\', \'april\', \'november\', \'2012\', \'eureka\', \'seven\', \'receive\', \'critic\', \'earn\', \'award\', \'numerous\', \'award\', \'japan\', \'notably\', \'2006\', \'tokyo\', \'international\', \'anime\', \'fair\', \'\\n\\n\\n\', \'=\', \'=\', \'overview\', \'=\', \'=\', \'\\n\\n\\n \', \'action\', \'adventure\', \'drama\', \'sci\', \'fi\', \'manga\', \'robot\', \'robot\', \'sci\', \'fi\', \'boy\', \'anime\', \'animation\', \'bandai\', \'visual\', \'kadokawa\', \'shoten\', \'mainichi\', \'broadcasting\', \'system\', \'bandai\', \'sony\', \'music\', \'entertainment\', \'bandai\', \'namco\', \'games\', \'sammy\', \'hakuhodo\', \'dy\', \'medium\', \'partner\', \'bandai\', \'channel\', \'tetsuo\', \'goto\', \'ayaka\', \'ohashi\', \'jamie\', \'marchi\', \'sainty\', \'nelsen\', \'micah\', \'solusod\', \'nao\', \'toyama\', \'takuya\', \'kirimoto\', \'chiaki\', \'omigawa\', \'yutaro\', \'honjo\' ...
#  Document(page_content='eureka seven, known in japan as psalms of planets eureka seven (japanese: 交響詩篇エウレカセブン, hepburn: kōkyōshihen eureka sebun, lit. "symphonic psalms eureka seven"), is a 2005 japanese anime series created by bones. the series was directed by tomoki kyoda, with series composition by dai satō, character designs by kenichi yoshida and music by naoki satō. eureka seven tells the story of renton thurston and the outlaw group gekkostate, his relationship with the enigmatic mecha pilot eureka, and the mystery of the coralians. the fifty-episode series aired on mbs between april 2005 and april 2006. it was licensed by funimation in north america, madman entertainment in australia and new zealand and by anime limited in the united kingdom for english home video releases.\nthe series spawned six manga adaptations, a light novel, three video games and a feature-length anime film which was released in april 2009. one of the manga titled eureka seven: ao which was serialized in monthly shōnen ace between january 2012 and october 2013, was further adapted into an anime series which aired twenty-four episodes between april and november 2012. eureka seven was well received by critics and earned several awards at numerous award shows in japan, most notably the 2006 tokyo international anime fair.\n\n\n== overview ==\n\n\n', metadata={'anime_id': 4246, 'cast': 'Keiji Fujiwara, Gichi Ootsuka, Hiroshi Haraguchi, Kaori Nazuka, Hironori Aoyagi, Michiko Neya, Yûko Sanpei, Tomoki Kyôda, Masaru Yasukawa, Dai Satô', 'episodes': 1, 'genre': 'Adventure, Romance, Sci-Fi', 'source': 'Original', 'Duration': '1 hr 55 min', 'name': 'Koukyoushihen Eureka Seven: Pocket ga Niji de Ippai', 'tokens': "['eureka', 'seven', 'know', 'japan', 'psalm', 'planet', 'eureka', 'seven', 'japanese', 'Jiao', 'Xiang', 'Shi', 'Pian', 'eurekasebun', 'hepburn', 'kokyoshihen', 'eureka', 'sebun', 'light', 'symphonic', 'psalm', 'eureka', 'seven', '2005', 'japanese', 'anime', 'series', 'create', 'bone', 'series', 'direct', 'tomoki', 'kyoda', 'series', 'composition', 'dai', 'sato', 'character', 'design', 'kenichi', 'yoshida', 'music', 'naoki', 'sato', 'eureka', 'seven', 'tell', 'story', 'renton', 'thurston', 'outlaw', 'group', 'gekkostate', 'relationship', 'enigmatic', 'mecha', 'pilot', 'eureka', 'mystery', 'coralian', 'episode', 'series', 'air', 'mb', 'april', '2005', 'april', '2006', 'license', 'funimation', 'north', 'america', 'madman', 'entertainment', 'australia', 'new', 'zealand', 'anime', 'limit', 'united', 'kingdom', 'english', 'home', 'video', 'release', '\\n', 'series', 'spawn', 'manga', 'adaptation', 'light', 'novel', 'video', 'game', 'feature', 'length', 'anime', 'film', 'release', 'april', '2009', 'manga', 'title', 'eureka', 'seven', 'ao', 'serialize', 'monthly', 'shonen', 'ace', 'january', '2012', 'october', '2013', 'far', 'adapt', 'anime', 'series', 'air', 'episode', 'april', 'november', '2012', 'eureka', 'seven', 'receive', 'critic', 'earn', 'award', 'numerous', 'award', 'japan', 'notably', '2006', 'tokyo', 'international', 'anime', 'fair', '\\n\\n\\n', '=', '=', 'overview', '=', '=', '\\n\\n\\n ', 'adventure', 'romance', 'sci', 'fi', 'original', 'future', 'anime', 'animation', 'group', 'young', 'base', 'tv', 'series', 'unknown', 'keiji', 'fujiwara', 'gichi', 'ootsuka', 'hiroshi', 'haraguchi', 'kaori', 'nazuka', 'hironori', 'aoyagi', 'michiko', 'neya', 'yuko', 'sanpei', 'tomoki', 'kyoda', 'masaru', 'yasukawa', 'dai', 'sato', 'renton', 'son', 'scientist', 'eureka', 'girl', 'live', 'sun', 'raise', 'young', 'attached', 'day', 'eureka', 'away', 'powerless', 'time', 'renton', 'vow', 'rescue', 'enter', 'military', 'soon', 'assign', 'independent', 'youth', 'unit', '303', 'mobile', 'force', 'thank', 'exceptional', 'performance', 'alongside', 'nirvash', 'bio', 'mechanical', 'armor', 'control', 'system', 'unknown', 'renton', 'lie', 'plot', 'extinguish', 'alien', 'invasion', 'currently', 'happen', 'involve', 'eureka', 'bone', 'kinema', 'citrus', 'koukyoushihen', ...

# %%
import yaml

# Load API key from config.yaml
with open("/Users/justinvhuang/Desktop/CSE-6242-Group-Project/app/config.yaml", "r") as file:
    config = yaml.safe_load(file)

api_key = config["api_key"]

# %%
import google.generativeai as genai
userdata = {"GOOGLE_API_KEY": api_key}
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
retriever = db.as_retriever(search_kwargs={"k": 50, "filter": filter_tokens})

# %%
from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# Prompt
prompt = hub.pull("rlm/rag-prompt")

# %%
llm = ChatGoogleGenerativeAI(model="gemini-pro", temperature=0,google_api_key = GOOGLE_API_KEY)

# %%
from langchain.chains.query_constructor.base import AttributeInfo
from langchain.retrievers.self_query.base import SelfQueryRetriever

# %%
metadata_field_info = [
    AttributeInfo(
        name="anime_id",
        description="The anime identifier",
        type="int",
    ),
    AttributeInfo(
        name="cast",
        description="The actors that are are in the anime",
        type="string",
    ),
       AttributeInfo(
        name="episodes",
        description="The number of episodes in the anime",
        type="int",
    ),
    AttributeInfo(
        name="source",
        description="Where the anime came from for example a manga or light novel",
        type="string",
    ),
       AttributeInfo(
        name="Duration",
        description="How long the anime is in minutes",
        type="string",
    ),
    AttributeInfo(
        name="name",
        description="The name of the anime",
        type="string",
    ),
    AttributeInfo(
        name="tokens",
        description="The token of the embedded text to do hybrid search",
        type="string",
    ),
    AttributeInfo(
        name="year",
        description="The year the movie was released",
        type="integer",
    ),
    AttributeInfo(
        name="score",
        description="The score of the rating of the anime",
        type="float",
    ),
    AttributeInfo(
        name="producer", description="Producer of the anime", type="string"
    ),
     AttributeInfo(
        name="studio", description="Which studio produced the anime", type="string"
    ), 
    AttributeInfo(
        name="producer", description="Producer of the anime", type="string"
    ), 
    AttributeInfo(
        name="licensors", description="Which tv licensor is running the anime online for streaming", type="string"
    ), 
    AttributeInfo(
        name="cf_recs", description="A list of strings of anime that is recommended based on collaborative filtering", type="string"
    ), 
    AttributeInfo(
        name="pop_recs", description="Popular recommended animes from this dataset", type="string"
    ),
     AttributeInfo(
        name="rating", description="The television rating for the anime that rates it for age groups", type="string"
    ),
       AttributeInfo(
        name="air_date", description="When the anime first was on tv/aired and when did it end", type="string"
    ),
]
document_content_description = "Description of animes"

# %%
self_retriever = SelfQueryRetriever.from_llm(
    llm,
    db,
    document_content_description,
    metadata_field_info,
)

# %%
# Chain
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
query = "What are some good treasure seeking anime?"
query_token = textprepo.preprocess_text(query)
rag_chain.invoke(query)
# Out:
# "I'm sorry, but I cannot answer your question based on the provided context. The provided text does not mention any treasure seeking anime."

# %%
retriever.get_relevant_documents("hi")
# Out:
# [Document(page_content='hiyokoi (japanese: ひよ恋) is a shōjo manga series written and illustrated by moe yukimaru. it is serialized in shueisha\'s monthly shōjo manga magazine ribon, and had been published into fourteen tankōbon volumes. the name of the series is a pun between "hiyoko" (ひよこ, which means "chick") and "koi" (恋, which means "love").\na twenty-two-minute-long movie based on the manga and produced by production i.g. was released in the ribon summer festival on july 30, 2010. the movie was later released on a dvd along with the yumeiro patissiere ova.\n\n\n\nhiyori nishiyama is a 15-year-old girl who is extremely short. after being in an accident that caused her bones to stop growing, she starts going to high school as a freshman, along with her best friend ritsuka. in her class there is a boy whose name is yuushin hirose and becomes hiyori\'s friend (despite the fact that hiyori is not very happy with his height or his constant happy attitude). after an accident where her panties were shown to the class, she is consoled by yuushin and starts liking him, eventually growing closer to him.\n\n\n', metadata={'anime_id': 15895, 'cast': 'UNKNOWN', 'episodes': 3, 'genre': 'Romance', 'source': 'Manga', 'Duration': '1 min per ep', 'name': 'Hiyokoi (2012)', 'tokens': "['hiyokoi', 'japanese', 'hiyolian', 'shojo', 'manga', 'series', 'write', 'illustrate', 'moe', 'yukimaru', 'serialize', 'shueisha', 'monthly', 'shojo', 'manga', 'magazine', 'ribon', 'publish', 'fourteen', 'tankobon', 'volume', 'series', 'pun', 'hiyoko', 'hiyoko', 'mean', 'chick', 'koi', 'Lian', 'mean', 'love', '\\n', 'minute', 'long', 'movie', 'base', 'manga', 'produce', 'production', 'i.g', 'release', 'ribon', 'summer', 'festival', 'july', '30', '2010', 'movie', 'later', 'release', 'dvd', 'yumeiro', 'patissiere', 'ova', '\\n\\n\\n\\n', 'hiyori', 'nishiyama', '15', 'year', 'old', 'girl', 'extremely', 'short', 'accident', 'cause', 'bone', 'stop', 'grow', 'start', 'high', 'school', 'freshman', 'good', 'friend', 'ritsuka', 'class', 'boy', 'yuushin', 'hirose', 'hiyori', 'friend', 'despite', 'fact', 'hiyori', 'happy', 'height', 'constant', 'happy', 'attitude', 'accident', 'pantie', 'class', 'console', 'yuushin', 'start', 'like', 'eventually', 'grow', 'close', '\\n\\n\\n ', 'romance', 'manga', 'unknown', 'tv', 'tokyo', 'unknown', 'episode', 'air', 'tv', 'ribon', 'x', 'oha', 'suta', 'special', 'production', 'i.g', 'hiyokoi', '2012']", 'score': 6.68, 'producer': 'TV Tokyo', 'studio': 'Production I.G', 'licensors': 'UNKNOWN', 'cf_recs': 'Tsubasa to Hotaru (2016), Tsubasa to Hotaru (2015), Uta no☆Prince-sama♪ Movie: Maji Love ST☆RISH Tours, Wheels, Pokemon: Aki no Special, Neon The Animation, Show By Rock!! x Joysound, Toho Cinemas x Pokemon Go, Yuki no Yoru no Yume, Neko Neko Gong Show', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'G - All Ages', 'air_date': 'Dec 2, 2012 to Dec 16, 2012'}),
#  Document(page_content='hiyokoi (japanese: ひよ恋) is a shōjo manga series written and illustrated by moe yukimaru. it is serialized in shueisha\'s monthly shōjo manga magazine ribon, and had been published into fourteen tankōbon volumes. the name of the series is a pun between "hiyoko" (ひよこ, which means "chick") and "koi" (恋, which means "love").\na twenty-two-minute-long movie based on the manga and produced by production i.g. was released in the ribon summer festival on july 30, 2010. the movie was later released on a dvd along with the yumeiro patissiere ova.\n\n\n\nhiyori nishiyama is a 15-year-old girl who is extremely short. after being in an accident that caused her bones to stop growing, she starts going to high school as a freshman, along with her best friend ritsuka. in her class there is a boy whose name is yuushin hirose and becomes hiyori\'s friend (despite the fact that hiyori is not very happy with his height or his constant happy attitude). after an accident where her panties were shown to the class, she is consoled by yuushin and starts liking him, eventually growing closer to him.\n\n\n', metadata={'anime_id': 8768, 'cast': 'Yuuki Sanpei, Kenji Suzumura, Saki Fujita, Nao Tôyama, Ayana Taketatsu', 'episodes': 1, 'genre': 'Romance', 'source': 'Manga', 'Duration': '22 min', 'name': 'Hiyokoi', 'tokens': "['hiyokoi', 'japanese', 'hiyolian', 'shojo', 'manga', 'series', 'write', 'illustrate', 'moe', 'yukimaru', 'serialize', 'shueisha', 'monthly', 'shojo', 'manga', 'magazine', 'ribon', 'publish', 'fourteen', 'tankobon', 'volume', 'series', 'pun', 'hiyoko', 'hiyoko', 'mean', 'chick', 'koi', 'Lian', 'mean', 'love', '\\n', 'minute', 'long', 'movie', 'base', 'manga', 'produce', 'production', 'i.g', 'release', 'ribon', 'summer', 'festival', 'july', '30', '2010', 'movie', 'later', 'release', 'dvd', 'yumeiro', 'patissiere', 'ova', '\\n\\n\\n\\n', 'hiyori', 'nishiyama', '15', 'year', 'old', 'girl', 'extremely', 'short', 'accident', 'cause', 'bone', 'stop', 'grow', 'start', 'high', 'school', 'freshman', 'good', 'friend', 'ritsuka', 'class', 'boy', 'yuushin', 'hirose', 'hiyori', 'friend', 'despite', 'fact', 'hiyori', 'happy', 'height', 'constant', 'happy', 'attitude', 'accident', 'pantie', 'class', 'console', 'yuushin', 'start', 'like', 'eventually', 'grow', 'close', '\\n\\n\\n ', 'romance', 'manga', 'tv', 'mini', 'series', 'base', 'manga', 'shoujo', 'school', 'anime', 'animation', 'shueisha', 'yuuki', 'sanpei', 'kenji', 'suzumura', 'saki', 'fujita', 'nao', 'toyama', 'ayana', 'taketatsu', 'hiyori', 'small', 'timid', 'girl', 'school', 'time', 'year', 'accident', 'leave', 'hospitalize', 'follow', 'struggle', 'social', 'skill', 'try', 'friend', 'maybe', 'little', 'bit', 'production', 'i.g', 'hiyokoi']", 'score': 7.28, 'producer': 'Shueisha', 'studio': 'Production I.G', 'licensors': 'UNKNOWN', 'cf_recs': 'Kimi ni Todoke 2nd Season, Kimi ni Todoke, Kyou, Koi wo Hajimemasu, Kaichou wa Maid-sama!, Hotarubi no Mori e, Kamisama Hajimemashita, Inu x Boku SS, Suki tte Ii na yo., Bokura ga Ita, Itazura na Kiss', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'UNKNOWN', 'air_date': 'Jul 30, 2010'}),
#  Document(page_content='i am here! (japanese: ココにいるよ!, hepburn: koko ni iru yo!) is a japanese shōjo manga series by ema tōyama. the series was serialized in the shōjo manga magazine, nakayoshi. the series ended with 5 volumes released by kodansha under the imprint, kodansha comics.\nit was announced in the new york anime festival 2009 that the series will be licensed in english by del rey manga and the release for the first volume will be november 23, 2010. they titled it "i am here!".\n\n\n== story ==\nthe series centers on a girl named hikage who describes herself as "plain". she is a very shy and insecure child. because of her unassertive attitude and unappreciated beauty, she finds herself constantly ignored by her classmates and has a difficult time making friends at school.\nin the first chapter of the manga, hikage begins middle school, vowing to overcome her loneliness and find companionship. then hinata starts to notice her in the first volume. she is supported in her ambitions by two online friends, black rabbit and mega pig, who read her blog about the sunflower shes been nurturing. a romantic and sad plot soon develops involving hikage and the two most popular boys in her class, hinata and teru, who have more to them than meets the eye.\na few bumps occur along the way as hikage grows closer to hinata, such as bullying and gossip. when she later sticks up for herself she gains recognition and friendliness from the class, but most importantly she obtains confidence in herself.\n\n\n', metadata={'anime_id': 9423, 'cast': 'UNKNOWN', 'episodes': 1, 'genre': 'Slice of Life', 'source': 'Unknown', 'Duration': '2 min', 'name': 'Koko ni Iru', 'tokens': "['japanese', 'kokoniiruyo', 'hepburn', 'koko', 'ni', 'iru', 'yo', 'japanese', 'shojo', 'manga', 'series', 'ema', 'toyama', 'series', 'serialize', 'shojo', 'manga', 'magazine', 'nakayoshi', 'series', 'end', '5', 'volume', 'release', 'kodansha', 'imprint', 'kodansha', 'comic_strip', '\\n', 'announce', 'new', 'york', 'anime', 'festival', '2009', 'series', 'license', 'english', 'del', 'rey', 'manga', 'release', 'volume', 'november', '23', '2010', 'title', '\\n\\n\\n', '=', '=', 'story', '=', '=', '\\n', 'series', 'center', 'girl', 'hikage', 'describe', 'plain', 'shy', 'insecure', 'child', 'unassertive', 'attitude', 'unappreciated', 'beauty', 'find', 'constantly', 'ignore', 'classmate', 'difficult', 'time', 'friend', 'school', '\\n', 'chapter', 'manga', 'hikage', 'begin', 'middle', 'school', 'vow', 'overcome', 'loneliness', 'find', 'companionship', 'hinata', 'start', 'notice', 'volume', 'support', 'ambition', 'online', 'friend', 'black', 'rabbit', 'mega', 'pig', 'read', 'blog', 'sunflower', 's', 'nurture', 'romantic', 'sad', 'plot', 'soon', 'develop', 'involve', 'hikage', 'popular', 'boy', 'class', 'hinata', 'teru', 'meet', 'eye', '\\n', 'bump', 'occur', 'way', 'hikage', 'grow', 'close', 'hinata', 'bullying', 'gossip', 'later', 'stick', 'gain', 'recognition', 'friendliness', 'class', 'importantly', 'obtain', 'confidence', '\\n\\n\\n ', 'slice', 'life', 'unknown', 'unknown', 'mad', 'box', 'unknown', 'short', 'direct', 'yasuo', 'muroi', 'unknown', 'koko', 'ni', 'iru']", 'score': 5.78, 'producer': 'Mad Box', 'studio': 'UNKNOWN', 'licensors': 'UNKNOWN', 'cf_recs': 'From Osaka with Cheer!, Kawaii Cook-san, Manga Ijin Monogatari, Drawing!!, KiyaKiya, Superfluid, Sennen no Yakusoku, Nanchatte!, Collapse Zen, Guitar Shoujo!', 'pop_recs': 'Cowboy Bebop, Escaflowne, GetBackers, Hachimitsu to Clover, Hajime no Ippo, Hikaru no Go, Cowboy Bebop: Tengoku no Tobira, Gantz, Hoshi no Koe, Hunter x Hunter', 'rating': 'G - All Ages', 'air_date': '2010'}),
#  Document(page_content="higehiro, short for higehiro: after being rejected, i shaved and took in a high school runaway (japanese: ひげを剃る。そして女子高生を拾う。, hepburn: hige o soru soshite joshi kōsei o hirou, lit.\u2009' shaved the beard then picked up a high school girl'), is a japanese romantic comedy light novel series written by shimesaba and illustrated by booota. it was serialized online between march 2017 and august 2018 on kadokawa's user-generated novel publishing website kakuyomu. it was later published by kadokawa shoten with five volumes between february 2018 and june 2021 under their kadokawa sneaker bunko imprint. a manga adaptation with art by imaru adachi has been serialized in kadokawa shoten's shōnen manga magazine monthly shōnen ace since november 2018. the light novel is licensed in north america by kadokawa and yen press. the manga is licensed by one peace books. an anime television series adaptation by project no.9 aired from april to june 2021.\n\n\n\nyoung handsome salaryman yoshida had finally gathered up the courage to confess his feelings for his employer and longtime crush airi gotou. sadly though, he ended up rejected and goes out drinking with his co-worker/best friend hashimoto to relieve himself of his sorrows. while heading back home in a drunken state, he meets sayu ogiwara, a teenage high school girl who asks to spend the night with him. he lets her in out of pity and because he is too exhausted to argue, saying to himself that he will chase her out tomorrow. the next day now sobered up, yoshida asks sayu how she ended up at his apartment: she reveals that she had run away from her family and home in hokkaido and has been prostituting herself to random men in exchange for a place to stay. now knowing her backstory, yoshida feeling bad for her finds himself unable to kick her out of his house and their time of living together begins.\n\n\n", metadata={'anime_id': 40938, 'cast': 'Macy Anne Johnson, Kazuyuki Okitsu, Sarah Roach, Natsumi Kawaida, Alex Hom, Kaori Ishihara, Hisako Kanemoto, Jill Harris, Kelsey Maher, Kana Ichinose', 'episodes': 13, 'genre': 'Drama, Romance', 'source': 'Light novel', 'Duration': '23 min per ep', 'name': 'Hige wo Soru. Soshite Joshikousei wo Hirou.', 'tokens': "['higehiro', 'short', 'higehiro', 'reject', 'shave', 'high', 'school', 'runaway', 'japanese', 'higewoTi', 'ru', 'soshiteNu', 'Zi', 'Gao', 'Sheng', 'woshi', 'u.', 'hepburn', 'hige', 'o', 'soru', 'soshite', 'joshi', 'kosei', 'o', 'hirou', 'light', 'shave', 'beard', 'pick', 'high', 'school', 'girl', 'japanese', 'romantic', 'comedy', 'light', 'novel', 'series', 'write', 'shimesaba', 'illustrate', 'booota', 'serialize', 'online', 'march', '2017', 'august', '2018', 'kadokawa', 'user', 'generate', 'novel', 'publishing', 'website', 'kakuyomu', 'later', 'publish', 'kadokawa', 'shoten', 'volume', 'february', '2018', 'june', '2021', 'kadokawa', 'sneaker', 'bunko', 'imprint', 'manga', 'adaptation', 'art', 'imaru', 'adachi', 'serialize', 'kadokawa', 'shoten', 'shonen', 'manga', 'magazine', 'monthly', 'shonen', 'ace', 'november', '2018', 'light', 'novel', 'license', 'north', 'america', 'kadokawa', 'yen', 'press', 'manga', 'license', 'peace', 'book', 'anime', 'television', 'series', 'adaptation', 'project', 'no.9', 'air', 'april', 'june', '2021', '\\n\\n\\n\\n', 'young', 'handsome', 'salaryman', 'yoshida', 'finally', 'gather', 'courage', 'confess', 'feeling', 'employer', 'longtime', 'crush', 'airi', 'gotou', 'sadly', 'end', 'reject', 'drink', 'co', 'worker', 'good', 'friend', 'hashimoto', 'relieve', 'sorrow', 'head', 'home', 'drunken', 'state', 'meet', 'sayu', 'ogiwara', 'teenage', 'high', 'school', 'girl', 'ask', 'spend', 'night', 'let', 'pity', 'exhausted', 'argue', 'chase', 'tomorrow', 'day', 'sober', 'yoshida', 'ask', 'sayu', 'end', 'apartment', 'reveal', 'run', 'away', 'family', 'home', 'hokkaido', 'prostitute', 'random', 'man', 'exchange', 'place', 'stay', 'know', 'backstory', 'yoshida', 'feel', 'bad', 'find', 'unable', 'kick',  ...
