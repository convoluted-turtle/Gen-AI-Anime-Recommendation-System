# %%
import pandas as pd 
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import difflib
import string
from collections import Counter
from tqdm import tqdm
import pickle

# %%
df = pd.read_csv("/Users/justinvhuang/Desktop/CSE-6242-Group-Project/users-score-2023.csv")

# %%
# Open the pickle file in binary read mode and load the pickled object
with open("my_animelist.pkl", 'rb') as f:
    loaded_list = pickle.load(f)

# %%
df = df[df['anime_id'].isin(loaded_list)]

# %%
anime_count = df.groupby('user_id')['anime_id'].count()

user_ids_to_drop = anime_count[anime_count < 10].index

filtered_df = df[~df['user_id'].isin(user_ids_to_drop)]

# %%
user_item_matrix = filtered_df.pivot_table(index='user_id', columns='Anime Title', values='rating')

user_item_matrix = user_item_matrix.fillna(0)

user_ratings_mean = user_item_matrix.mean(axis=1)
user_item_matrix_centered = user_item_matrix.sub(user_ratings_mean, axis=0)

item_similarity = cosine_similarity(user_item_matrix_centered.T)

# %%
def jaccard_similarity(title1, title2):
    title1_tokens = set(title1.lower().translate(str.maketrans('', '', string.punctuation)).split())
    title2_tokens = set(title2.lower().translate(str.maketrans('', '', string.punctuation)).split())
    intersection = len(title1_tokens.intersection(title2_tokens))
    union = len(title1_tokens.union(title2_tokens))
    return intersection / union if union else 0

def item_collaborative_recommender(anime_title, user_item_matrix, item_similarity, top_n=10):
    sim_scores = item_similarity[user_item_matrix.columns.get_loc(anime_title)]
    
    top_indices = np.argsort(sim_scores)[::-1][1:2*top_n+1]  
    
    similar_titles = []
    for idx in top_indices:
        title = user_item_matrix.columns[idx]
        if jaccard_similarity(anime_title, title) < 0.5:  
            similar_titles.append(title)
        if len(similar_titles) >= top_n:
            break
    
    return similar_titles[:top_n]

# %%
recommendations = item_collaborative_recommender('One Piece', user_item_matrix, item_similarity)
print(recommendations)
# Out:
# ['Bleach', 'Naruto', 'Naruto: Shippuuden', 'Fairy Tail', 'Death Note', 'Fullmetal Alchemist', 'Fullmetal Alchemist: Brotherhood', 'Code Geass: Hangyaku no Lelouch', 'Dragon Ball Z', 'Soul Eater']

# %%
# Create an empty dictionary to store recommendations
anime_recommendations_dict = {}

# Group the DataFrame by 'Anime Title' to avoid repeated computations
grouped_df = filtered_df.groupby('Anime Title')

# Loop through unique anime titles with tqdm for a progress bar
for anime_title, anime_group in tqdm(grouped_df, total=len(grouped_df), desc="Processing Anime Titles"):
    # Assuming you want to use the first anime_id for each anime_title (you may need to adjust this logic)
    anime_id = anime_group['anime_id'].iloc[0]
    
    # Generate recommendations for the current anime title
    recommendations = item_collaborative_recommender(anime_title, user_item_matrix, item_similarity)
    
    # Store the recommendations in the dictionary with anime_id as the key
    anime_recommendations_dict[anime_id] = recommendations
# Out:
# Processing Anime Titles: 100%|██████████| 5017/5017 [00:03<00:00, 1339.80it/s]

# %%
anime_recommendations_dict
# Out:
# {52034: ['Bocchi the Rock!',
#   'Chainsaw Man',
#   'Jigokuraku',
#   '86',
#   'Kimetsu no Yaiba: Katanakaji no Sato-hen',
#   'Blue Lock',
#   'Kaguya-sama wa Kokurasetai: Ultra Romantic',
#   'Boku no Hero Academia 6th Season',
#   'Cyberpunk: Edgerunners',
#   'Boku no Kokoro no Yabai Yatsu'],
#  38748: ['After Man',
#   'Hyoutan Suzume',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  2928: ['.hack//G.U. Trilogy',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//Gift',
#   '.hack//Roots',
#   '.hack//Unison',
#   '.hack//Liminality',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//Sign',
#   '6 Angels',
#   "Aquarian Age: Saga II - Don't Forget Me..."],
#  3269: ['.hack//G.U. Returner',
#   '.hack//Roots',
#   '.hack//Liminality',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//Sign',
#   'Blassreiter',
#   'Appleseed Saga Ex Machina',
#   'Air Gear Special'],
#  4469: ['.hack//G.U. Returner',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//Liminality',
#   '.hack//Roots',
#   '"Tokyo"',
#   'Tiger Mask (Movie)',
#   'Hyoutan Suzume',
#   'Drop',
#   'After Man'],
#  454: ['.hack//Unison',
#   '.hack//Liminality',
#   '.hack//G.U. Returner',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//G.U. Trilogy',
#   '.hack//Roots',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//Sign',
#   '3x3 Eyes: Seima Densetsu',
#   '3x3 Eyes'],
#  299: ['.hack//Gift',
#   '.hack//Unison',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//Roots',
#   '.hack//Sign',
#   '.hack//G.U. Returner',
#   '.hack//G.U. Trilogy',
#   '.hack//G.U. Trilogy: Parody Mode',
#   'Aa! Megami-sama! Movie',
#   'Final Fantasy: Unlimited'],
#  873: ['.hack//Tasogare no Udewa Densetsu',
#   '.hack//Sign',
#   '.hack//G.U. Trilogy',
#   '.hack//Liminality',
#   '.hack//G.U. Returner',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//G.U. Trilogy: Parody Mode',
#   'Air Gear',
#   'Black Cat (TV)'],
#  48: ['.hack//Tasogare no Udewa Densetsu',
#   '.hack//Roots',
#   '.hack//Liminality',
#   '.hack//Unison',
#   '.hack//Gift',
#   '.hack//G.U. Trilogy',
#   'Fullmetal Alchemist',
#   'Cowboy Bebop',
#   'FLCL',
#   'Final Fantasy VII: Advent Children'],
#  298: ['.hack//Roots',
#   '.hack//Sign',
#   '.hack//Liminality',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//G.U. Trilogy',
#   '.hack//G.U. Returner',
#   '.hack//G.U. Trilogy: Parody Mode',
#   'Chobits',
#   'D.N.Angel'],
#  1487: ['.hack//Gift',
#   '.hack//Liminality',
#   '.hack//G.U. Returner',
#   '.hack//Sign',
#   '.hack//Roots',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//G.U. Trilogy',
#   '3x3 Eyes: Seima Densetsu',
#   'Aa! Megami-sama! Movie'],
#  11755: ['100-man-nen Chikyuu no Tabi: Bander Book',
#   'GO-GO Tamagotchi!',
#   'Ni-hiki no Sanma (1968)',
#   'Choujin Locke Special',
#   'American Rabbit no Bouken',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Tondemo Senshi Muteking',
#   'Hyoutan Suzume',
#   'TWD Express Rolling Takeoff',
#   'Akuma-kun (Movie)'],
#  1583: ['Time Slip Ichimannen: Prime Rose',
#   'U-Jin Brand',
#   'Shishunki Bishoujo Gattai Robo Z-Mind',
#   'Blue Remains',
#   'Mighty Orbots',
#   'Nido to Mezamenu Komori Uta',
#   'Little Nemo Pilot',
#   'DC Super Heroes vs Taka no Tsumedan',
#   'Choujin Locke Special',
#   'Uchuu Majin Daikengou'],
#  28761: ['Crazy for It',
#   '"Tokyo"',
#   'A Log Day of Timbre',
#   'Beluga',
#   'Sayokyoku',
#   'Commercial War',
#   'Crayon Angel',
#   'Yakusoku',
#   'Yasashii Kinyoubi',
#   'Landscape'],
#  5525: ['D.Gray-man',
#   'Pandora Hearts',
#   'Kuroshitsuji',
#   'Ao no Exorcist',
#   'Nabari no Ou',
#   'Code Geass: Hangyaku no Lelouch',
#   'Code Geass: Hangyaku no Lelouch R2',
#   'Katekyo Hitman Reborn!',
#   'Hakuouki',
#   'Fairy Tail'],
#  1328: ['Landscape',
#   'Land',
#   'Yakusoku',
#   'Usalullaby',
#   'Kuroi Ame ni Utarete',
#   'Chikotan',
#   'Ningyohime',
#   'The Siamese: First Mission',
#   'Kuma ni Kuwarenu Otoko',
#   'A Log Day of Timbre'],
#  6060: ['Shukatsu Kyosokyoku',
#   'Chinpui Specials',
#   'Hyoutan Suzume',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Tsuiseki',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot'],
#  41380: ['Arifureta Shokugyou de Sekai Saikyou',
#   'Choujin Koukousei-tachi wa Isekai demo Yoyuu de Ikinuku you desu!',
#   'Hachi-nan tte, Sore wa Nai deshou!',
#   'Genjitsu Shugi Yuusha no Oukoku Saikenki',
#   'Assassins Pride',
#   'Deatte 5-byou de Battle',
#   'Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu',
#   'Benriya Saitou-san, Isekai ni Iku',
#   'Genjitsu Shugi Yuusha no Oukoku Saikenki Part 2',
#   "Darwin's Game"],
#  44881: ['Deatte 5-byou de Battle',
#   'Benriya Saitou-san, Isekai ni Iku',
#   'Arifureta Shokugyou de Sekai Saikyou',
#   'Choujin Koukousei-tachi wa Isekai demo Yoyuu de Ikinuku you desu!',
#   'Assassins Pride',
#   'Genjitsu Shugi Yuusha no Oukoku Saikenki',
#   'Genjitsu Shugi Yuusha no Oukoku Saikenki Part 2',
#   'Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu',
#   'Bokutachi no Remake',
#   'Hachi-nan tte, Sore wa Nai deshou!'],
#  48976: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  5133: ['Ni-hiki no Sanma (1968)',
#   'Wan Wan Chuushingura',
#   'Zdravstvuite!',
#   'Stitch! Perfect Memory',
#   'Hyoutan Suzume',
#   'TWD Express Rolling Takeoff',
#   'Tsuiseki',
#   'Matsugae wo Musubi',
#   'Omukaisan',
#   'Koisuru Asteroid: KiraKira Zoukan-gou'],
#  1901: ['Crusher Joe',
#   '100-man-nen Chikyuu no Tabi: Bander Book',
#   'Crusher Joe OVA',
#   'Amefuri Kozou',
#   'Cosmo Police Justy',
#   'Assemble Insert',
#   'Andromeda Stories',
#   'Ai City',
#   'Ginga Tansa 2100-nen: Border Planet',
#   'Antique Heart'],
#  48858: ['Memories (Music)',
#   'The iDOLM@STER Cinderella Girls: U149 Recap',
#   'Carol (Music)',
#   'Heroes',
#   'My Song',
#   'After Man',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora'],
#  40679: ['Love All Play',
#   'Bakuten!! Movie',
#   'Actors: Songs Connection',
#   'Opus.COLORs',
#   'After Man',
#   'SD Gundam World Heroes',
#   'Zdravstvuite!',
#   'Kin no Kuni Mizu no Kuni',
#   'Paradise (Music)',
#   'A3! Season Autumn & Winter'],
#  40148: ['World Dai Star',
#   "BanG Dream! Movie: Poppin' Dream!",
#   'BanG Dream! Morfonication',
#   'BanG Dream! 5th Anniversary Animation: CiRCLE Thanks Party!',
#   'BanG Dream! Film Live 2nd Stage',
#   'Gekidol: Actidol Project',
#   'Alice in Deadly School',
#   'Idolls!',
#   "BanG Dream! It's MyGO!!!!!",
#   'Z/X: Code Reunion'],
#  9624: ['Astarotte no Omocha!',
#   'HenSemi (TV)',
#   'A-Channel',
#   'B-gata H-kei',
#   'Denpa Onna to Seishun Otoko',
#   'Acchi Kocchi',
#   'HenSemi',
#   'Amagami SS',
#   'Amagami SS+ Plus',
#   'Oniichan no Koto nanka Zenzen Suki ja Nai n da kara ne!!'],
#  36793: ['Boku no Kanojo ga Majimesugiru Sho-bitch na Ken',
#   'Bokutachi wa Benkyou ga Dekinai',
#   '5-toubun no Hanayome',
#   'Akkun to Kanojo',
#   'Domestic na Kanojo',
#   '5-toubun no Hanayome ∬',
#   'Assassins Pride',
#   'Araburu Kisetsu no Otome-domo yo.',
#   'Bokutachi no Remake',
#   'Beatless'],
#  300: ['Blue Seed',
#   'Armitage III',
#   'Bastard!! Ankoku no Hakaishin',
#   'Bannou Bunka Neko-Musume',
#   'Black Magic M-66',
#   'Bubblegum Crisis',
#   'AD Police',
#   'Dominion',
#   'Appleseed',
#   'Gunnm'],
#  1225: ['AD Police',
#   'Aozora Shoujo-tai',
#   'Black Magic M-66',
#   'Bannou Bunka Neko-Musume',
#   'Blue Seed 2',
#   'Amon Saga',
#   'Bio Hunter',
#   'Bakuretsu Hunters OVA',
#   'Angel Cop',
#   'Bakuen Campus Guardress'],
#  51464: ['Teppen!!!!!!!!!!!!!!!',
#   'Aru Asa Dummy Head Mic ni Natteita Ore-kun no Jinsei',
#   'Warau Arsnotoria Sun!',
#   'Onipan!',
#   'World Dai Star',
#   'Chimimo',
#   'Uchi no Shishou wa Shippo ga Nai',
#   'Irodorimidori',
#   'Kizuna no Allele',
#   'Bonobono: Kumomo no Ki no Koto'],
#  38101: ['Bokutachi wa Benkyou ga Dekinai',
#   'Domestic na Kanojo',
#   'Arifureta Shokugyou de Sekai Saikyou',
#   'Bokutachi no Remake',
#   'Blend S',
#   'Eromanga-sensei',
#   '86',
#   'Aho Girl',
#   'Kaguya-sama wa Kokurasetai: Tensai-tachi no Renai Zunousen',
#   'Darling in the FranXX'],
#  48548: ['Kanojo, Okarishimasu 3rd Season',
#   'Seishun Buta Yarou wa Odekake Sister no Yume wo Minai',
#   'Gridman Universe',
#   'Yukueshirezu',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Spy Kyoushitsu 2nd Season',
#   'Ijiranaide, Nagatoro-san 2nd Attack Mini Anime',
#   "BanG Dream! It's MyGO!!!!!",
#   'Cybot Robocchi',
#   'Battle Spirits: Kakumei no Galette'],
#  39783: ['Bokutachi wa Benkyou ga Dekinai',
#   'Bokutachi no Remake',
#   'Domestic na Kanojo',
#   'Hige wo Soru. Soshite Joshikousei wo Hirou.',
#   'Aharen-san wa Hakarenai',
#   'Kanojo, Okarishimasu',
#   '86',
#   'Fuufu Ijou, Koibito Miman.',
#   'Arifureta Shokugyou de Sekai Saikyou',
#   'Ijiranaide, Nagatoro-san'],
#  2475: ['Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Hyoutan Suzume',
#   'Nido to Mezamenu Komori Uta',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  13971: ['Beluga',
#   'Kamakura',
#   'A Log Day of Timbre',
#   'Maze',
#   'Sayokyoku',
#   'Tatamp',
#   'Yasashii Kinyoubi',
#   'Ninja & Soldier',
#   'Crocotires Traction AAA',
#   'Angel (Special)'],
#  41457: ['Chainsaw Man',
#   'Fumetsu no Anata e',
#   'Akudama Drive',
#   'Dr. Stone',
#   'Bocchi the Rock!',
#   '"Oshi no Ko"',
#   'Boku no Hero Academia 4th Season',
#   'Deca-Dence',
#   'Boku no Hero Academia 5th Season',
#   'Darling in the FranXX'],
#  32998: ['Bungou Stray Dogs',
#   'Bungou Stray Dogs 2nd Season',
#   'ACCA: 13-ku Kansatsu-ka',
#   'Boku dake ga Inai Machi',
#   'Arslan Senki (TV)',
#   'Drifters',
#   'Arslan Senki (TV): Fuujin Ranbu',
#   'Ajin',
#   'Death Parade',
#   'Gangsta.'],
#  320: ['Kite Liberator',
#   'Mezzo Forte',
#   'Blood: The Last Vampire',
#   'Gunnm',
#   'Juubee Ninpuuchou',
#   'Armitage III',
#   'Akira',
#   'Jin-Rou',
#   'Ao no 6-gou',
#   'Appleseed (Movie)'],
#  38712: ['Usalullaby',
#   'Pulsar',
#   'Maku',
#   'Tsuiseki',
#   '"Tokyo"',
#   'Landscape',
#   'Takoyaki Story',
#   'Tama Gura Abayo: Moki Yumokyu Superdeluxe',
#   'Yakusoku',
#   'Hyoutan Suzume'],
#  9776: ['Acchi Kocchi',
#   'Astarotte no Omocha!',
#   'Denpa Onna to Seishun Otoko',
#   'Boku wa Tomodachi ga Sukunai',
#   'Hanasaku Iroha',
#   'Yuru Yuri',
#   'Dog Days',
#   'Ben-To',
#   'Amagami SS',
#   'Ano Natsu de Matteru'],
#  10737: ['Ai Mai! Moe Can Change!',
#   'Morita-san wa Mukuchi',
#   'Anne Happy♪',
#   'Softenni Specials',
#   'Boku no Imouto wa "Osaka Okan"',
#   'Amagami SS OVA',
#   'Acchi Kocchi',
#   'Morita-san wa Mukuchi.',
#   'Morita-san wa Mukuchi. Specials',
#   'Amagi Brilliant Park: Wakuwaku Mini Theater - Rakugaki Backstage'],
#  5447: ['"Tokyo"',
#   'Kuroi Ame ni Utarete',
#   'Matsugae wo Musubi',
#   'Hyoutan Suzume',
#   'Zdravstvuite!',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Wan Wan Chuushingura',
#   'Omukaisan',
#   'Kagirinaki Rakuen',
#   'After Man'],
#  1349: ['Bouken Shounen Shadar',
#   'Hyoutan Suzume',
#   'Shounen Ninja Kaze no Fujimaru',
#   'Video Senshi Lezarion',
#   'Pupa (Movie)',
#   'Uchuusen Sagittarius Pilot',
#   'After Man',
#   'Uchuu Majin Daikengou',
#   'Toshishun',
#   'Tsuiseki'],
#  36039: ['B: The Beginning',
#   'Juushinki Pandora',
#   'ID-0',
#   'Beatless',
#   'Bem',
#   'Blame! Movie',
#   'Chikyuugai Shounen Shoujo',
#   'Hero Mask',
#   'Angolmois: Genkou Kassenki',
#   'Revisions'],
#  40272: ['A3! Season Spring & Summer',
#   'Paradise (Music)',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  39184: ['A3! Season Autumn & Winter',
#   'Actors: Songs Connection',
#   'Opus.COLORs',
#   'Paradise (Music)',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot'],
#  33337: ['91 Days',
#   'Fune wo Amu',
#   'Bungou Stray Dogs 2nd Season',
#   'Bungou Stray Dogs',
#   'Ballroom e Youkoso',
#   'Arslan Senki (TV): Fuujin Ranbu',
#   'Alice to Zouroku',
#   'Amaama to Inazuma',
#   'Arslan Senki (TV)',
#   'Drifters'],
#  1346: ['Bubblegum Crash',
#   'Bubblegum Crisis',
#   'Angel Cop',
#   'Black Magic M-66',
#   'Crusher Joe OVA',
#   'Ai City',
#   'Crusher Joe',
#   'Akai Koudan Zillion: Utahime Yakyoku',
#   'Ankoku Shinwa',
#   'Tokyo Vice'],
#  53787: ['Shoujo Nosferatu',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash'],
#  366: ['AIKa R-16: Virgin Mission',
#   'Najica Dengeki Sakusen',
#   'Burn Up!',
#   '009-1',
#   'AD Police',
#   'Bubblegum Crisis',
#   'Chikyuu Shoujo Arjuna',
#   'A Kite',
#   'Akihabara Dennou-gumi',
#   'Blue Seed'],
#  2163: ['AIKa',
#   'Burn Up!',
#   '6 Angels',
#   'Chou Henshin Cosprayers',
#   '009-1',
#   'Divergence Eve',
#   'Angel',
#   'Najica Dengeki Sakusen',
#   'Aozora Shoujo-tai',
#   "Aquarian Age: Saga II - Don't Forget Me..."],
#  12149: ['Love Live! School Idol Project',
#   'Girls & Panzer',
#   'Choujigen Game Neptune The Animation',
#   "Dog Days'",
#   'Aikatsu!',
#   'Acchi Kocchi',
#   'Black★Rock Shooter (TV)',
#   'A-Channel',
#   'Genei wo Kakeru Taiyou',
#   'Senki Zesshou Symphogear'],
#  49: ['Aa! Megami-sama! Sorezore no Tsubasa',
#   'Aa! Megami-sama! Sorezore no Tsubasa Specials',
#   'Ai Yori Aoshi',
#   'Chobits',
#   'Love Hina Christmas Special: Silent Eve',
#   'Love Hina Again',
#   'Love Hina',
#   'Love Hina Haru Special: Kimi Sakura Chiru Nakare!!',
#   'Ai Yori Aoshi: Enishi - Miyuki',
#   'Azumanga Daiou The Animation'],
#  9611: ['Aa! Megami-sama! Tatakau Tsubasa',
#   'Aa! Megami-sama! Sorezore no Tsubasa Specials',
#   'Aa! Megami-sama! (TV) Specials',
#   'Aa! Megami-sama! Sorezore no Tsubasa',
#   'Ai Tenchi Muyou!',
#   'Ai Yori Aoshi: Enishi - Miyuki',
#   'Busou Renkin: Mahiro no Busou Renkin Kouza',
#   'Alice in Cyberland',
#   'Angel (Special)',
#   'A Log Day of Timbre'],
#  50: ['Aa! Megami-sama! Sorezore no Tsubasa',
#   'Aa! Megami-sama! Tatakau Tsubasa',
#   'Aa! Megami-sama! Sorezore no Tsubasa Specials',
#   'Ai Yori Aoshi',
#   'Chobits',
#   'Love Hina',
#   'Full Metal Panic!',
#   'Onegai☆Teacher',
#   'Full Metal Panic? Fumoffu',
#   'Full Metal Panic! The Second Raid'],
#  1003: ['Aa! Megami-sama! Sorezore no Tsubasa Specials',
#   'Aa! Megami-sama! Tatakau Tsubasa',
#   'Aa! Megami-sama! Sorezore no Tsubasa',
#   'Aa! Megami-sama! Movie',
#   'Aa! Megami-sama! (2011)',
#   'Ai Yori Aoshi: Enishi - Miyuki',
#   'Ai Yori Aoshi',
#   'Chobits Recap',
#   'Amaenaide yo!!',
#   'Love Hina Haru Special: Kimi Sakura Chiru Nakare!!'],
#  304: ['Aa! Megami-sama! Sorezore no Tsubasa',
#   'Aa! Megami-sama! Tatakau Tsubasa',
#   'Aa! Megami-sama! (TV) Specials',
#   'Aa! Megami-sama! Sorezore no Tsubasa Specials',
#   'Ai Yori Aoshi',
#   'Chobits',
#   'Air Movie',
#   'Love Hina Christmas Special: Silent Eve',
#   'Ai Yori Aoshi: Enishi - Miyuki',
#   'Love Hina Haru Special: Kimi Sakura Chiru Nakare!!'],
#  880: ['Aa! Megami-sama! (TV)',
#   'Aa! Megami-sama! (TV) Specials',
#   'Aa! Megami-sama! Movie',
#   'Aa! Megami-sama!',
#   'Aa! Megami-sama! (2011)',
#   'Ai Yori Aoshi',
#   'Amaenaide yo!!',
#   'Chobits',
#   'Girls Bravo: First Season',
#   'Full Metal Panic! The Second Raid'],
#  2198: ['Aa! Megami-sama! Tatakau Tsubasa',
#   'Aa! Megami-sama! (TV) Specials',
#   'Aa! Megami-sama! Movie',
#   'Aa! Megami-sama! (2011)',
#   'Aa! Megami-sama!',
#   'Aa! Megami-sama! (TV)',
#   'Ai Yori Aoshi: Enishi - Miyuki',
#   'Ai Yori Aoshi',
#   'Amaenaide yo!!',
#   'Chobits Recap'],
#  3090: ['Aa! Megami-sama! Sorezore no Tsubasa Specials',
#   'Aa! Megami-sama! (TV) Specials',
#   'Aa! Megami-sama! Movie',
#   'Aa! Megami-sama! (2011)',
#   'Aa! Megami-sama! (TV)',
#   'Ai Yori Aoshi: Enishi - Miyuki',
#   'Ai Yori Aoshi',
#   'Amaenaide yo!!',
#   'Chobits Recap',
#   'Air Movie'],
#  305: ['Uchuu Majin Daikengou',
#   'Nido to Mezamenu Komori Uta',
#   'Hyoutan Suzume',
#   'High School Jingi',
#   'After Man',
#   'Wan Wan Chuushingura',
#   'Omukaisan',
#   'Kagirinaki Rakuen',
#   'Shounen Jack to Mahoutsukai',
#   'TWD Express Rolling Takeoff'],
#  306: ['Azumanga Daiou The Animation',
#   'FLCL',
#   'Heppoko Jikken Animation Excel♥Saga',
#   'Akira',
#   'Cowboy Bebop: Tengoku no Tobira',
#   'Cowboy Bebop',
#   'Dead Leaves',
#   'Genshiken',
#   'Dennou Coil',
#   'Haibane Renmei'],
#  25397: ['Gakusen Toshi Asterisk',
#   'Black Bullet',
#   'Date A Live',
#   'Gakusen Toshi Asterisk 2nd Season',
#   'Campione! Matsurowanu Kamigami to Kamigoroshi no Maou',
#   'Busou Shoujo Machiavellianism',
#   'Juuou Mujin no Fafnir',
#   'Grisaia no Kajitsu',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka',
#   'Amagi Brilliant Park'],
#  5877: ['Nido to Mezamenu Komori Uta',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'DC Super Heroes vs Taka no Tsumedan'],
#  11759: ['Guilty Crown',
#   'Chuunibyou demo Koi ga Shitai!',
#   'Boku wa Tomodachi ga Sukunai',
#   'Another',
#   'Boku wa Tomodachi ga Sukunai Next',
#   'Date A Live',
#   'Angel Beats!',
#   'Akame ga Kill!',
#   'Black Bullet',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka'],
#  12291: ['Chuunibyou demo Koi ga Shitai!',
#   'Boku wa Tomodachi ga Sukunai',
#   'Haiyore! Nyaruko-san',
#   'Ano Natsu de Matteru',
#   'Boku wa Tomodachi ga Sukunai Next',
#   'A-Channel',
#   'Denpa Onna to Seishun Otoko',
#   'GJ-bu',
#   'Binbougami ga!',
#   'Accel World'],
#  311: ['Mahoutsukai Chappy',
#   'Miracle Shoujo Limit-chan',
#   'Sasurai no Taiyou',
#   'Wan Wan Chuushingura',
#   'Uchuu Majin Daikengou',
#   'Ookami Shounen Ken',
#   'Blocker Gundan IV Machine Blaster',
#   'Tamagotchi! Yume Kira Dream',
#   'Kagirinaki Rakuen',
#   'Hyoutan Suzume'],
#  31790: ['Bubuki Buranki',
#   'Comet Lucifer',
#   'Ao no Kanata no Four Rhythm',
#   'Bubuki Buranki: Hoshi no Kyojin',
#   'Divine Gate',
#   'Concrete Revolutio: Choujin Gensou',
#   'ēlDLIVE',
#   'Aquarion Logos',
#   'Bakuon!!',
#   'Chaos Dragon: Sekiryuu Seneki'],
#  38670: ['Paradise (Music)',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'After Man',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  39790: ['Akebi-chan no Sailor-fuku',
#   'Assault Lily: Bouquet',
#   'Asagao to Kase-san.',
#   'Anima Yell!',
#   '22/7',
#   'Koisuru Asteroid',
#   'Do It Yourself!!',
#   '4-nin wa Sorezore Uso wo Tsuku',
#   'Amanchu! Advance',
#   "Birdie Wing: Golf Girls' Story"],
#  35113: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  39590: ['Yi Ren Zhi Xia 5th season',
#   'TWD Express Rolling Takeoff',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'SD Gundam World Heroes',
#   'After Man',
#   'Kouya no Kotobuki Hikoutai Kanzenban',
#   'Omukaisan',
#   'Huckleberry no Bouken (Movie)',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora'],
#  27939: ['"Tokyo"',
#   'After Man',
#   'Wonder',
#   'Zdravstvuite!',
#   'Hyoutan Suzume',
#   'Wan Wan Chuushingura',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Commercial War',
#   'Ni-hiki no Sanma (1968)'],
#  2796: ['Tsuiseki',
#   'Himitsu',
#   'After Man',
#   'Hyoutan Suzume',
#   'Donten',
#   'DC Super Heroes vs Taka no Tsumedan',
#   'Omukaisan',
#   'Pride',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou'],
#  50028: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  33326: ['After Man',
#   'Wonder',
#   'Cherry Blossom (Music)',
#   '"Tokyo"',
#   'Land',
#   'Yakusoku',
#   'Himitsu',
#   'Ningyohime',
#   'Love',
#   'Zdravstvuite!'],
#  244: ['Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Hyoutan Suzume',
#   'GO-GO Tamagotchi!',
#   'Tsuiseki',
#   'Ookami Shounen Ken',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps'],
#  32977: ['A Log Day of Timbre',
#   'Kumo no Ito',
#   '1-gatsu ni wa Christmas',
#   '"Tokyo"',
#   'Columbos',
#   'Hot Minute: Aggretsuko',
#   'Maku',
#   'Africa no Salaryman',
#   'Sakura',
#   'Tokyo Cosmo'],
#  36904: ['Beastars',
#   'BNA',
#   'Devilman: Crybaby',
#   'Carole & Tuesday',
#   'Gaikotsu Shotenin Honda-san',
#   'Gokushufudou',
#   'Eizouken ni wa Te wo Dasu na!',
#   'Boku no Hero Academia 3rd Season',
#   'Boku no Hero Academia 2nd Season',
#   'Dorohedoro'],
#  49520: ['Akebi-chan no Sailor-fuku',
#   'Deaimon',
#   'Boku no Kokoro no Yabai Yatsu',
#   'Bokutachi no Remake',
#   'Benriya Saitou-san, Isekai ni Iku',
#   'Do It Yourself!!',
#   'Bocchi the Rock!',
#   'Akiba Meido Sensou',
#   '5-toubun no Hanayome ∬',
#   'Akuyaku Reijou nanode Last Boss wo Kattemimashita'],
#  37403: ['Ao Ashi',
#   '2.43: Seiin Koukou Danshi Volley-bu',
#   'All Out!!',
#   'Days (TV)',
#   'Blue Lock',
#   'Appare-Ranman!',
#   'Battery',
#   'Captain Tsubasa (2018)',
#   'Shakunetsu Kabaddi',
#   'Arte'],
#  34881: ['Blend S',
#   'Demi-chan wa Kataritai',
#   'Eromanga-sensei',
#   'Gabriel DropOut',
#   'Gamers!',
#   'Asobi Asobase',
#   'Dagashi Kashi',
#   'Boku no Kanojo ga Majimesugiru Sho-bitch na Ken',
#   'Bokutachi wa Benkyou ga Dekinai',
#   '5-toubun no Hanayome'],
#  6535: ['Aos',
#   'Ni-hiki no Sanma',
#   'Pop',
#   'Satsujinkyou Jidai',
#   'The Bathroom',
#   'Gulliver Funtouki',
#   'Commercial War',
#   'Kiseichuu no Ichiya',
#   'Omake',
#   'Carol (Music)'],
#  5053: ['Scoopers',
#   'High School Jingi',
#   'Wan Wan Chuushingura',
#   'Tiger Mask (Movie)',
#   'Shounen Jack to Mahoutsukai',
#   'Hyoutan Suzume',
#   'Ni-hiki no Sanma (1968)',
#   'Zdravstvuite!',
#   'Uchuu Majin Daikengou',
#   'Landscape'],
#  12501: ['"Tokyo"',
#   'Ningyohime',
#   'After Man',
#   'Landscape',
#   'With All Our Hearts',
#   'Land',
#   'Love',
#   'Takoyaki Story',
#   'Himitsu',
#   'Drop'],
#  2554: ['Ai no Wakakusa Monogatari',
#   'Makiba no Shoujo Katri',
#   'Araiguma Rascal',
#   'Andes Shounen Pepero no Bouken',
#   'Minami no Niji no Lucy',
#   'Boukensha: The Man Was from Spain',
#   'Tondemo Nezumi Daikatsuyaku',
#   'Mori no Tonto-tachi',
#   'Mahoutsukai Chappy',
#   'Hoshi no Ko Chobin'],
#  24699: ['Ookami Shounen Ken',
#   'Shounen Ninja Kaze no Fujimaru',
#   'SD Gundam World Heroes',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Kouya no Kotobuki Hikoutai Kanzenban',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps'],
#  1533: ['Kamikaze Kaitou Jeanne',
#   'Attack No.1',
#   'Ojamajo Doremi',
#   'Kaitou Saint Tail',
#   'La Seine no Hoshi',
#   'Futari wa Precure',
#   'Nurse Angel Ririka SOS',
#   'Hikari no Densetsu',
#   'Lady Georgie',
#   'Kojika Monogatari'],
#  53: ['Aa! Megami-sama! (TV)',
#   'Amaenaide yo!!',
#   'Aa! Megami-sama! Sorezore no Tsubasa',
#   'Girls Bravo: First Season',
#   'Chobits',
#   'Onegai☆Teacher',
#   'Love Hina',
#   'Asu no Yoichi!',
#   'Onegai☆Twins',
#   'Air'],
#  3266: ['Aa! Megami-sama! (TV) Specials',
#   'Aa! Megami-sama! Sorezore no Tsubasa Specials',
#   'Aa! Megami-sama! Tatakau Tsubasa',
#   'Aa! Megami-sama! Sorezore no Tsubasa',
#   'Amaenaide yo!!',
#   'Aa! Megami-sama! Movie',
#   'Aa! Megami-sama!',
#   'Chobits Recap',
#   'Aa! Megami-sama! (TV)',
#   'Hanaukyou Maid-tai OVA'],
#  719: ['Haru wo Daite Ita',
#   'Fuyu no Semi',
#   'Boku no Sexual Harassment',
#   'Ikoku Irokoi Romantan',
#   'Fake',
#   'Hyakujitsu no Bara',
#   'Kirepapa.',
#   'Kizuna',
#   'Okane ga Nai',
#   'Papa to Kiss in the Dark'],
#  5784: ['Hyakujitsu no Bara',
#   'Koisuru Boukun',
#   'Ikoku Irokoi Romantan',
#   'Fuyu no Semi',
#   'Haru wo Daite Ita',
#   'Seitokaichou ni Chuukoku',
#   'Boku no Sexual Harassment',
#   'Boku wa Konomama Kaeranai',
#   'Kirepapa.',
#   "Be-Boy Kidnapp'n Idol"],
#  42847: ['Hula Fulla Dance',
#   'Bokura no Yoake',
#   'Ikuta no Kita',
#   'Eien no 831',
#   'Rainbow',
#   'Honekami',
#   'The iDOLM@STER Cinderella Girls: U149 Recap',
#   'Kagirinaki Rakuen',
#   'GO-GO Tamagotchi!',
#   'Fukarai-chou, Tunnel Roji no Otoko'],
#  2548: ['Ai Shoujo Pollyanna Story',
#   'La Seine no Hoshi',
#   'Makiba no Shoujo Katri',
#   'Araiguma Rascal',
#   'Andes Shounen Pepero no Bouken',
#   'Fushigi no Kuni no Alice',
#   'Mori no Tonto-tachi',
#   'Anime Sanjuushi',
#   'Kojika Monogatari',
#   'Minami no Niji no Lucy'],
#  15607: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   "Phantasy Star Online 2: Episode Oracle - Xiao's Report",
#   'Slash'],
#  2041: ['Majokko Tickle',
#   'Ai no Wakakusa Monogatari Specials',
#   'Meiken Lassie',
#   'Nido to Mezamenu Komori Uta',
#   'Cap Kakumei Bottleman DX',
#   "Phantasy Star Online 2: Episode Oracle - Xiao's Report",
#   'Maple Town Monogatari (Movie)',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou'],
#  37204: ['Aikatsu on Parade!',
#   'Aikatsu Stars!',
#   'Aikatsu on Parade! (ONA)',
#   'Aikatsu Stars! Movie',
#   'Aikatsu Planet!',
#   'Aikatsu! Music Award: Minna de Shou wo MoracchaimaShow!',
#   'Battle Spirits: Kakumei no Galette',
#   'Himitsu',
#   'Usagi no Mofy',
#   'Waccha PriMagi!'],
#  42653: ['Aikatsu on Parade! (ONA)',
#   'Himitsu',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Battle Spirits: Kakumei no Galette',
#   'SD Gundam World Heroes',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps'],
#  32717: ['Aikatsu Friends!',
#   'Aikatsu on Parade!',
#   'Aikatsu! Music Award: Minna de Shou wo MoracchaimaShow!',
#   'Aikatsu on Parade! (ONA)',
#   'Aikatsu Planet!',
#   'Battle Spirits: Kakumei no Galette',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Himitsu',
#   'SD Gundam World Heroes',
#   'Kagirinaki Rakuen'],
#  31485: ['Aikatsu! Music Award: Minna de Shou wo MoracchaimaShow!',
#   'Aikatsu on Parade!',
#   'Aikatsu on Parade! (ONA)',
#   'Aikatsu Friends!',
#   'Aikatsu Planet!',
#   'Himitsu',
#   'Kagirinaki Rakuen',
#   'Ikuta no Kita',
#   'Battle Spirits: Kakumei no Galette',
#   'Matsugae wo Musubi'],
#  40266: ['Aikatsu Friends!',
#   'Aikatsu Planet!',
#   'Aikatsu! Music Award: Minna de Shou wo MoracchaimaShow!',
#   'Battle Spirits: Kakumei no Galette',
#   'Himitsu',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'SD Gundam World Heroes',
#   'Omukaisan',
#   'Aikatsu Stars! Movie',
#   'TWD Express Rolling Takeoff'],
#  41555: ['Aikatsu Planet!',
#   'Battle Spirits: Kakumei no Galette',
#   'Himitsu',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot'],
#  15061: ['Aikatsu Stars! Movie',
#   'Aikatsu! Music Award: Minna de Shou wo MoracchaimaShow!',
#   'Aikatsu on Parade!',
#   'Aikatsu on Parade! (ONA)',
#   'Dokidoki! Precure',
#   'Happiness Charge Precure!',
#   'Delicious Party♡Precure',
#   'Waccha PriMagi!',
#   'Battle Spirits: Kakumei no Galette',
#   'Precure Miracle Universe Movie'],
#  30845: ['Aikatsu on Parade! (ONA)',
#   'Aikatsu Stars! Movie',
#   'Aikatsu on Parade!',
#   'Aikatsu Planet!',
#   'Kagirinaki Rakuen',
#   'Battle Spirits: Kakumei no Galette',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Ikuta no Kita'],
#  101: ['Kanon (2006)',
#   'Clannad',
#   'Clannad: After Story',
#   'Chobits',
#   'Elfen Lied',
#   'Angel Beats!',
#   'Byousoku 5 Centimeter',
#   'Fate/stay night',
#   'Code Geass: Hangyaku no Lelouch',
#   'Higurashi no Naku Koro ni'],
#  857: ['Air Gear: Kuro no Hane to Nemuri no Mori - Break on the Sky',
#   'Bleach',
#   'Code Geass: Hangyaku no Lelouch',
#   'D.Gray-man',
#   'Code Geass: Hangyaku no Lelouch R2',
#   'Fullmetal Alchemist',
#   'Death Note',
#   'Fate/stay night',
#   'Full Metal Panic!',
#   'Black Cat (TV)'],
#  3791: ['Air Gear: Kuro no Hane to Nemuri no Mori - Break on the Sky',
#   'Bleach: The Sealed Sword Frenzy',
#   'Asu no Yoichi!',
#   'Bleach Movie 4: Jigoku-hen',
#   'Amaenaide yo!!',
#   'Akikan!',
#   'Beelzebub',
#   'ChäoS;HEAd',
#   'Black Cat (TV)',
#   "Asura Cryin'"],
#  9201: ['Air Gear Special',
#   'Air Gear',
#   'Beelzebub',
#   'Bleach Movie 4: Jigoku-hen',
#   'Break Blade Movie 1: Kakusei no Toki',
#   'Asu no Yoichi!',
#   'Ao no Exorcist',
#   'Ben-To',
#   'Freezing',
#   'Bakuman.'],
#  230: ['Grappler Baki (TV)',
#   'Air Gear',
#   'Buzzer Beater',
#   'Bouken Ou Beet',
#   'Avenger',
#   'Bakuretsu Tenshi',
#   'Battle Programmer Shirase',
#   'Amaenaide yo!!',
#   'Bouken Ou Beet Excellion',
#   'Angel Heart'],
#  713: ['Kanon (2006)',
#   'Clannad',
#   'Chobits',
#   'Clannad: After Story',
#   'Byousoku 5 Centimeter',
#   'Kanon',
#   'Aa! Megami-sama! Movie',
#   'Chrno Crusade',
#   'Chobits Recap',
#   'Kimi ga Nozomu Eien'],
#  21861: ['Beluga',
#   'Crayon Angel',
#   'A Log Day of Timbre',
#   'Yasashii Kinyoubi',
#   'Haru no Shikumi',
#   'Modern No.2',
#   'Monotonous Purgatory',
#   'Aftermath',
#   'Jam',
#   'Kamakura'],
#  2221: ['Hikari no Densetsu',
#   'Attacker You!',
#   'La Seine no Hoshi',
#   'Mori no Tonto-tachi',
#   'Hoshi no Ko Chobin',
#   'Ashita e Attack!',
#   'Cybot Robocchi',
#   'Mahou no Idol Pastel Yumi',
#   'Mahoutsukai Chappy',
#   'Blocker Gundan IV Machine Blaster'],
#  31580: ['Boku dake ga Inai Machi',
#   '91 Days',
#   'Boku no Hero Academia',
#   'Death Parade',
#   'Bungou Stray Dogs',
#   'Boku no Hero Academia 2nd Season',
#   'Akame ga Kill!',
#   'Arslan Senki (TV)',
#   'Ansatsu Kyoushitsu',
#   'Drifters'],
#  32015: ['Ajin Part 3: Shougeki',
#   'Ajin Part 2: Shoutotsu',
#   'Ajin Part 1: Shoudou',
#   'Usuzumizakura: Garo',
#   'Berserk (Music)',
#   'Wonder',
#   'Tiger Mask (Movie)',
#   'Paradise (Music)',
#   'Shoujo Nosferatu',
#   '100-man no Inochi no Ue ni Ore wa Tatteiru Recap'],
#  30868: ['Ajin Part 2: Shoutotsu',
#   'Ajin Part 3: Shougeki',
#   'Ajin OVA',
#   'Shounen Sunday CM: Imawa no Kuni no Alice',
#   'Usuzumizakura: Garo',
#   'Cherry Blossom (Music)',
#   'Paradise (Music)',
#   'Tiger Mask (Movie)',
#   'Tenkuu Senki Shurato Recaps',
#   '100-man no Inochi no Ue ni Ore wa Tatteiru Recap'],
#  30869: ['Ajin Part 3: Shougeki',
#   'Tiger Mask (Movie)',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  30870: ['Ajin Part 2: Shoutotsu',
#   'Tiger Mask (Movie)',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  1485: ['Ie Naki Ko Remy',
#   'Romeo no Aoi Sora',
#   'Arabian Nights: Sindbad no Bouken (TV)',
#   'Nanatsu no Umi no Tico',
#   'Hello! Lady Lynn',
#   'Anime Himitsu no Hanazono',
#   'Tsurikichi Sanpei',
#   'Sango Shou Densetsu: Aoi Umi no Elfie',
#   'Araiguma Rascal',
#   'Hello! Sandybell'],
#  30123: ['Akatsuki no Yona',
#   'Ao Haru Ride',
#   'Aoharu x Kikanjuu',
#   'Charlotte',
#   'Arslan Senki (TV)',
#   'Gekkan Shoujo Nozaki-kun',
#   'Bungou Stray Dogs',
#   'Barakamon',
#   'Ansatsu Kyoushitsu',
#   'Boku dake ga Inai Machi'],
#  31173: ['Akatsuki no Yona',
#   'Ao Haru Ride',
#   'Aoharu x Kikanjuu',
#   'Arslan Senki (TV)',
#   'Akatsuki no Yona OVA',
#   'Arslan Senki (TV): Fuujin Ranbu',
#   'Bungou Stray Dogs',
#   'Amaama to Inazuma',
#   'Bungou Stray Dogs 2nd Season',
#   'Charlotte'],
#  283: ['Ai Shoujo Pollyanna Story',
#   'Ai no Wakakusa Monogatari',
#   'Alps no Shoujo Heidi',
#   'Konnichiwa Anne: Before Green Gables',
#   'Akage no Anne: Green Gables e no Michi',
#   'Anime Sanjuushi',
#   'Araiguma Rascal',
#   'Haha wo Tazunete Sanzenri',
#   'Flanders no Inu',
#   'Fushigi no Kuni no Alice'],
#  8950: ['Ookami Shounen Ken',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Nido to Mezamenu Komori Uta'],
#  4923: ['Hyoutan Suzume',
#   'Uchuusen Sagittarius Pilot',
#   'Toshishun',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Tsuiseki',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot'],
#  2051: ['Hyoutan Suzume',
#   'High School Jingi',
#   'Omukaisan',
#   'Tsuiseki',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja'],
#  2688: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  2689: ['Sango no Umi to Ouji',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'After Man',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  2316: ['Mahoutsukai Chappy',
#   'American Rabbit no Bouken',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  22199: ['Black Bullet',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka',
#   'Boku no Hero Academia',
#   'Aldnoah.Zero',
#   'Boku dake ga Inai Machi',
#   'Charlotte',
#   'Gate: Jieitai Kanochi nite, Kaku Tatakaeri',
#   'Ansatsu Kyoushitsu',
#   'Boku no Hero Academia 2nd Season',
#   'Death Parade'],
#  25013: ['Akagami no Shirayuki-hime',
#   'Akagami no Shirayuki-hime 2nd Season',
#   'Ao Haru Ride',
#   'Gekkan Shoujo Nozaki-kun',
#   'Arslan Senki (TV)',
#   'Barakamon',
#   'Boku dake ga Inai Machi',
#   'Bungou Stray Dogs',
#   'Charlotte',
#   'Ansatsu Kyoushitsu'],
#  30370: ['Akagami no Shirayuki-hime 2nd Season',
#   'Akagami no Shirayuki-hime',
#   'Kamisama Hajimemashita OVA',
#   'Amnesia OVA',
#   'Dance with Devils',
#   'Aoharu x Kikanjuu',
#   'Ao Haru Ride',
#   'Donten ni Warau',
#   'Arslan Senki (TV): Fuujin Ranbu',
#   'Fruits Basket 1st Season'],
#  103: ['Mojakou',
#   'Chou Denji Machine Voltes V',
#   'Kaiketsu Jouki Tanteidan',
#   'Norimono Oukoku BuBu ChaCha',
#   'Ni-hiki no Sanma (1968)',
#   'Matsugae wo Musubi',
#   'The Siamese: First Mission',
#   'Yuru Campâ–³',
#   'Kin no Kuni Mizu no Kuni',
#   'Kimagure Orangeâ˜†Road'],
#  48553: ['Aharen-san wa Hakarenai',
#   'Do It Yourself!!',
#   'Adachi to Shimamura',
#   'Deaimon',
#   'Akiba Meido Sensou',
#   'Assault Lily: Bouquet',
#   '4-nin wa Sorezore Uso wo Tsuku',
#   'Slow Loop',
#   'Boku no Kokoro no Yabai Yatsu',
#   'Bocchi the Rock!'],
#  29513: ['Kaze no Matasaburou (Movie)',
#   'Aftermath',
#   'Utopa',
#   'A Log Day of Timbre',
#   'Baja no Studio',
#   'Ancien to Mahou no Tablet: Mou Hitotsu no Hirune Hime',
#   'Mikagura Gakuen Kumikyoku',
#   'Baja no Studio: Baja no Mita Umi',
#   'Trust',
#   'Yasashii Lion'],
#  52193: ['Akebi-chan no Sailor-fuku',
#   'Do It Yourself!!',
#   'Bocchi the Rock!',
#   "Birdie Wing: Golf Girls' Story",
#   '4-nin wa Sorezore Uso wo Tsuku',
#   'Aharen-san wa Hakarenai',
#   'Edomae Elf',
#   'Assault Lily: Bouquet',
#   'Boku no Kokoro no Yabai Yatsu',
#   'Engage Kiss'],
#  2288: ['After Man',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Fukuro'],
#  5112: ['Asu no Yoichi!',
#   'Asobi ni Iku yo!',
#   "Asura Cryin'",
#   'Goshuushou-sama Ninomiya-kun',
#   'B-gata H-kei',
#   'Amaenaide yo!!',
#   'Kanokon',
#   'ChäoS;HEAd',
#   'Kämpfer',
#   'Princess Lover!'],
#  47: ['Cowboy Bebop',
#   'Koukaku Kidoutai',
#   'FLCL',
#   'Cowboy Bebop: Tengoku no Tobira',
#   'Neon Genesis Evangelion',
#   'Mononoke Hime',
#   'Neon Genesis Evangelion: The End of Evangelion',
#   'Howl no Ugoku Shiro',
#   'Black Lagoon',
#   'Sen to Chihiro no Kamikakushi'],
#  36864: ['Beelzebub-jou no Okinimesu mama.',
#   '3D Kanojo: Real Girl',
#   'Anima Yell!',
#   'Animegataris',
#   'Tachibanakan Triangle',
#   'Yatogame-chan Kansatsu Nikki',
#   'Chuubyou Gekihatsu Boy',
#   'Boku no Tonari ni Ankoku Hakaishin ga Imasu.',
#   '180 Byou de Kimi no Mimi wo Shiawase ni Dekiru ka?',
#   'Joshikausei'],
#  16201: ['Another',
#   'Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.',
#   'Chuunibyou demo Koi ga Shitai!',
#   'Death Billiards',
#   'Boku dake ga Inai Machi',
#   'Watashi ga Motenai no wa Dou Kangaetemo Omaera ga Warui!',
#   'Aoi Bungaku Series',
#   'Barakamon',
#   'Danshi Koukousei no Nichijou',
#   'Death Parade'],
#  41433: ['Deca-Dence',
#   '86',
#   'Appare-Ranman!',
#   "Darwin's Game",
#   '100-man no Inochi no Ue ni Ore wa Tatteiru',
#   'Chainsaw Man',
#   'Babylon',
#   'Enen no Shouboutai',
#   'Fumetsu no Anata e',
#   'Dr. Stone'],
#  19429: ['Black Bullet',
#   'Gokukoku no Brynhildr',
#   'Blade & Soul',
#   'Absolute Duo',
#   'Akame ga Kill!',
#   'Danganronpa: Kibou no Gakuen to Zetsubou no Koukousei The Animation',
#   'Bokura wa Minna Kawai-sou',
#   'Amagi Brilliant Park',
#   'Coppelion',
#   'Date A Live'],
#  8194: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Kaiketsu Zorori no Dragon Taiji',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash'],
#  8226: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  49979: ['Benriya Saitou-san, Isekai ni Iku',
#   'Kanojo ga Koushaku-tei ni Itta Riyuu',
#   'Fantasy Bishoujo Juniku Ojisan to',
#   'Mushikaburi-hime',
#   'Aharen-san wa Hakarenai',
#   '100-man no Inochi no Ue ni Ore wa Tatteiru 2nd Season',
#   '100-man no Inochi no Ue ni Ore wa Tatteiru',
#   'Buddy Daddies',
#   'Dead Mount Death Play',
#   'Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu'],
#  22729: ['Aldnoah.Zero Part 2',
#   'Black Bullet',
#   'Akame ga Kill!',
#   'Fate/stay night: Unlimited Blade Works',
#   'Amagi Brilliant Park',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka',
#   'Charlotte',
#   'Boku dake ga Inai Machi',
#   'Gate: Jieitai Kanochi nite, Kaku Tatakaeri',
#   'Death Parade'],
#  27655: ['Aldnoah.Zero',
#   'Black Bullet',
#   'Akame ga Kill!',
#   'Amagi Brilliant Park',
#   'Charlotte',
#   'Fate/stay night: Unlimited Blade Works',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka',
#   'Gate: Jieitai Kanochi nite, Kaku Tatakaeri',
#   'Arslan Senki (TV)',
#   'Boku dake ga Inai Machi'],
#  1442: ['Tiger Mask (Movie)',
#   'Kaibutsu Gakushou',
#   'Nido to Mezamenu Komori Uta',
#   'Uchuusen Sagittarius Pilot',
#   'Toshishun',
#   'Omukaisan',
#   'Tamagotchi! Yume Kira Dream',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora'],
#  3843: ['Hyoutan Suzume',
#   'Shounen Jack to Mahoutsukai',
#   'TWD Express Rolling Takeoff',
#   'Tsuiseki',
#   'Omukaisan',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'DC Super Heroes vs Taka no Tsumedan',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot'],
#  5330: ['Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Usalullaby',
#   'Pride',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Kagirinaki Rakuen',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja'],
#  33839: ['Memories (Music)',
#   'Carol (Music)',
#   'My Song',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja'],
#  34350: ['Amanchu!',
#   'Amaama to Inazuma',
#   'Anne Happy♪',
#   'Centaur no Nayami',
#   'Animegataris',
#   'Demi-chan wa Kataritai',
#   'Amanchu! Advance',
#   'Clockwork Planet',
#   'Blend S',
#   'Aho Girl'],
#  1177: ['Animation Seisaku Shinkou Kuromi-chan',
#   'Animation Seisaku Shinkou Kuromi-chan 2',
#   'Figure 17: Tsubasa & Hikaru',
#   'Black Magic M-66',
#   'Assemble Insert',
#   '11-nin Iru!',
#   'Brigadoon: Marin to Melan',
#   'Bannou Bunka Neko-Musume',
#   'Boogiepop wa Warawanai',
#   'Abenobashi Mahou☆Shoutengai'],
#  31588: ['Days (TV)',
#   'Battery',
#   'Ahiru no Sora',
#   'Cheer Danshi!!',
#   'Diamond no Ace',
#   'Ao Ashi',
#   '2.43: Seiin Koukou Danshi Volley-bu',
#   'Baby Steps',
#   'Ballroom e Youkoso',
#   'ēlDLIVE'],
#  5270: ['Gundam: Mission to the Rise',
#   'Rainbow',
#   'Black Cat',
#   'Pride',
#   'Crayon Angel',
#   'Tiger Mask (Movie)',
#   'Shounen Ninja Kaze no Fujimaru',
#   'Shounen Jack to Mahoutsukai',
#   'Kujira (1952)',
#   'Hyoutan Suzume'],
#  3549: ['Bamboo Blade',
#   "Asura Cryin'",
#   'Kure-nai',
#   'Aria the Natural',
#   'Crystal Blaze',
#   'Aria the Origination',
#   'Asatte no Houkou.',
#   'Toshokan Sensou',
#   'Bounen no Xamdou',
#   'Wagaya no Oinari-sama.'],
#  2225: ['Akage no Anne',
#   'Ai no Wakakusa Monogatari',
#   'Ai Shoujo Pollyanna Story',
#   'Fushigi no Kuni no Alice',
#   'Calimero',
#   'Haha wo Tazunete Sanzenri',
#   'Hello! Sandybell',
#   'Arabian Nights: Sindbad no Bouken (TV)',
#   'Lady Georgie',
#   'Anime Himitsu no Hanazono'],
#  9547: ['TWD Express Rolling Takeoff',
#   'Omukaisan',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Huckleberry no Bouken (Movie)',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash'],
#  40613: ['Oni: Kamigami Yama no Onari',
#   'Citrus (Music)',
#   'Omukaisan',
#   'Makoto-chan',
#   'After Man',
#   'Zdravstvuite!',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps'],
#  32828: ['Flying Witch',
#   'Demi-chan wa Kataritai',
#   'Amanchu!',
#   'Barakamon',
#   'Blend S',
#   'Dagashi Kashi',
#   'Amagi Brilliant Park',
#   'Aho Girl',
#   'Alice to Zouroku',
#   'Danna ga Nani wo Itteiru ka Wakaranai Ken'],
#  591: ['Asu no Yoichi!',
#   'Girls Bravo: First Season',
#   'Ai Yori Aoshi',
#   'Girls Bravo: Second Season',
#   'Akikan!',
#   'Goshuushou-sama Ninomiya-kun',
#   'Green Green',
#   'Kanokon',
#   'Ichigo 100%',
#   'Aa! Megami-sama! (TV)'],
#  8676: ['Boku wa Tomodachi ga Sukunai',
#   'Bakemonogatari',
#   'Angel Beats!',
#   'B-gata H-kei',
#   'Baka to Test to Shoukanjuu',
#   'Ano Natsu de Matteru',
#   'Clannad: After Story',
#   'Denpa Onna to Seishun Otoko',
#   'Kami nomi zo Shiru Sekai',
#   'Clannad'],
#  9117: ['Ano Natsu de Matteru',
#   'Boku wa Tomodachi ga Sukunai Next',
#   'Boku wa Tomodachi ga Sukunai',
#   'Astarotte no Omocha!',
#   'Ben-To',
#   'Asobi ni Iku yo!',
#   'A-Channel: +A-Channel',
#   'Denpa Onna to Seishun Otoko',
#   'A-Channel',
#   'Campione! Matsurowanu Kamigami to Kamigoroshi no Maou'],
#  11235: ['Ano Natsu de Matteru',
#   'Boku wa Tomodachi ga Sukunai',
#   'Boku wa Tomodachi ga Sukunai Next',
#   'Ben-To',
#   'Chuunibyou demo Koi ga Shitai!',
#   'Denpa Onna to Seishun Otoko',
#   'Campione! Matsurowanu Kamigami to Kamigoroshi no Maou',
#   'Date A Live',
#   'Accel World',
#   'Dakara Boku wa, H ga Dekinai.'],
#  22147: ['Charlotte',
#   'Chuunibyou demo Koi ga Shitai!',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka',
#   'Boku wa Tomodachi ga Sukunai Next',
#   'Chuunibyou demo Koi ga Shitai! Ren',
#   'D-Frag!',
#   'Bokura wa Minna Kawai-sou',
#   'Black Bullet',
#   'Aldnoah.Zero',
#   'Gekkan Shoujo Nozaki-kun'],
#  30056: ['Africa no Salaryman',
#   'Chiruran: Nibun no Ichi Special',
#   'Cinderella',
#   'L/R: Licensed by Royal Special',
#   '100-man no Inochi no Ue ni Ore wa Tatteiru Recap',
#   'Rainbow',
#   'High School Jingi',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'I Wanna Be Your Friend',
#   "Tomorrow's Leaves"],
#  31771: ['Amaama to Inazuma',
#   'Anne Happy♪',
#   'Bakuon!!',
#   'Alice to Zouroku',
#   'Flying Witch',
#   'Comic Girls',
#   'Animegataris',
#   'Centaur no Nayami',
#   'Flip Flappers',
#   'Blend S'],
#  36800: ['Anima Yell!',
#   'Aria the Crepuscolo',
#   'Comic Girls',
#   'Animegataris',
#   'Anne Happy♪',
#   'Adachi to Shimamura',
#   '22/7',
#   'Bakuon!!',
#   'Alice to Zouroku',
#   'Akebi-chan no Sailor-fuku'],
#  49938: ['Misaki no Mayoiga',
#   'Ikuta no Kita',
#   'Ki-No-Ko',
#   'Bakugan: Battle Planet',
#   'Kagirinaki Rakuen',
#   'Donten',
#   'Fukuro',
#   'Cap Kakumei Bottleman DX',
#   'After Man',
#   'Matsugae wo Musubi'],
#  28981: ['Rainbow',
#   'Tsuiseki',
#   'Berserk (Music)',
#   'Ninja & Soldier',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Landscape',
#   'Himitsu',
#   'Heroes',
#   'Hyoutan Suzume',
#   'Cherry Blossom (Music)'],
#  6462: ['Yamatarou Kaeru',
#   'Lunn wa Kaze no Naka',
#   'Midori no Neko',
#   'Stitch! Perfect Memory',
#   'Kagirinaki Rakuen',
#   'Harbor Tale',
#   'Omukaisan',
#   'Sango no Umi to Ouji',
#   'TWD Express Rolling Takeoff',
#   'Shounen Jack to Mahoutsukai'],
#  50983: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  15085: ['Brothers Conflict',
#   'Diabolik Lovers',
#   'Arcana Famiglia',
#   'Kamisama Hajimemashita',
#   'Karneval (TV)',
#   'Kamigami no Asobi',
#   'Free!',
#   'Hiiro no Kakera',
#   'Ao Haru Ride',
#   'Suki tte Ii na yo.'],
#  20655: ['DC Super Heroes vs Taka no Tsumedan',
#   'Donten',
#   'Hyoutan Suzume',
#   'Pride',
#   'The iDOLM@STER Cinderella Girls: U149 Recap',
#   'Parade',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Rainbow',
#   'Koisuru Asteroid: KiraKira Zoukan-gou'],
#  2249: ['Choujikuu Romanesque Samy: Missing 99',
#   'Hare Tokidoki Buta',
#   'Hoshi no Orpheus',
#   'Shounen Jack to Mahoutsukai',
#   'Xabungle Graffiti',
#   'TWD Express Rolling Takeoff',
#   'Hyoutan Suzume',
#   'Nido to Mezamenu Komori Uta',
#   'Tsuiseki',
#   'Wan Wan Chuushingura'],
#  2356: ['Devilman: Tanjou-hen',
#   'Devilman',
#   "Violence Jack: Hell's Wind-hen",
#   'Violence Jack: Jigoku Gai-hen',
#   'Baoh Raihousha',
#   'Amon Saga',
#   'Abashiri Ikka',
#   'Mazinger Z tai Devilman',
#   'Ankoku Shinwa',
#   'Battle Royal High School'],
#  41029: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  34893: ['Ki-No-Ko',
#   'I Wanna Be Your Friend',
#   'Fukuro',
#   "I Think You're a Little Confused",
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot'],
#  3043: ['Andersen Monogatari',
#   'Chibikko Remi to Meiken Kapi',
# ...
#   'TWD Express Rolling Takeoff',
#   'Landscape',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Ookami Shounen Ken'],
#  17513: ['Brothers Conflict',
#   'Amnesia',
#   'Kamigami no Asobi',
#   'Dance with Devils',
#   'Karneval (TV)',
#   'Kamisama Hajimemashita',
#   'DRAMAtical Murder',
#   'Hiiro no Kakera',
#   'Free!',
#   'Makai Ouji: Devils and Realist'],
#  18689: ['Baby Steps',
#   'Haikyuu!!',
#   'Kuroko no Basket 2nd Season',
#   'Days (TV)',
#   'Haikyuu!! Karasuno Koukou vs. Shiratorizawa Gakuen Koukou',
#   'Yowamushi Pedal',
#   'Kuroko no Basket 3rd Season',
#   'Kuroko no Basket',
#   'Hajime no Ippo: Rising',
#   'All Out!!'],
#  32271: ['Dies Irae: To the Ring Reincarnation',
#   'Lord of Vermilion: Guren no Ou',
#   'Yi Ren Zhi Xia 5th season',
#   'Memories (Music)',
#   'Berserk (Music)',
#   'Carol (Music)',
#   'Monster Strike Anime',
#   'Trust',
#   'My Song',
#   'Kouya no Kotobuki Hikoutai Kanzenban'],
#  36515: ['Yi Ren Zhi Xia 5th season',
#   'Kouya no Kotobuki Hikoutai Kanzenban',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  552: ['Digimon Tamers',
#   'Digimon Frontier',
#   'Digimon Adventure: Bokura no War Game!',
#   'Pokemon',
#   'Dragon Ball Z',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Dragon Ball',
#   'Cardcaptor Sakura',
#   'Digimon Savers',
#   'Pokemon Movie 01: Mewtwo no Gyakushuu'],
#  1313: ['Digimon Tamers',
#   'Digimon Frontier',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Savers',
#   'Pokemon',
#   'Dragon Ball Z',
#   'Dragon Ball',
#   'Cardcaptor Sakura',
#   'Dragon Ball GT',
#   'Pokemon Movie 01: Mewtwo no Gyakushuu'],
#  2398: ['Digimon Adventure: Bokura no War Game!',
#   'Digimon Adventure Movie',
#   'Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Digimon Tamers',
#   'Digimon Frontier',
#   'Digimon X-Evolution',
#   'Digimon Adventure',
#   'Digimon Savers',
#   'Digimon Xros Wars'],
#  2961: ['Digimon Adventure: Bokura no War Game!',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Tamers',
#   'Digimon Frontier',
#   'Digimon Savers',
#   'Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Pokemon Movie 02: Maboroshi no Pokemon Lugia Bakutan',
#   'Pokemon Movie 01: Mewtwo no Gyakushuu',
#   'Pokemon Movie 03: Kesshoutou no Teiou Entei'],
#  25687: ['Digimon Adventure tri. 2: Ketsui',
#   'Digimon Adventure tri. 3: Kokuhaku',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Adventure 02',
#   'Digimon Adventure: Last Evolution Kizuna',
#   'Digimon Adventure',
#   'Digimon Adventure Movie',
#   'Digimon Tamers',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Frontier'],
#  32108: ['Digimon Adventure tri. 3: Kokuhaku',
#   'Digimon Adventure tri. 1: Saikai',
#   'Digimon Adventure: Last Evolution Kizuna',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Adventure 02',
#   'Digimon Adventure Movie',
#   'Digimon Adventure',
#   'Digimon Tamers',
#   'Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku'],
#  32551: ['Digimon Adventure tri. 2: Ketsui',
#   'Digimon Adventure tri. 1: Saikai',
#   'Digimon Adventure: Last Evolution Kizuna',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku',
#   'Digimon Adventure 02',
#   'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi',
#   'Digimon Adventure Movie',
#   'Digimon Xros Wars'],
#  2397: ['Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Adventure Movie',
#   'Digimon Adventure 02',
#   'Digimon Adventure',
#   'Digimon Tamers',
#   'Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Digimon Frontier',
#   'Digimon X-Evolution',
#   'Digimon Savers'],
#  38088: ['Digimon Adventure tri. 3: Kokuhaku',
#   'Digimon Ghost Game',
#   'Digimon Adventure tri. 2: Ketsui',
#   'Digimon Ghost Game Recap',
#   'Digimon Universe: Appli Monsters',
#   'Beyblade Burst Sparking',
#   'Beyblade Burst Dynamite Battle',
#   'Memories (Music)',
#   'Beyblade Burst Gachi',
#   'Pokemon (2019): Kami to Yobareshi Arceus'],
#  1132: ['Digimon Tamers',
#   'Digimon Adventure 02',
#   'Digimon Adventure',
#   'Digimon Savers',
#   'Digimon Adventure Movie',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Digimon X-Evolution'],
#  49515: ['Usagi no Mofy',
#   'SD Gundam World Heroes',
#   'Stitch! Perfect Memory',
#   'Kagirinaki Rakuen',
#   'Paradise (Music)',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Yi Ren Zhi Xia 5th season',
#   'Omukaisan',
#   'Battle Spirits: Kakumei no Galette'],
#  51780: ['Stitch! Perfect Memory',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love'],
#  859: ['Digimon Frontier',
#   'Digimon Tamers',
#   'Digimon Adventure 02',
#   'Digimon Xros Wars',
#   'Digimon X-Evolution',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Adventure',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku'],
#  874: ['Digimon Adventure 02',
#   'Digimon Frontier',
#   'Digimon Adventure',
#   'Digimon Adventure Movie',
#   'Digimon Savers',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Dragon Ball Z',
#   'Pokemon'],
#  3032: ['Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon X-Evolution',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Savers',
#   'Digimon Adventure Movie',
#   'Digimon Tamers',
#   'Digimon Frontier',
#   'Digimon Xros Wars',
#   'Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku'],
#  3033: ['Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon X-Evolution',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Savers',
#   'Digimon Adventure Movie',
#   'Digimon Frontier',
#   'Digimon Xros Wars',
#   'Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku',
#   'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi'],
#  33314: ['Digimon Ghost Game Recap',
#   'SD Gundam World Heroes',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Battle Spirits: Kakumei no Galette',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Stitch! Perfect Memory',
#   'Cap Kakumei Bottleman',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Yi Ren Zhi Xia 5th season'],
#  2123: ['Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Savers',
#   'Digimon Adventure: Bokura no War Game!',
#   'Digimon Xros Wars',
#   'Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku',
#   'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi',
#   'Digimon Frontier',
#   'Digimon Adventure Movie'],
#  8624: ['Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku',
#   'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi',
#   'Digimon Savers',
#   'Digimon X-Evolution',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Frontier',
#   'Digimon Universe: Appli Monsters',
#   'Digimon Adventure 02: Diablomon no Gyakushuu',
#   'Digimon Tamers'],
#  10444: ['Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi',
#   'Digimon Xros Wars',
#   'Digimon Universe: Appli Monsters',
#   'Digimon Savers',
#   'Digimon X-Evolution',
#   'Digimon Ghost Game',
#   'Digimon Tamers: Boukensha-tachi no Tatakai',
#   'Digimon Tamers: Bousou Digimon Tokkyuu',
#   'Digimon Ghost Game Recap',
#   'Metal Fight Beyblade Zero G'],
#  11385: ['Digimon Xros Wars: Aku no Death General to Nanatsu no Oukoku',
#   'Digimon Xros Wars',
#   'Digimon Universe: Appli Monsters',
#   'Digimon Ghost Game Recap',
#   'Metal Fight Beyblade Zero G Specials',
#   'Yi Ren Zhi Xia 5th season',
#   'Metal Fight Beyblade Zero G',
#   'Ningyohime',
#   'Shounen Ninja Kaze no Fujimaru',
#   'Stitch! Perfect Memory'],
#  2983: ['Black Cat',
#   'Scoopers',
#   'DC Super Heroes vs Taka no Tsumedan',
#   'TWD Express Rolling Takeoff',
#   'Nido to Mezamenu Komori Uta',
#   'Omukaisan',
#   'Hyoutan Suzume',
#   'Donten',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Tsuiseki'],
#  31163: ['Hai to Gensou no Grimgar',
#   'Gate: Jieitai Kanochi nite, Kaku Tatakaeri',
#   'Charlotte',
#   'Gangsta.',
#   'Drifters',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka',
#   'Boku dake ga Inai Machi',
#   'Black Bullet',
#   'Dagashi Kashi',
#   'Aldnoah.Zero'],
#  3499: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  424: ['Dirty Pair: Bouryaku no 005-bin',
#   'Crusher Joe OVA',
#   'Rhea Gall Force',
#   'Cleopatra D.C.',
#   'Gall Force: Chikyuu Shou',
#   'Gall Force: New Era',
#   'Mujigen Hunter Fandora',
#   'Relic Armor Legaciam',
#   'Choujikuu Romanesque Samy: Missing 99',
#   'Idol Bouei-tai Hummingbird'],
#  1802: ['Dirty Pair: Bouryaku no 005-bin',
#   'Dirty Pair: The Movie',
#   'GO-GO Tamagotchi!',
#   'The Siamese: First Mission',
#   'Uchuu Majin Daikengou',
#   'Ookami Shounen Ken',
#   'Pride',
#   'Mechakko Dotakon',
#   'Omukaisan',
#   'Ni-hiki no Sanma (1968)'],
#  4200: ['Dirty Pair: Bouryaku no 005-bin',
#   'Dirty Pair: The Movie',
#   'Pupa (Movie)',
#   'Zdravstvuite!',
#   'Mechakko Dotakon',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Landscape',
#   'Ijiranaide, Nagatoro-san 2nd Attack Mini Anime',
#   'Matsugae wo Musubi',
#   'Nora'],
#  1795: ['Dirty Pair: The Movie',
#   'Dirty Pair OVA',
#   'Scoopers',
#   'The Siamese: First Mission',
#   'Uchuu Majin Daikengou',
#   'Mujigen Hunter Fandora',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Zdravstvuite!',
#   'Relic Armor Legaciam',
#   'Landscape'],
#  1796: ['Dirty Pair: Bouryaku no 005-bin',
#   'Dirty Pair OVA',
#   'Crusher Joe OVA',
#   'Dirty Pair Flash',
#   'Kenritsu Chikyuu Boueigun',
#   'Rhea Gall Force',
#   'Crusher Joe',
#   'Relic Armor Legaciam',
#   'Idol Bouei-tai Hummingbird',
#   'Gall Force: Chikyuu Shou'],
#  294: ['Sei Michaela Gakuen Hyouryuuki II',
#   'Metal Fight Beyblade Zero G Specials',
#   'Pride',
#   'Nido to Mezamenu Komori Uta',
#   'Omukaisan',
#   'Pulsar',
#   'Bakugan: Armored Alliance',
#   'The Siamese: First Mission',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou'],
#  31710: ['Bubuki Buranki',
#   'Endride',
#   'Comet Lucifer',
#   'Luck & Logic',
#   'Chaos Dragon: Sekiryuu Seneki',
#   'Active Raid: Kidou Kyoushuushitsu Dai Hachi Gakari',
#   'Big Order (TV)',
#   'Gunslinger Stratos The Animation',
#   'Dimension W',
#   'Seisen Cerberus: Ryuukoku no Fatalités'],
#  48542: ['Akebi-chan no Sailor-fuku',
#   'Deaimon',
#   'Edomae Elf',
#   'Akiba Meido Sensou',
#   'Slow Loop',
#   '4-nin wa Sorezore Uso wo Tsuku',
#   'Bocchi the Rock!',
#   'Healer Girl',
#   'Aharen-san wa Hakarenai',
#   'Yama no Susume: Next Summit'],
#  6797: ['Karo to Piyobupt: Ouchi',
#   'Kipling Jr.',
#   "Kid's Castle",
#   'Karo to Piyobupt: Sandwich',
#   'Karo to Piyobupt: Ame no Hi',
#   'Tsuiseki',
#   'Omake',
#   'Commercial War',
#   'Landscape',
#   'Chinpui Specials'],
#  4693: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Slash',
#   'Haha wo Tazunete Sanzenri (Special)'],
#  10155: ['Dragon Crisis!',
#   'Astarotte no Omocha!',
#   'Hidan no Aria',
#   'IS: Infinite Stratos',
#   'Boku wa Tomodachi ga Sukunai',
#   'Denpa Onna to Seishun Otoko',
#   'Campione! Matsurowanu Kamigami to Kamigoroshi no Maou',
#   'Date A Live',
#   'Ben-To',
#   'Hoshizora e Kakaru Hashi'],
#  11783: ['Campione! Matsurowanu Kamigami to Kamigoroshi no Maou',
#   'Date A Live',
#   'Haiyore! Nyaruko-san',
#   'Astarotte no Omocha!',
#   'Dakara Boku wa, H ga Dekinai.',
#   'Haiyore! Nyaruko-san W',
#   'Boku wa Tomodachi ga Sukunai Next',
#   'Dragon Crisis!',
#   'Hagure Yuusha no Aesthetica',
#   'Acchi Kocchi'],
#  2318: ['Tiger Mask (Movie)',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Ookami Shounen Ken',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Uchuusen Sagittarius Pilot',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja'],
#  42571: ['Otona no Bouguya-san II',
#   'The iDOLM@STER Cinderella Girls: U149 Recap',
#   'Memories (Music)',
#   'Shoujo Nosferatu',
#   'Carol (Music)',
#   'My Song',
#   'Rebirth',
#   'Rainbow',
#   "I Think You're a Little Confused",
#   'Omukaisan'],
#  5593: ['Durarara!!',
#   'Aoi Bungaku Series',
#   'Kuroshitsuji',
#   'Devil May Cry',
#   'Hakuouki',
#   '07-Ghost',
#   'D.Gray-man',
#   'Detroit Metal City',
#   'Cencoroll',
#   'Baccano!'],
#  16419: ['Happiness Charge Precure!',
#   'Smile Precure!',
#   'Yes! Precure 5 GoGo!',
#   'Delicious Party♡Precure',
#   'Heartcatch Precure!',
#   'Tropical-Rouge! Precure',
#   'Kirakira☆Precure A La Mode Movie: Paritto! Omoide no Mille-Feuille!',
#   'Yes! Precure 5',
#   'Precure Miracle Universe Movie',
#   'Aikatsu Friends!'],
#  5618: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Uchuusen Sagittarius Pilot',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Nido to Mezamenu Komori Uta'],
#  40623: ['Otona no Bouguya-san II',
#   'Z/X: Code Reunion',
#   'Memories (Music)',
#   'Shikizakura',
#   'Carol (Music)',
#   'Hatena☆Illusion',
#   'Rebirth',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'My Song',
#   'The iDOLM@STER Cinderella Girls: U149 Recap'],
#  42803: ['Memories (Music)',
#   'Carol (Music)',
#   'The iDOLM@STER Cinderella Girls: U149 Recap',
#   'My Song',
#   'Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot'],
#  46604: ['TWD Express Rolling Takeoff',
#   'The Siamese: First Mission',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu Movie',
#   'Omukaisan',
#   'SD Gundam World Heroes',
#   "I Think You're a Little Confused",
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Shoujo Nosferatu',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps'],
#  37982: ['5-toubun no Hanayome',
#   '5-toubun no Hanayome ∬',
#   'Bokutachi wa Benkyou ga Dekinai',
#   'Kanojo, Okarishimasu',
#   'Hige wo Soru. Soshite Joshikousei wo Hirou.',
#   'Bokutachi no Remake',
#   '3D Kanojo: Real Girl',
#   'Darling in the FranXX',
#   'Araburu Kisetsu no Otome-domo yo.',
#   'Eromanga-sensei'],
#  1151: ['New Dominion Tank Police',
#   'Black Magic M-66',
#   'Bubblegum Crisis',
#   'Bubblegum Crash',
#   'AD Police',
#   'Project A-Ko',
#   'Dirty Pair: The Movie',
#   'Dirty Pair: Bouryaku no 005-bin',
#   'Dirty Pair',
#   'Cyber City Oedo 808'],
#  39560: ['Omukaisan',
#   'TWD Express Rolling Takeoff',
#   'Koisuru Asteroid: KiraKira Zoukan-gou',
#   'Pride',
#   'The Aurora: Umi no Aurora',
#   'Tenkuu Senki Shurato Recaps',
#   'Uchuu Kaizoku Mito no Daibouken Pilot',
#   'Ooyukiumi no Kaina: Hoshi no Kenja',
#   'Love',
#   'Parade'],
#  ...}

# %%
import pickle

# File path to save the dictionary
file_path = "anime_recommendations_item_knn_CF.pkl"

# Save the dictionary using pickle
with open(file_path, 'wb') as f:
    pickle.dump(anime_recommendations_dict, f)
