# %%
import pandas as pd
import numpy as np 
from tqdm import tqdm
import pickle

# %%
df = pd.read_csv("/Users/justinvhuang/Desktop/CSE-6242-Group-Project/users-score-2023.csv")

# %%
df2 = pd.read_json("/Users/justinvhuang/Desktop/CSE-6242-Group-Project/fin_anime_dfv2.json")

# %%
anime_list = df2['anime_id'].tolist()

# %%
filtered_df = df[df['anime_id'].isin(anime_list)]

# %%
# Get unique anime and user IDs
anime_ids = filtered_df['anime_id'].unique()
user_ids = filtered_df['user_id'].unique()

# Create a dictionary to map anime IDs to indices
anime_id_to_index = {anime_id: index for index, anime_id in enumerate(anime_ids)}

# %%
class ThompsonSamplingPopularity:
    def __init__(self, num_anime):
        self.num_anime = num_anime
        self.alpha = np.ones(num_anime)  
        self.beta = np.ones(num_anime)   

    def update_parameters(self, user_ratings, user_interactions):
        self.alpha += user_ratings
        self.beta += user_interactions - user_ratings

    def recommend_top_popular_anime(self, anime_popularity, num_recommendations=50):
        sorted_anime_indices = np.argsort(anime_popularity)[::-1]  
        return sorted_anime_indices[:num_recommendations]

    def recommend_anime(self, user_ratings, user_interactions, anime_popularity):
        self.update_parameters(user_ratings, user_interactions)

        expected_theta = self.alpha / (self.alpha + self.beta)
        adjusted_theta = expected_theta * anime_popularity

        return self.recommend_top_popular_anime(adjusted_theta)

# %%
#Calculate popularity of each anime based on the total number of interactions
anime_interactions = filtered_df.groupby('anime_id')['user_id'].count().sort_values(ascending=False)
anime_popularity = anime_interactions.values / anime_interactions.values.sum()

# Initialize Thompson Sampling with popularity
thompson_sampling = ThompsonSamplingPopularity(len(anime_ids))

# %%
# Initialize an empty set to store unique recommended anime IDs
all_recommended_anime_ids = set()

# Iterate through user IDs with tqdm for progress tracking
for user_id in tqdm(user_ids, desc="Processing users"):
    user_data =filtered_df[filtered_df['user_id'] == user_id]
    user_ratings = np.zeros(len(anime_ids))
    user_interactions = np.zeros(len(anime_ids))

    for _, row in user_data.iterrows():
        anime_index = anime_id_to_index[row['anime_id']]
        user_ratings[anime_index] += row['rating']
        user_interactions[anime_index] += 1

    recommended_anime_indices = thompson_sampling.recommend_anime(user_ratings, user_interactions, anime_popularity)
    recommended_anime_ids = [anime_ids[index] for index in recommended_anime_indices]

    # Add recommended anime IDs to the set
    all_recommended_anime_ids.update(recommended_anime_ids)

# Convert the set to a list
all_recommended_anime_ids = list(all_recommended_anime_ids)
# Out:
# Processing users: 100%|██████████| 265292/265292 [46:59<00:00, 94.09it/s]

# %%
pop_recs1 = all_recommended_anime_ids[0:15]
len(pop_recs1)
# Out:
# 15

# %%
df3 = df2[df2['anime_id'].isin(pop_recs1)].drop_duplicates('Genres')
# Filter and drop rows containing 'Ecchi' and 'Hentai'
filtered_df = df3[~df3['Genres'].str.contains('Ecchi|Hentai')]

# %%
popular_dict_10 = filtered_df.sort_values("Favorites",ascending = False).head(15)

# %%
popular_dict_10
# Out:
#                    anime_Rating anime_Score  \
# 4641                    UNKNOWN        8.75
# 4885                    UNKNOWN        8.76
# 6931                    UNKNOWN        8.41
# 4877                    UNKNOWN         8.0
# 6657                    UNKNOWN        6.99
# 4951                    UNKNOWN        8.08
# 6398                    UNKNOWN        8.38
# 4815  PG-13 - Teens 13 or older        7.58
# 6904                    UNKNOWN        7.12
# 4741                    UNKNOWN        7.06
#
#                                          anime_Synopsis  \
# 4641  Crime is timeless. By the year 2071, humanity ...
# 4885  In his father's absence, teenager Ippo Makunou...
# 6931  Hunters are specialized in a wide variety of f...
# 4877  Yuuta Takemoto, a sophomore at an arts college...
# 6657  Thought your life was bad? Sometimes, death is...
# 4951  While searching through his grandfather's atti...
# 6398  Another day, another bounty—such is the life o...
# 4815  Mido Ban and Amano Ginji are known as the Get ...
# 6904  It is the year 2046, Noboru Terao and Mikako N...
# 4741  Hitomi Kanzaki is in a very depressed mood. Sh...
#
#                                                    plot  \
# 4641  Cowboy Bebop (Japanese: カウボーイビバップ, Hepburn: Ka...
# 4885  Hajime no Ippo (はじめの一歩, lit. "The First Step")...
# 6931  Hunter × Hunter (stylized as HUNTER×HUNTER and...
# 4877  Honey and Clover (Japanese: ハチミツとクローバー, Hepbur...
# 6657  Gantz (stylized in all caps) is a Japanese man...
# 4951  Hikaru no Go (ヒカルの碁, lit. Hikaru's Go) is a Ja...
# 6398  Cowboy Bebop (Japanese: カウボーイビバップ, Hepburn: Ka...
# 4815  GetBackers (Japanese: ゲットバッカーズ -奪還屋-, Hepburn:...
# 6904  The classical Japanese language (文語 bungo, "li...
# 4741  The Vision of Escaflowne (Japanese: 天空のエスカフローネ...
#
#                                         Producers  \
# 4641                                Bandai Visual
# 4885                                          VAP
# 6931                                      Fuji TV
# 4877  Dentsu, Genco, Fuji TV, Asmik Ace, Shueisha
# 6657                                      Fuji TV
# 4951                TV Tokyo, Dentsu, Dream Force
# 6398                       Sunrise, Bandai Visual
# 4815         TBS, Kodansha, Rondo Robe, Rakuonsha
# 6904                                      UNKNOWN
# 4741                                 Atelier Musa
#
#                                      Licensors           Studios  \
# 4641          Funimation, Bandai Entertainment           Sunrise
# 4885  Discotek Media, Geneon Entertainment USA          Madhouse
# 6931                                 VIZ Media  Nippon Animation
# 4877                 VIZ Media, Discotek Media         J.C.Staff
# 6657                     ADV Films, Funimation             Gonzo
# 4951                                 VIZ Media           Pierrot
# 6398               Sony Pictures Entertainment             Bones
# 4815               ADV Films, Sentai Filmworks       Studio Deen
# 6904                          ADV Films, GKIDS  CoMix Wave Films
# 4741          Funimation, Bandai Entertainment    Bones, Sunrise
#
#                                               Image URL Episodes  \
# 4641  https://cdn.myanimelist.net/images/anime/4/196...     26.0
# 4885  https://cdn.myanimelist.net/images/anime/4/863...     75.0
# 6931  https://cdn.myanimelist.net/images/anime/1305/...     62.0
# 4877  https://cdn.myanimelist.net/images/anime/1301/...     24.0
# 6657  https://cdn.myanimelist.net/images/anime/13/59...     13.0
# 4951  https://cdn.myanimelist.net/images/anime/12/78...     75.0
# 6398  https://cdn.myanimelist.net/images/anime/1439/...      1.0
# 4815  https://cdn.myanimelist.net/images/anime/4/754...     49.0
# 6904  https://cdn.myanimelist.net/images/anime/1980/...      1.0
# 4741  https://cdn.myanimelist.net/images/anime/1539/...      1.0
#
#                                           Genres  ... Favorites  \
# 4641               Action, Award Winning, Sci-Fi  ...     78525
# 4885                                      Sports  ...     20143
# 6931                  Action, Adventure, Fantasy  ...     10442
# 4877                      Comedy, Drama, Romance  ...      4136
# 6657               Action, Drama, Horror, Sci-Fi  ...      2360
# 4951                 Comedy, Drama, Supernatural  ...      2341
# 6398                              Action, Sci-Fi  ...      1448
# 4815               Action, Mystery, Supernatural  ...       867
# 6904       Award Winning, Drama, Romance, Sci-Fi  ...       528
# 4741  Adventure, Drama, Fantasy, Romance, Sci-Fi  ...       199
#
#                              Aired  Members       Duration  \
# 4641   Apr 3, 1998 to Apr 24, 1999  1771505  24 min per ep
# 4885   Oct 4, 2000 to Mar 27, 2002   546859  23 min per ep
# 6931  Oct 16, 1999 to Mar 31, 2001   564771  23 min per ep
# 4877  Apr 15, 2005 to Sep 27, 2005   260166  23 min per ep
# 6657  Apr 13, 2004 to Jun 22, 2004   347630  22 min per ep
# 4951  Oct 10, 2001 to Mar 26, 2003   133599  23 min per ep
# 6398                   Sep 1, 2001   360978    1 hr 55 min
# 4815   Oct 5, 2002 to Sep 20, 2003   119875  24 min per ep
# 6904                   Feb 2, 2002   152141         24 min
# 4741                  Jun 24, 2000    67624    1 hr 37 min
#
#                                                    text anime_id  \
# 4641  Cowboy Bebop (Japanese: カウボーイビバップ, Hepburn: Ka...        1
# 4885  Hajime no Ippo (はじめの一歩, lit. "The First Step")...      263
# 6931  Hunter × Hunter (stylized as HUNTER×HUNTER and...      136
# 4877  Honey and Clover (Japanese: ハチミツとクローバー, Hepbur...       16
# 6657  Gantz (stylized in all caps) is a Japanese man...      384
# 4951  Hikaru no Go (ヒカルの碁, lit. Hikaru's Go) is a Ja...      135
# 6398  Cowboy Bebop (Japanese: カウボーイビバップ, Hepburn: Ka...        5
# 4815  GetBackers (Japanese: ゲットバッカーズ -奪還屋-, Hepburn:...      132
# 6904  The classical Japanese language (文語 bungo, "li...      256
# 4741  The Vision of Escaflowne (Japanese: 天空のエスカフローネ...      393
#
#                                                  tokens  \
# 4641  ['cowboy', 'bebop', 'japanese', 'kaubo', 'ibib...
# 4885  ['hajime', 'ippo', 'hazimenoYi', 'Bu', 'light'...
# 6931  ['hunter', 'x', 'hunter', 'stylize', 'hunterxh...
# 4877  ['honey', 'clover', 'japanese', 'hachimitsutok...
# 6657  ['gantz', 'stylize', 'cap', 'japanese', 'manga...
# 4951  ['hikaru', 'hikarunoqi', 'light', 'hikaru', 'j...
# 6398  ['cowboy', 'bebop', 'japanese', 'kaubo', 'ibib...
# 4815  ['getbacker', 'japanese', 'getsutobatsuka', 'z...
# 6904  ['classical', 'japanese', 'language', 'Wen', '...
# 4741  ['vision', 'escaflowne', 'japanese', 'Tian', '...
#
#                                  Name  \
# 4641                     Cowboy Bebop
# 4885                   Hajime no Ippo
# 6931                  Hunter x Hunter
# 4877             Hachimitsu to Clover
# 6657                            Gantz
# 4951                     Hikaru no Go
# 6398  Cowboy Bebop: Tengoku no Tobira
# 4815                       GetBackers
# 6904                     Hoshi no Koe
# 4741                       Escaflowne
#
#                                                 image_y  \
# 4641  https://cdn.myanimelist.net/images/anime/4/196...
# 4885  https://cdn.myanimelist.net/images/anime/4/863...
# 6931  https://cdn.myanimelist.net/images/anime/1305/...
# 4877  https://cdn.myanimelist.net/images/anime/1301/...
# 6657  https://cdn.myanimelist.net/images/anime/13/59...
# 4951  https://cdn.myanimelist.net/images/anime/12/78...
# 6398  https://cdn.myanimelist.net/images/anime/1439/...
# 4815  https://cdn.myanimelist.net/images/anime/1056/...
# 6904  https://cdn.myanimelist.net/images/anime/1980/...
# 4741  https://cdn.myanimelist.net/images/anime/1539/...
#
#                            imdb_name_basics_primaryName
# 4641  Isshin Chiba, Kevin Seymour, Hajime Yatate, Un...
# 4885  Ichirô Nagai, Kôhei Kiyasu, Paul St. Peter, Ke...
# 6931  Junko Takeuchi, Annika Odegard, Carol-Anne Day...
# 4877  Sam Riegel, Tomokazu Sugita, Hiroshi Kamiya, C...
# 6657  Hiroshi Kamiya, John Gremillion, Chris Patton,...
# 4951  Tomoko Kawakami, Sam Vincent, Brad Swaile, Mat...
# 6398  Melissa Fahn, Tensai Okamura, Nicholas Guest, ...
# 4815  Kelly Dealyn, Darren Pleavin, Matt Hislope, Sh...
# 6904  Yoshihiro Hagiwara, Tenmon, Mika Shinohara, Su...
# 4741  Kazuki Akane, Tomokazu Seki, Kazuki Sekine, Jô...
#
# [10 rows x 21 columns]

# %%
popular_dict = df[df['anime_id'].isin(all_recommended_anime_ids)].drop_duplicates('anime_id')[['anime_id', 'Anime Title']].to_dict(orient='records')

# %%
popular_dict_10 = filtered_df[filtered_df['anime_id'].isin(all_recommended_anime_ids)].drop_duplicates('anime_id')[['anime_id', 'Name']].to_dict(orient='records')

# %%
file_path = "popular_dict.pkl"

# Open the file in binary write mode and save the list using pickle.dump()
with open(file_path, 'wb') as f:
    pickle.dump(popular_dict, f)

# %%
file_path = "popular_dict_10.pkl"

# Open the file in binary write mode and save the list using pickle.dump()
with open(file_path, 'wb') as f:
    pickle.dump(popular_dict_10, f)

# %%
popular_dict_10
# Out:
# [{'anime_id': 1, 'Name': 'Cowboy Bebop'},
#  {'anime_id': 393, 'Name': 'Escaflowne'},
#  {'anime_id': 132, 'Name': 'GetBackers'},
#  {'anime_id': 16, 'Name': 'Hachimitsu to Clover'},
#  {'anime_id': 263, 'Name': 'Hajime no Ippo'},
#  {'anime_id': 135, 'Name': 'Hikaru no Go'},
#  {'anime_id': 5, 'Name': 'Cowboy Bebop: Tengoku no Tobira'},
#  {'anime_id': 384, 'Name': 'Gantz'},
#  {'anime_id': 256, 'Name': 'Hoshi no Koe'},
#  {'anime_id': 136, 'Name': 'Hunter x Hunter'}]
