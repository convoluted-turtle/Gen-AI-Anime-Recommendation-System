# %%
import pandas as pd 
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import difflib
import string
from collections import Counter
from tqdm import tqdm

# %%
df = pd.read_csv("/Users/justinvhuang/Desktop/CSE-6242-Group-Project/users-score-2023.csv")

# %%
anime_count = df.groupby('user_id')['anime_id'].count()

user_ids_to_drop = anime_count[anime_count < 10].index

filtered_df = df[~df['user_id'].isin(user_ids_to_drop)]

# %%
user_item_matrix = filtered_df.pivot_table(index='user_id', columns='Anime Title', values='rating')

user_item_matrix = user_item_matrix.fillna(0)

user_ratings_mean = user_item_matrix.mean(axis=1)
user_item_matrix_centered = user_item_matrix.sub(user_ratings_mean, axis=0)

item_similarity = cosine_similarity(user_item_matrix_centered.T)
# Out:
# /Users/justinvhuang/miniforge3/envs/spacy/lib/python3.8/site-packages/pandas/core/reshape/reshape.py:134: PerformanceWarning: The following operation may generate 3215923296 cells in the resulting pandas object.
#   warnings.warn(

# %%
def jaccard_similarity(title1, title2):
    title1_tokens = set(title1.lower().translate(str.maketrans('', '', string.punctuation)).split())
    title2_tokens = set(title2.lower().translate(str.maketrans('', '', string.punctuation)).split())
    intersection = len(title1_tokens.intersection(title2_tokens))
    union = len(title1_tokens.union(title2_tokens))
    return intersection / union if union else 0

def item_collaborative_recommender(anime_title, user_item_matrix, item_similarity, top_n=10):
    sim_scores = item_similarity[user_item_matrix.columns.get_loc(anime_title)]
    
    top_indices = np.argsort(sim_scores)[::-1][1:2*top_n+1]  
    
    similar_titles = []
    for idx in top_indices:
        title = user_item_matrix.columns[idx]
        if jaccard_similarity(anime_title, title) < 0.5:  
            similar_titles.append(title)
        if len(similar_titles) >= top_n:
            break
    
    return similar_titles[:top_n]

# %%
recommendations = item_collaborative_recommender('Elfen Lied', user_item_matrix, item_similarity)
print(recommendations)
# Out:
# ['Death Note', 'Code Geass: Hangyaku no Lelouch', 'Fullmetal Alchemist', 'Elfen Lied: Tooriame nite Arui wa, Shoujo wa Ikani Shite Sono Shinjou ni Itatta ka? - Regenschauer', 'Code Geass: Hangyaku no Lelouch R2', 'Higurashi no Naku Koro ni', 'Claymore', 'Hellsing', 'Clannad', 'Highschool of the Dead']

# %%
# Create an empty dictionary to store recommendations
anime_recommendations_dict = {}

# Group the DataFrame by 'Anime Title' to avoid repeated computations
grouped_df = filtered_df.groupby('Anime Title')

# Loop through unique anime titles with tqdm for a progress bar
for anime_title, anime_group in tqdm(grouped_df, total=len(grouped_df), desc="Processing Anime Titles"):
    # Assuming you want to use the first anime_id for each anime_title (you may need to adjust this logic)
    anime_id = anime_group['anime_id'].iloc[0]
    
    # Generate recommendations for the current anime title
    recommendations = item_collaborative_recommender(anime_title, user_item_matrix, item_similarity)
    
    # Store the recommendations in the dictionary with anime_id as the key
    anime_recommendations_dict[anime_id] = recommendations
# Out:
# Processing Anime Titles: 100%|██████████| 16608/16608 [00:20<00:00, 811.63it/s]

# %%
anime_recommendations_dict
# Out:
# {51478: ['Adobe Student and Teacher Edition',
#   'A lot of life',
#   'After Hours',
#   'A Viva Non Non',
#   '32',
#   'ABC Tenkiyohou',
#   '2005',
#   "A Doodlin' Song",
#   'Accept',
#   '(OO)'],
#  20707: ['2010',
#   'Ai Uta: Since 2007',
#   '3-Nen C-Gumi 14-Ban Kubozono Chiyoko no Nyuukaku',
#   '"Star"t',
#   '7-kakan.',
#   '3-D Heaven',
#   '365-nichi no Love Song',
#   '2',
#   '"Tokyo"',
#   '112 Sabsections of Skyline'],
#  7669: ['"Bungaku Shoujo" Memoire',
#   '"Bungaku Shoujo" Movie',
#   'Cencoroll',
#   'Denpa-teki na Kanojo',
#   'Amagami SS: Tachibana Miya-hen - Imouto',
#   'Another: The Other - Inga',
#   "Arata naru Sekai: World's/Start/Load/End",
#   'Black★Rock Shooter (OVA)',
#   'Boku wa Tomodachi ga Sukunai: Yaminabe wa Bishoujo ga Zannen na Nioi',
#   'Angel Beats! Another Epilogue'],
#  8481: ['"Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi',
#   'Denpa-teki na Kanojo',
#   'Amagami SS: Tachibana Miya-hen - Imouto',
#   'Amagami SS',
#   "Arata naru Sekai: World's/Start/Load/End",
#   'Amagami SS+ Plus',
#   'Black★Rock Shooter (OVA)',
#   'A-Channel',
#   'Angel Beats! Another Epilogue',
#   'Boku wa Tomodachi ga Sukunai: Yaminabe wa Bishoujo ga Zannen na Nioi'],
#  6408: ['"Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi',
#   'Denpa-teki na Kanojo',
#   'Amagami SS',
#   'Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.',
#   'Ano Natsu de Matteru',
#   'Denpa Onna to Seishun Otoko',
#   'Bakemonogatari',
#   'Byousoku 5 Centimeter',
#   'Black★Rock Shooter (OVA)',
#   'ef: A Tale of Melodies.'],
#  38045: ['Ai no Sato',
#   'Aimai na Mama',
#   'After Hours',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   'Ai to Yuuto: Hajimete no Otsukai',
#   'A Walk With the Colors',
#   '23rd Japan Media Arts Festival Introduction',
#   '"Tokyo"',
#   'Abyssal Zone',
#   'Amai Koibito'],
#  6076: ['0-sen Hayato Pilot',
#   'Tough Guy!',
#   'Ganbare Goemon: Chikyuu Kyuushutsu Daisakusen',
#   'Ari to Hato (1959)',
#   'Shin Mashin Eiyuuden Wataru Majinzan',
#   'Tanu no Magical Holiday',
#   'Sekai Douwa Anime Zenshuu',
#   '21-seiki wa Minna ga Shuyaku',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   'Akuei to Gacchinpo: Tenkomori'],
#  35025: ['Neko to Mata',
#   'Neko no Robu',
#   'Buppu na Mainichi',
#   'Yousei Land Mukashibanashi',
#   'Caribadix',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!'],
#  33363: ['?/Sankaku no Rhythm/Trump no Arasoi',
#   '"Kinako" Movie x Mameshiba',
#   '......',
#   'A Smart Experiment',
#   '23-ji no Saga Meshi Anime',
#   "A Sea Doesn't Tell Much",
#   'Afureko! AR',
#   '77Danui Bimil',
#   'Youkai Ninpouchou Jiraiya!',
#   '"Kiss Dekiru Gyoza" x Mameshiba Movie'],
#  49668: ['After Hours',
#   'Aisou ze!',
#   'Accept',
#   'A Viva Non Non',
#   'Ai no Sato',
#   'ABC Tenkiyohou',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   'Adobe Student and Teacher Edition',
#   'Akui Sensou',
#   'Afternoon Class'],
#  41060: ['A Walk With the Colors',
#   'Akui Sensou',
#   'Aimai na Mama',
#   '11-gatsu Umare no Otokonoko no Tame ni.',
#   '38-39°C',
#   'Ai no Sato',
#   'Akkenaku, Sekai wa',
#   'Alche Miss Katrina',
#   '23rd Japan Media Arts Festival Introduction',
#   '12 Zhi Wenzi He 5 Geren'],
#  35632: ['Ai ga Tarinai yo',
#   '4-shuunen Monst? Shiru ka yo!',
#   'Terrace House x Craft Boss',
#   '"Kiss Dekiru Gyoza" x Mameshiba Movie',
#   'Pokemon ASMR',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   'Ai no Sato',
#   'Xiong Chumo',
#   '12-wol',
#   '6 Songs'],
#  37843: ['"Kinako" Movie x Mameshiba',
#   '"R100" x Mameshiba Original Manners',
#   'Aigatari na Itte',
#   '12-wol',
#   'Ai no Sato',
#   'Air Folktale',
#   'Aitsura Zenin Dousoukai',
#   '6 Songs',
#   'Akashi',
#   'Ai to Yuuto: Hajimete no Otsukai'],
#  52034: ['Bocchi the Rock!',
#   'Chainsaw Man',
#   'Jigokuraku',
#   '86',
#   '86 Part 2',
#   'Kimetsu no Yaiba: Katanakaji no Sato-hen',
#   'Dr. Stone: New World',
#   'Blue Lock',
#   'Kaguya-sama wa Kokurasetai: Ultra Romantic',
#   'Cyberpunk: Edgerunners'],
#  34595: ['"Tokyo"',
#   'AEON',
#   '5-tsu no Yubi no Niwa',
#   '23-ji no Saga Meshi Anime',
#   'Ai Datta n da yo',
#   'About You',
#   'Acnes no Uta',
#   'Akubi Neko',
#   'Algo',
#   '112 Sabsections of Skyline'],
#  37626: ['"Kiss Dekiru Gyoza" x Mameshiba Movie',
#   'ABC Tenkiyohou',
#   'Adobe Student and Teacher Edition',
#   'After Hours',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   '4-shuunen Monst? Shiru ka yo!',
#   'Ai no Sato',
#   '"Kinako" Movie x Mameshiba',
#   '11-gatsu Umare no Otokonoko no Tame ni.',
#   '2'],
#  41090: ['Agitation!',
#   'AAside',
#   'Adobe Student and Teacher Edition',
#   '"Tokyo"',
#   '27th',
#   'A Christmas Song',
#   '365-nichi no Love Song',
#   'Anger',
#   'After-School Emotion',
#   '2'],
#  38748: ['Ai no Sato',
#   '6 Songs',
#   'After Hours',
#   'Aimai na Mama',
#   'Ai to Yuuto: Hajimete no Otsukai',
#   'Acnes no Uta',
#   'A Walk With the Colors',
#   '12 Zhi Wenzi He 5 Geren',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   'Aki Monogatari'],
#  40554: ['Ao Fei Q Chong',
#   'Aotenjou no Clown',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Daisougen to Hakuba',
#   'Congming de Yixiu Zhi Fan Dou Gongzhu',
#   'Hazedon',
#   'Goesu Daejeonjaeng',
#   'Cofun Gal no Coffy'],
#  51481: ['Kirakira (2021)',
#   'Happiness World',
#   "I Can't Control Myself",
#   'Hikari no Machi',
#   'Ai-mai Chocolate',
#   'Heart Beat (2019)',
#   'Felicia (2021)',
#   'Error',
#   'Aihen Jihen',
#   'Hologram Circus'],
#  38603: ['Ai Okure',
#   'Ahiru-kun no Chiisana Bouken',
#   '12 Shengxiao Quanjiafu de Shenqi Shijie',
#   '12 Shengxiao Guanjiafu: Wangluo Shijie Lixian',
#   'Ni Tian Zhan Ji',
#   'Ikinuke! Bakusou! Kusohamu-chan!',
#   'Ai ga Oshigoto',
#   'Ai wo Kite',
#   '(Mi) Liu',
#   'Anata no wo Uchi ga Eigakan'],
#  51723: ['Pandemic',
#   'Summer: Inaka no Seikatsu',
#   'Harem Cult',
#   'J* Genkai Koubi: Goui Sounyuu de Bachibachi Niku Anaka',
#   'Haji+ Shinchishin',
#   'Abandon: 100 Nuki Shinai to Derarenai Fushigi na Kyoushitsu',
#   'Renseijutsushi Colette no H na Sakusei Monogatari',
#   'Tsugunai',
#   'Yamitsuki Mura: Melty Limit The Animation',
#   'Kimi wa Yasashiku Netorareru The Animation'],
#  52691: ['Ai ga Oshigoto',
#   'Ai wo Kite',
#   'Ahiru-kun no Chiisana Bouken',
#   'Ai Okure',
#   'Akai Fuusen',
#   '12 Shengxiao Quanjiafu de Shenqi Shijie',
#   '12 Shengxiao Guanjiafu: Wangluo Shijie Lixian',
#   'Ni Tian Zhan Ji',
#   '9-gatsu',
#   '3341'],
#  51268: ['Afternoon Class',
#   'AEON',
#   'After Hours',
#   'About You',
#   'Adobe Student and Teacher Edition',
#   'Acnes no Uta',
#   '5-tsu no Yubi no Niwa',
#   'ABC Tenkiyohou',
#   'Aisou ze!',
#   'Al Dente Tango'],
#  36734: ['Affordance',
#   '0 Man',
#   '21-seiki',
#   '4.Eyes Re-Mix 2005',
#   'Sylvanian Families: Freya no Happy Diary',
#   'Cap Kakumei Bottleman DX: Side Story',
#   'KJ File 2nd Season',
#   'Airs',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong'],
#  40658: ['Pandemic',
#   'Aku no Onna Kanbu: Full Moon Night R',
#   'Bitch Gakuen ga Seijun na Hazu ga Nai!!? The Animation',
#   'Ane Chijo♥Max Heart',
#   'Boku to Joi no Shinsatsu Nisshi The Animation',
#   'Ero Konbini Tenchou',
#   'Hime-sama Love Life!',
#   'Chiisana Tsubomi no Sono Oku ni...',
#   '#Ima made de Ichiban Yokatta Sex The Animation',
#   'J* Genkai Koubi: Goui Sounyuu de Bachibachi Niku Anaka'],
#  56036: ['Niehime to Kemono no Ou Mini Anime',
#   'Ahiru-kun no Chiisana Bouken',
#   'Ai Okure',
#   '12 Shengxiao Quanjiafu de Shenqi Shijie',
#   'Ni Tian Zhan Ji',
#   '12 Shengxiao Guanjiafu: Wangluo Shijie Lixian',
#   'Ikinuke! Bakusou! Kusohamu-chan!',
#   'Bosanimal',
#   'Ai ga Oshigoto',
#   'Ai wo Kite'],
#  2928: ['.hack//G.U. Trilogy',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//Roots',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//Intermezzo',
#   '.hack//Liminality',
#   '.hack//Tasogare no Udewa Densetsu: Offline de Aimashou',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//Quantum'],
#  3269: ['.hack//G.U. Returner',
#   '.hack//Roots',
#   '.hack//Liminality',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//Intermezzo',
#   '.hack//Quantum',
#   '.hack//Sign',
#   '.hack//Tasogare no Udewa Densetsu: Offline de Aimashou'],
#  4469: ['.hack//G.U. Returner',
#   '.hack//Tasogare no Udewa Densetsu: Offline de Aimashou',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//Intermezzo',
#   '.hack//Liminality',
#   '.hack//Roots',
#   '.hack//Quantum: Sore ike! Bokura no Chimuchimu-chan!!',
#   '.hack//Quantum',
#   '.hack//Versus: The Thanatos Report'],
#  454: ['.hack//Unison',
#   '.hack//Intermezzo',
#   '.hack//Liminality',
#   '.hack//G.U. Returner',
#   '.hack//Tasogare no Udewa Densetsu: Offline de Aimashou',
#   '.hack//Roots',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//G.U. Trilogy',
#   '.hack//Sign'],
#  1143: ['.hack//Unison',
#   '.hack//Gift',
#   '.hack//Liminality',
#   '.hack//Tasogare no Udewa Densetsu: Offline de Aimashou',
#   '.hack//G.U. Returner',
#   '.hack//Sign',
#   '.hack//Roots',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//G.U. Trilogy',
#   '.hack//G.U. Trilogy: Parody Mode'],
#  299: ['.hack//Gift',
#   '.hack//Unison',
#   '.hack//Intermezzo',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//Sign',
#   '.hack//Roots',
#   '.hack//G.U. Returner',
#   '.hack//G.U. Trilogy',
#   '.hack//Tasogare no Udewa Densetsu: Offline de Aimashou',
#   '.hack//Quantum'],
#  9332: ['.hack//G.U. Trilogy',
#   '.hack//The Movie: Sekai no Mukou ni',
#   '.hack//G.U. Returner',
#   '.hack//Roots',
#   '.hack//Liminality',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//Unison',
#   '.hack//Intermezzo',
#   '.hack//Gift',
#   '.hack//Sign'],
#  10390: ['.hack//Versus: The Thanatos Report',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//Tasogare no Udewa Densetsu: Offline de Aimashou',
#   '.hack//Quantum',
#   '11eyes Picture Drama',
#   '"Kinako" Movie x Mameshiba',
#   'Adobe Student and Teacher Edition',
#   'Afureko! AR',
#   '40-shuunen da yo!! CoroCoro All-Star Shougakkou',
#   'Acerola-chan'],
#  873: ['.hack//Tasogare no Udewa Densetsu',
#   '.hack//Sign',
#   '.hack//G.U. Trilogy',
#   '.hack//Liminality',
#   '.hack//G.U. Returner',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//Intermezzo',
#   '.hack//Quantum',
#   '.hack//G.U. Trilogy: Parody Mode'],
#  48: ['.hack//Tasogare no Udewa Densetsu',
#   '.hack//Roots',
#   '.hack//Liminality',
#   '.hack//Intermezzo',
#   '.hack//Unison',
#   '.hack//Gift',
#   '.hack//G.U. Trilogy',
#   'Fullmetal Alchemist',
#   'Cowboy Bebop',
#   'FLCL'],
#  298: ['.hack//Sign',
#   '.hack//Roots',
#   '.hack//Liminality',
#   '.hack//Gift',
#   '.hack//Unison',
#   '.hack//Intermezzo',
#   '.hack//G.U. Trilogy',
#   '.hack//G.U. Returner',
#   '.hack//Quantum',
#   '.hack//G.U. Trilogy: Parody Mode'],
#  1994: ['.hack//Gift',
#   '.hack//Unison',
#   '.hack//Intermezzo',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//G.U. Returner',
#   '.hack//Liminality',
#   '.hack//G.U. Trilogy',
#   '.hack//Roots',
#   '.hack//Quantum: Sore ike! Bokura no Chimuchimu-chan!!',
#   '.hack//Quantum'],
#  11375: ['.hack//Versus: The Thanatos Report',
#   '.hack//Quantum',
#   '.hack//G.U. Returner',
#   '.hack//G.U. Trilogy',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//Unison',
#   '.hack//Quantum: Sore ike! Bokura no Chimuchimu-chan!!',
#   '.hack//Intermezzo',
#   '.hack//Liminality',
#   '.hack//Roots'],
#  1487: ['.hack//Intermezzo',
#   '.hack//Gift',
#   '.hack//Liminality',
#   '.hack//G.U. Returner',
#   '.hack//Tasogare no Udewa Densetsu: Offline de Aimashou',
#   '.hack//Sign',
#   '.hack//Roots',
#   '.hack//Tasogare no Udewa Densetsu',
#   '.hack//G.U. Trilogy',
#   '.hack//G.U. Trilogy: Parody Mode'],
#  15219: ['.hack//The Movie: Sekai no Mukou ni',
#   '.hack//Quantum: Sore ike! Bokura no Chimuchimu-chan!!',
#   '.hack//G.U. Trilogy: Parody Mode',
#   '.hack//Quantum',
#   '.hack//G.U. Returner',
#   '3-tsu no Hanashi',
#   'Aiseki Mogol Girl',
#   '100% Pascal-sensei',
#   'Aitsu to Lullaby: Suiyobi no Cinderella',
#   'Akindo Sei no Little Peso'],
#  52399: ['Affordance',
#   '21-seiki',
#   '(a long day of) Mr. Calpaccio',
#   '4.Eyes Re-Mix 2005',
#   'Airs',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!'],
#  12763: ['Amigo Tomodachi',
#   'Momonga-mon',
#   'Liv & Bell',
#   'Akuei to Gacchinpo: Tenkomori',
#   'Teach',
#   'Ama Gli Animali',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   '21-seiki wa Minna ga Shuyaku',
#   'AAA de Ikou!!: Yuuna & Akiko',
#   'Robot Pulta'],
#  33978: ['AAA de Ikou!!: Yuuna & Akiko',
#   'Akuei to Gacchinpo The Movie: Chelsea no Gyakushuu/Akuei to Mahou no Hammer',
#   'Robot Pulta',
#   'Dotanba no Manners',
#   'Lan Mao',
#   'Momonga-mon',
#   'Amigo Tomodachi',
#   'Fuwa Aoyun Manyouji',
#   'Ai no Kiseki: Doctor Norman Monogatari',
#   'Aladdin to Mahou no Lamp no Koutsuu Anzen'],
#  29978: ['"Tokyo"',
#   '12-gatsu no Uta',
#   'Akagaki Genzou: Tokuri no Wakare',
#   'Chibi Maruko-chan: Hi no Youjin',
#   'Nintama Rantarou no Uchuu Daibouken with Cosmic Front☆Next',
#   'Nintama Rantarou no Shouboutai',
#   'Ajjishin da Tsunami wa? Jibun no Inochi wa Jibun de Mamoru',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   'Liv & Bell',
#   'Ama Gli Animali'],
#  11755: ['Cyborg 009 VS Devilman',
#   'Cyborg 009: Call of Justice 1',
#   'Captain Herlock',
#   'Cyborg 009: Call of Justice 2',
#   'Cyborg 009: The Reopening',
#   'Cyborg 009: Call of Justice 3',
#   '.hack//The Movie: Sekai no Mukou ni',
#   'Asura',
#   'Appleseed Alpha',
#   'Arve Rezzle: Kikaijikake no Yousei-tachi'],
#  32737: ['Adobe Student and Teacher Edition',
#   'ABC Tenkiyohou',
#   'Akashi',
#   '4-shuunen Monst? Shiru ka yo!',
#   'A.A',
#   'After Hours',
#   'Ai to Yuuto: Hajimete no Otsukai',
#   'Air Folktale',
#   '6 Songs',
#   'Akuma no Organ'],
#  1583: ['A.D. Police (TV)',
#   'AD Police',
#   'AIKa',
#   'AIKa R-16: Virgin Mission',
#   'AIKa Zero',
#   'Angel Cop',
#   'Aozora Shoujo-tai',
#   'Burn Up!',
#   'AIKa: Special Trial',
#   'Area 88 (TV)'],
#  3234: ['Alexandros no Ketsudan',
#   '2002-nen Halmeoni Ondo',
#   'Akai Jitensha',
#   'Adesugata Mahou no Sannin Musume',
#   'Ai no Tabidachi',
#   'Akisutozeneko',
#   'Akai Yama Aoi Yama Shiroi Yama',
#   '15 Sonyeon Uju Pyoryugi',
#   'A Christmas Song',
#   '009 Re:Cyborg x Zip'],
#  28761: ['2005-nen Uchuu no Tabi',
#   'Adventures in Beauty Wonderland',
#   '1',
#   '12-gatsu no Uta',
#   'Crazy for It',
#   '2010',
#   '112 Sabsections of Skyline',
#   'Aki no Puzzle',
#   'Fetish Doll',
#   'Count Down'],
#  5525: ['D.Gray-man',
#   'Pandora Hearts',
#   'Ao no Exorcist',
#   'Kuroshitsuji',
#   'Code Geass: Hangyaku no Lelouch',
#   'Code Geass: Hangyaku no Lelouch R2',
#   'Nabari no Ou',
#   'Hakuouki',
#   'Katekyo Hitman Reborn!',
#   'Fairy Tail'],
#  1328: ['Fire Tripper',
#   'The Supergal',
#   'Warau Hyouteki',
#   '"Eiji"',
#   'B.B. Fish',
#   'Adachi-ga Hara',
#   'Akuma no Kairozu',
#   'Cosmos Pink Shock',
#   'Choujikuu Romanesque Samy: Missing 99',
#   'Antique Heart'],
#  2730: ['100%',
#   'Age Man to Fuku Chin',
#   'Angel',
#   'Kugutsu Ai: Doura Gaiden',
#   'Rebiya',
#   'SM no Susume',
#   '?/Sankaku no Rhythm/Trump no Arasoi',
#   '69 Pink Riders 2',
#   'Rhythm: Koi no Rhythm',
#   'Adesugata Mahou no Sannin Musume'],
#  6060: ['Kotencotenco',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   'Liv & Bell',
#   '21-seiki wa Minna ga Shuyaku',
#   'Ama Gli Animali',
#   'Teach',
#   'Akuei to Gacchinpo: Tenkomori',
#   'Nintama Rantarou no Shouboutai',
#   'Chibi Maruko-chan: Hi no Youjin',
#   'Ajjishin da Tsunami wa? Jibun no Inochi wa Jibun de Mamoru'],
#  36745: ['1/100 Shibuya Crossing',
#   '1/100 Train Station',
#   'Aigatari na Itte',
#   'Afternoon Class',
#   'Air Folktale',
#   '23rd Japan Media Arts Festival Introduction',
#   '6 Songs',
#   'ABC Tenkiyohou',
#   'A.A',
#   'Aa / ii'],
#  36746: ['1/100 Rice Planting',
#   '1/100 Train Station',
#   '112 Sabsections of Skyline',
#   '"Tokyo"',
#   'ABC Tenkiyohou',
#   'A Woman in a Fashion Building',
#   'Adobe Student and Teacher Edition',
#   'Aishiteru (2010)',
#   'Afternoon Class',
#   '1000-mankai Hug Nanda'],
#  36747: ['1/100 Shibuya Crossing',
#   '1/100 Rice Planting',
#   'Adobe Student and Teacher Edition',
#   'ABC Tenkiyohou',
#   'Aishiteru (2010)',
#   'A Christmas Song',
#   'Afternoon Class',
#   'A Woman in a Fashion Building',
#   'Against',
#   '11-gatsu Umare no Otokonoko no Tame ni.'],
#  51239: ['15-fun de Wakaru: Kami no Tou',
#   'Ami no Monomane 150 Renpatsu',
#   'Sajou no Yumekui Shoujo',
#   'A Qi Aoyou Ji',
#   'Ao no Butai ni Omoi wo Yosete',
#   'Tonari no Kaibutsu-kun Special',
#   'Kidou Senshi Gundam 00 CB Chara',
#   'Sword Art Online: Full Dive - Opening Eizou',
#   'Kami nomi zo Shiru Sekai PV',
#   'Re:Zero kara Hajimeru Isekai Seikatsu - Memory Snow Announcement'],
#  55408: ['1985',
#   'Aozora',
#   'ABC-Mart Grand Stage CMs',
#   'Anata no wo Uchi ga Eigakan',
#   "An Atheist's Christmas",
#   'Albino',
#   'Ai wo Kite',
#   'Ai ga Oshigoto',
#   'Akogare',
#   'Aishang Zhi Di'],
#  7374: ['0-sen Hayato',
#   'Amigo Tomodachi',
#   'Momonga-mon',
#   'Ama Gli Animali',
#   'Teach',
#   'Akuei to Gacchinpo: Tenkomori',
#   'Liv & Bell',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   '21-seiki wa Minna ga Shuyaku',
#   'Akuei to Gacchinpo The Movie: Chelsea no Gyakushuu/Akuei to Mahou no Hammer'],
#  35447: ['Aiseki Mogol Girl',
#   'Akachan Honbuchou 2nd Season',
#   'Ninja Box 3rd Season',
#   'Akachan Honbuchou 3rd Season',
#   'Teikou Penguin',
#   'PePePePengiin',
#   'Amigo Tomodachi',
#   'Momonga-mon',
#   'Bokutachi no Peace River',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu'],
#  34052: ['PePePePengiin',
#   'Teikou Penguin',
#   'Akachan Honbuchou 3rd Season',
#   'Akachan Honbuchou 2nd Season',
#   'Ninja Box 3rd Season',
#   'Honeycomb Summer',
#   'Trick with Treat!! (with Undead)',
#   'Play "Tag"',
#   'Choegang Habche: Mix Master',
#   'Unlimited☆Power!!!!!'],
#  39208: ['"Tokyo"',
#   '6 Songs',
#   '112 Sabsections of Skyline',
#   'Ai no Tabidachi',
#   'Adobe Student and Teacher Edition',
#   'A Christmas Song',
#   'Aitsura Zenin Dousoukai',
#   '27th',
#   '23rd Japan Media Arts Festival Introduction',
#   'Amakage'],
#  41380: ['Arifureta Shokugyou de Sekai Saikyou',
#   'Arifureta Shokugyou de Sekai Saikyou 2nd Season',
#   'Choujin Koukousei-tachi wa Isekai demo Yoyuu de Ikinuku you desu!',
#   'Hachi-nan tte, Sore wa Nai deshou!',
#   'Genjitsu Shugi Yuusha no Oukoku Saikenki',
#   'Assassins Pride',
#   'Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka III',
#   'Benriya Saitou-san, Isekai ni Iku',
#   'Genjitsu Shugi Yuusha no Oukoku Saikenki Part 2'],
#  44881: ['Arifureta Shokugyou de Sekai Saikyou 2nd Season',
#   'Arifureta Shokugyou de Sekai Saikyou',
#   'Deatte 5-byou de Battle',
#   'Benriya Saitou-san, Isekai ni Iku',
#   'Genjitsu Shugi Yuusha no Oukoku Saikenki',
#   'Choujin Koukousei-tachi wa Isekai demo Yoyuu de Ikinuku you desu!',
#   'Genjitsu Shugi Yuusha no Oukoku Saikenki Part 2',
#   'Assassins Pride',
#   'Gaikotsu Kishi-sama, Tadaima Isekai e Odekakechuu',
#   'Bokutachi no Remake'],
#  48976: ['Tenchi Muyou! Ryououki 3rd Season Picture Drama',
#   'Mao Zhi Ming Specials',
#   'Princess Knight☆Catue DVD-BOX Special',
#   'Mashiro no Oto Mini',
#   'Kaiko sareta Ankoku Heishi (30-dai) no Slow na Second Life Mini Anime Episode 0',
#   'Kemonokko Tsuushin: The Animation - Nekomusume Nia',
#   'Mahou Shoujo Elena DVD-BOX Special',
#   'Shin Shinka no Mi Gekijou',
#   'Tensai Ouji no Akaji Kokka Saisei Jutsu: Short Drama',
#   'Kaiko sareta Ankoku Heishi (30-dai) no Slow na Second Life Mini Anime'],
#  5133: ['Akuma Tou no Prince: Mitsume ga Tooru',
#   'Bremen 4: Jigoku no Naka no Tenshi-tachi',
#   'Akuei to Gacchinpo: Tenkomori - Maboroshi no Omake Episode',
#   'Nintama Rantarou no Shouboutai',
#   'Chibi Maruko-chan: Hi no Youjin',
#   'Nintama Rantarou no Uchuu Daibouken with Cosmic Front☆Next',
#   'Ajjishin da Tsunami wa? Jibun no Inochi wa Jibun de Mamoru',
#   'Ni-hiki no Sanma (1968)',
#   'Ama Gli Animali',
#   'Akuei to Gacchinpo: Tenkomori'],
#  48352: ['Bastions',
#   "Be Rockin'",
#   '12 Shengxiao Quanjiafu de Shenqi Shijie',
#   'Ai Okure',
#   'Ahiru-kun no Chiisana Bouken',
#   '12 Shengxiao Guanjiafu: Wangluo Shijie Lixian',
#   'Ni Tian Zhan Ji',
#   'Ikinuke! Bakusou! Kusohamu-chan!',
#   'Chokkan × Algorhythm♪',
#   'Aotenjou no Clown'],
#  49414: ['Akuyaku Mahou Shoujo Midoro',
#   'Ai W-kun',
#   '3341',
#   'Akai Fuusen',
#   'Aa Okashii ne',
#   'Akubi Neko',
#   '12 Zhi Wenzi He 5 Geren',
#   '38-39°C',
#   'Ai ga Oshigoto',
#   'Ai wo Kite'],
#  53917: ['Accept',
#   'Amakamisama',
#   'Amagami',
#   'A Viva Non Non',
#   'Amai Koibito',
#   'A Walk With the Colors',
#   'Akui Sensou',
#   'Aisou ze!',
#   '1985',
#   "Ain't Seen Nothing Like This"],
#  1549: ['Maetel Legend',
#   'Ginga Tetsudou 999: Eternal Fantasy',
#   'Ginga Tetsudou 999: Eien no Tabibito Emeraldas',
#   'Shin Taketori Monogatari: 1000-nen Joou',
#   'Ginga Tetsudou 999: Glass no Clair',
#   'DNA Sights 999.9',
#   '100%',
#   'Adesugata Mahou no Sannin Musume',
#   'Arei no Kagami: Way to the Virgin Space',
#   'Ginga Tetsudou 999: Kimi wa Senshi no You ni Ikirareru ka?'],
#  3914: ['Atama Yama',
#   'Aru Machi Kado no Monogatari',
#   'Bavel no Hon',
#   'Aru Tabibito no Nikki',
#   'Aru Tabibito no Nikki Specials',
#   'Fantascope: Tylostoma',
#   'Fuyu no Hi',
#   'Ginga no Uo Ursa Minor Blue',
#   '4-Day Weekend',
#   'Ai'],
#  48313: ['Akui Sensou',
#   'A Walk With the Colors',
#   '23rd Japan Media Arts Festival Introduction',
#   'Alche Miss Katrina',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   'Accept',
#   'Aimai na Mama',
#   'Aishiteru (2010)',
#   'Anata ga Miemashita',
#   'ABC Tenkiyohou'],
#  1901: ['Crusher Joe',
#   'Crusher Joe OVA',
#   'Area 88',
#   'Arion',
#   'Assemble Insert',
#   'Black Magic M-66',
#   'California Crisis: Tsuigeki no Juuka',
#   'Bobby ni Kubittake',
#   '1 Pound no Fukuin',
#   'Baoh Raihousha'],
#  39286: ['27th',
#   '"Tokyo"',
#   'Adobe Student and Teacher Edition',
#   'A Woman in a Fashion Building',
#   '32',
#   'Ab-rah',
#   'Ake-Vono',
#   'A Viva Non Non',
#   'ABC Tenkiyohou',
#   'About You'],
#  51078: ['Ai no Sato',
#   "A Doodlin' Song",
#   'Ai to Yuuto: Hajimete no Otsukai',
#   '32',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   '2005',
#   'A Walk With the Colors',
#   '38-39°C',
#   'Akui Sensou',
#   'Aishang Zhi Di'],
#  6682: ['11eyes: Momoiro Genmutan',
#   "Asura Cryin'",
#   'ChäoS;HEAd',
#   'Asu no Yoichi!',
#   'Angel Beats!',
#   'Akaneiro ni Somaru Saka',
#   "Asura Cryin' 2",
#   'Baka to Test to Shoukanjuu',
#   'Ichiban Ushiro no Daimaou',
#   'Fortune Arterial: Akai Yakusoku'],
#  20557: ['Alphard x Taka no Tsume',
#   'A Qi Aoyou Ji',
#   '3-nen D-gumi Glass no Kamen: Tobidase! Watashitachi no Victory Road',
#   '(a long day of) Mr. Calpaccio',
#   'Moffun to Issho',
#   'Guaishou Xiao Guan',
#   'Si Ge Yongzhe',
#   'Xiong Chumo',
#   'Shanhai Jihui',
#   'Feng Huo Zhan Ji'],
#  7739: ['11eyes',
#   'Akaneiro ni Somaru Saka: Hardcore',
#   'Akikan!: Kan Ippatsu!? Onsen Panic',
#   'C³',
#   'Angel Beats! Specials',
#   'Angel Beats! Another Epilogue',
#   'Akaneiro ni Somaru Saka',
#   'Asobi ni Iku yo!: Asobi ni Oide',
#   "Asura Cryin' 2",
#   'Asobi ni Iku yo!'],
#  43858: ['12 Shengxiao Quanjiafu de Shenqi Shijie',
#   'Ikinuke! Bakusou! Kusohamu-chan!',
#   'Ahiru-kun no Chiisana Bouken',
#   'Ai Okure',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Daisougen to Hakuba'],
#  43852: ['Ahiru-kun no Chiisana Bouken',
#   'Ai Okure',
#   '12 Shengxiao Guanjiafu: Wangluo Shijie Lixian',
#   'Ni Tian Zhan Ji',
#   'Ikinuke! Bakusou! Kusohamu-chan!',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!'],
#  43912: ["90's Love (SQUAR Remix)",
#   '38-39°C',
#   'Akkenaku, Sekai wa',
#   'Ai no Sungekijou',
#   'Ai W-kun',
#   '3341',
#   'Akashi',
#   'Aishiteru',
#   'Another Day, Another Place',
#   'Akai Fuusen'],
#  29411: ['3-tsu no Hanashi',
#   'Juu-nin no Chiisa na Indian',
#   'Home My Home',
#   'Kirin no Otenki Mama-san',
#   'Ojiichan ga Kaizoku Datta Koro',
#   'Beautiful Name',
#   'Stone',
#   'Koro wa Yane no Ue',
#   'Akuei to Gacchinpo: Tenkomori - Maboroshi no Omake Episode',
#   'Oshizuka ni'],
#  23579: ['12-sai. 2nd Season',
#   '12-sai.: Chicchana Mune no Tokimeki',
#   'Adachi to Shimamura Mini Anime',
#   '6HP (Six Hearts Princess)',
#   '12-sai.: Chicchana Mune no Tokimeki 2nd Season',
#   'Tokyo Fantasia',
#   'Sora e',
#   'Crash!',
#   'Motion Lumine',
#   'Sleepy'],
#  31319: ['Mako-chan no Koutsuu Anzen',
#   'Tabun',
#   'Inemuri Buu-chan',
#   'Urameshi Denwa',
#   'Koro wa Yane no Ue',
#   'Ninja Box 3rd Season',
#   'Teikou Penguin',
#   'Akachan Honbuchou 3rd Season',
#   'Akachan Honbuchou 2nd Season',
#   '15-sai, Kyou kara Dousei Hajimemasu.'],
#  32601: ['12-sai.',
#   '12-sai. 2nd Season',
#   'Akkun to Kanojo',
#   'Action Heroine Cheer Fruits',
#   'Alice or Alice',
#   'Bernard-jou Iwaku.',
#   'Anne Happy♪',
#   'Anima Yell!',
#   'Ame-iro Cocoa',
#   'Ame-iro Cocoa: Rainy Color e Youkoso!'],
#  33419: ['12-sai. 2nd Season',
#   'Bloomy*Cafe',
#   "W'z: Hand Shakers with W'z",
#   'Aikatsu Planet! Movie',
#   '100% Pascal-sensei (TV)',
#   'Wangu Xian Qiong III: Eren Gu Pian',
#   '12-sai.',
#   'Akachan Honbuchou 3rd Season',
#   'Ninja Box 3rd Season',
#   'Teikou Penguin'],
#  51344: ['Akashi',
#   'Aigatari na Itte',
#   'Ai no Tabidachi',
#   '38-39°C',
#   'After Man',
#   '9-gatsu',
#   'Air Folktale',
#   '12 Zhi Wenzi He 5 Geren',
#   'Akkenaku, Sekai wa',
#   "90's Love (SQUAR Remix)"],
#  37065: ['Airs',
#   'Aa Okashii ne',
#   'Aaron He Lili',
#   'Animal 1',
#   'Aikodesho',
#   '(a long day of) Mr. Calpaccio',
#   'Ai Ni',
#   'Aresuke',
#   '21-seiki',
#   'Affordance'],
#  5762: ['Ane Jiru 2 The Animation: Shirakawa Sanshimai ni Omakase',
#   'Ane Jiru The Animation: Shirakawa Sanshimai ni Omakase',
#   'Fault!!',
#   'Cafe Junkie',
#   'Aneimo',
#   'Binkan Athlete',
#   'Alignment You! You! The Animation',
#   'Ane☆Haramix',
#   'Accelerando: Datenshi-tachi no Sasayaki',
#   'Akina to Onsen de H Shiyo!'],
#  18305: ['Abe George Kattobi Seishun Ki: Shibuya Honky Tonk',
#   'Cheorin Samchongsa',
#   'Anpanman to Hajimeyou! Iro, Kazu, Katachi Wakaru ka na Iro, Katachi',
#   'Animal 1',
#   'Aresuke',
#   'Aaron He Lili',
#   'Ai Ni',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad'],
#  48881: ['ABC-Mart Grand Stage CMs',
#   "A Doodlin' Song",
#   'A Viva Non Non',
#   'A Walk With the Colors',
#   '2005',
#   '32',
#   'Akui Sensou',
#   '100 Manten☆Pax Salomena',
#   'Alche Miss Katrina',
#   'Airs'],
#  51221: ['InaDan Gag Gaiden',
#   'Inamori Asuto no Soccer Kyoushitsu',
#   'Kamiusagi Rope x TOHO Cinemas',
#   'Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?',
#   'Felix x Kamiusagi Rope',
#   'Kana Kana Kazoku',
#   'Kamiusagi Rope x TOHO Cinemas (Movies)',
#   'au x Rope',
#   'Kamiusagi Rope (ONA)',
#   'Xiong Chumo'],
#  52554: ['A Qi Aoyou Ji',
#   'Peach Boy Riverside Mini Anime',
#   'Mao Zhi Ming Specials',
#   'Tenchi Muyou! Ryououki 3rd Season Picture Drama',
#   'Mashiro no Oto Mini',
#   'Princess Knight☆Catue DVD-BOX Special',
#   'Kaiko sareta Ankoku Heishi (30-dai) no Slow na Second Life Mini Anime Episode 0',
#   'Kemonokko Tsuushin: The Animation - Nekomusume Nia',
#   'Mahou Shoujo Elena DVD-BOX Special',
#   'Shin Shinka no Mi Gekijou'],
#  51240: ['15-fun de Wakaru: Kami no Tou',
#   'Ami no Monomane 150 Renpatsu',
#   'Sajou no Yumekui Shoujo',
#   'A Qi Aoyou Ji',
#   'Ao no Butai ni Omoi wo Yosete',
#   'Tonari no Kaibutsu-kun Special',
#   'Sword Art Online: Full Dive - Opening Eizou',
#   'Kidou Senshi Gundam 00 CB Chara',
#   'Kami nomi zo Shiru Sekai PV',
#   'Re:Zero kara Hajimeru Isekai Seikatsu - Memory Snow Announcement'],
#  38019: ['Appare! Momotarou no Koutsuu Anzen',
#   'Anime Roukyoku Kikou Shimizu no Jirochouden',
#   'Anata no wo Uchi ga Eigakan',
#   'Bai Gui Youeryuan 2nd Season',
#   'Bai Gui Youeryuan',
#   'Ao Fei Q Chong',
#   'Aotenjou no Clown',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!'],
#  48858: ['Tenka Hyakken: Meiji-kan e Youkoso!',
#   'Miren Record',
#   'Pittoshite! Marmalade',
#   'Umi Yori Fukai Sora no Shita',
#   'Pastel Tea Time',
#   'Aru Asa Dummy Head Mic ni Natteita Ore-kun no Jinsei',
#   'Tsunagu, Soramoyou',
#   'Motto ne!',
#   'AAside',
#   'Teikou Penguin'],
#  35248: ['Caligula (TV)',
#   'Action Heroine Cheer Fruits',
#   "Akiba's Trip The Animation",
#   'Clione no Akari',
#   'ēlDLIVE',
#   'Alice to Zouroku',
#   'Animegataris',
#   'Active Raid: Kidou Kyoushuushitsu Dai Hachi Gakari 2nd',
#   'Akanesasu Shoujo',
#   'Clockwork Planet'],
#  51915: ["Partner's Territory",
#   'Ikimono-san',
#   'Hello Kitty no Hajimete no Christmas Cake',
#   'Apple Papple Princess',
#   '12 Shengxiao Quanjiafu de Shenqi Shijie',
#   'Ahiru-kun no Chiisana Bouken',
#   'Ai Okure',
#   '12 Shengxiao Guanjiafu: Wangluo Shijie Lixian',
#   'Ni Tian Zhan Ji',
#   'Ahiru no Pekkle no Sindbad no Bouken'],
#  55204: ['Albino',
#   'Aishang Zhi Di',
#   'Akogare',
#   'Accept',
#   'Alita De Shi Lian',
#   '2005',
#   '100 Manten☆Pax Salomena',
#   'Alche Miss Katrina',
#   '9-gatsu',
#   'A Walk With the Colors'],
#  30234: ['A Play',
#   '2',
#   'Ai think so,',
#   '3-Nen C-Gumi 14-Ban Kubozono Chiyoko no Nyuukaku',
#   '2010',
#   '7-kakan.',
#   'Ai Uta: Since 2007',
#   'A Christmas Song',
#   'Ainone',
#   'Akisutozeneko'],
#  38756: ['Akisutozeneko',
#   '11-gatsu Umare no Otokonoko no Tame ni.',
#   'A Christmas Song',
#   'A Woman in a Fashion Building',
#   'A Walk With the Colors',
#   'Accept',
#   'Aa / ii',
#   'Ab-rah',
#   'ABC Tenkiyohou',
#   'Adobe Student and Teacher Edition'],
#  46003: ['2.43 Mini Anime: Inside Story',
#   '2.43: Seiin Koukou Danshi Volley-bu Mini Anime',
#   'Kamiusagi Rope x TOHO Cinemas',
#   'Kana Kana Kazoku',
#   'Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?',
#   'Felix x Kamiusagi Rope',
#   'Agukaru: Play with Ibaraki-hen Episode 0',
#   'au x Rope',
#   'Kamiusagi Rope x TOHO Cinemas (Movies)',
#   'Kamiusagi Rope (ONA)'],
#  46004: ['2.43 Mini Anime: Fukui-ben Kouza',
#   '2.43: Seiin Koukou Danshi Volley-bu Mini Anime',
#   '2.43 Mini Anime: Volleyball Kouza',
#   'Kamiusagi Rope x TOHO Cinemas',
#   'Kana Kana Kazoku',
#   'Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?',
#   'Felix x Kamiusagi Rope',
#   'Agukaru: Play with Ibaraki-hen Episode 0',
#   'au x Rope',
#   'Kamiusagi Rope x TOHO Cinemas (Movies)'],
#  45585: ['2.43 Mini Anime: Inside Story',
#   '2.43: Seiin Koukou Danshi Volley-bu Mini Anime',
#   'Guaishou Xiao Guan',
#   'Moffun to Issho',
#   'Si Ge Yongzhe',
#   'Di Yi Xulie',
#   'Feng Huo Zhan Ji',
#   'Shanhai Jihui',
#   'Wan Sheng Jie 4',
#   'Kamiusagi Rope x TOHO Cinemas'],
#  40679: ['Bakuten!!',
#   'Ahiru no Sora',
#   'Futsal Boys!!!!!',
#   'Skate-Leading☆Stars',
#   'Love All Play',
#   'Gunjou no Fanfare',
#   'Ao Ashi',
#   'Re-Main',
#   'A3! Season Autumn & Winter',
#   'A3! Season Spring & Summer'],
#  46000: ['2.43 Mini Anime: Inside Story',
#   '2.43 Mini Anime: Fukui-ben Kouza',
#   '2.43 Mini Anime: Volleyball Kouza',
#   'Si Ge Yongzhe',
#   'Moffun to Issho',
#   'Guaishou Xiao Guan',
#   'Feng Huo Zhan Ji',
#   'Di Yi Xulie',
#   'Shanhai Jihui',
#   'Wan Sheng Jie 4'],
#  29347: ['"Calpis" Hakkou Monogatari',
#   'Adobe Student and Teacher Edition',
#   '2',
#   'Akisutozeneko',
#   '"Tokyo"',
#   'Ai no Sato',
#   'Aigatari na Itte',
#   '23rd Japan Media Arts Festival Introduction',
#   'Ai to Shi',
#   '"Kiss Dekiru Gyoza" x Mameshiba Movie'],
#  51241: ['15-fun de Wakaru: Kami no Tou',
#   'Ami no Monomane 150 Renpatsu',
#   'Boku no Sensou',
#   'Tonari no Kaibutsu-kun Special',
#   'A Qi Aoyou Ji',
#   'Kami nomi zo Shiru Sekai PV',
#   'Re:Zero kara Hajimeru Isekai Seikatsu - Memory Snow Announcement',
#   'Kyou, Watashi no Monogatari ga Hashirimasu.: Another Side-hen',
#   'Kyou, Watashi no Monogatari ga Hashirimasu.',
#   'One Piece: Otoshidama Special - Tokubetsu Hou Mugiwara Kaizoku-dan no Himitsu!'],
#  31874: ['Katsuobushi da yo Jinsei wa',
#   'Airs',
#   'Ai ga Oshigoto',
#   'Ai wo Kite',
#   '(Mi) Liu',
#   'Rainbow Signal: Hi-Fi Set',
#   'Kuro',
#   'Tenkousei wa Uchuujin',
#   'Joukyuusei',
#   'Kaiketsu Tamagon'],
#  54066: ['32',
#   "A Doodlin' Song",
#   '1985',
#   'ABC-Mart Grand Stage CMs',
#   'Akogare',
#   'Albino',
#   'Aishang Zhi Di',
#   'A Viva Non Non',
#   '100 Manten☆Pax Salomena',
#   'Accept'],
#  28339: ['2010',
#   '4.Eyes',
#   'Adventures in Beauty Wonderland',
#   'A Smart Experiment',
#   'A Log Day of Timbre',
#   '?/Sankaku no Rhythm/Trump no Arasoi',
#   'A Woman in a Fashion Building',
#   '2',
#   'Akisutozeneko',
#   'Okashina Hotel'],
#  32813: ['Akisutozeneko',
#   '2',
#   'A Christmas Song',
#   'Ai no Tabidachi',
#   '9',
#   'Alba',
#   'Ab-rah',
#   'Alluptoyou',
#   '112 Sabsections of Skyline',
#   'Acerola-chan'],
#  16696: ['15 Sonyeon Uju Pyoryugi',
#   'Cheorin Samchongsa',
#   'Abe George Kattobi Seishun Ki: Shibuya Honky Tonk',
#   'Anpanman to Hajimeyou! Iro, Kazu, Katachi Wakaru ka na Iro, Katachi',
#   'Kamiusagi Rope x au Collaboration',
#   'Aladdin to Mahou no Lamp no Koutsuu Anzen',
#   'Ai no Kiseki: Doctor Norman Monogatari',
#   'AAA de Ikou!!: Yuuna & Akiko',
#   'Robot Pulta',
#   'Akuei to Gacchinpo The Movie: Chelsea no Gyakushuu/Akuei to Mahou no Hammer'],
#  5628: ['Ama Gli Animali',
#   '21-seiki wa Minna ga Shuyaku',
#   'Akuei to Gacchinpo: Tenkomori',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   'Liv & Bell',
#   'Teach',
#   'Nintama Rantarou no Uchuu Daibouken with Cosmic Front☆Next',
#   'Ajjishin da Tsunami wa? Jibun no Inochi wa Jibun de Mamoru',
#   'Nintama Rantarou no Shouboutai',
#   'Chibi Maruko-chan: Hi no Youjin'],
#  6073: ['Momonga-mon',
#   'Amigo Tomodachi',
#   'Liv & Bell',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   '21-seiki wa Minna ga Shuyaku',
#   'Akuei to Gacchinpo: Tenkomori',
#   'Ama Gli Animali',
#   'Teach',
#   'Robot Pulta',
#   'Akuei to Gacchinpo The Movie: Chelsea no Gyakushuu/Akuei to Mahou no Hammer'],
#  6074: ['Patchin shite! Obaachan',
#   'Ama Gli Animali',
#   'Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   'Liv & Bell',
#   '21-seiki wa Minna ga Shuyaku',
#   'Teach',
#   'Akuei to Gacchinpo: Tenkomori',
#   '21 Emon Uchuu e Irasshai!',
#   'Chibi Maruko-chan: Hi no Youjin',
#   'Ajjishin da Tsunami wa? Jibun no Inochi wa Jibun de Mamoru'],
#  51524: ['Affordance',
#   '0 Man',
#   '(a long day of) Mr. Calpaccio',
#   '4.Eyes Re-Mix 2005',
#   'Airs',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!'],
#  2863: ['Akiko',
#   'Ail Maniax: Inma Seifukugari & Majogari no Yoru ni',
#   '2x1',
#   '69 Pink Riders',
#   'Auction: Bijo Dorei',
#   'Ayatsuri Ningyou',
#   'Age Man to Fuku Chin',
#   'Advancer Tina',
#   '69 Pink Riders 2',
#   'Bad End'],
#  10139: ['Akuei to Gacchinpo The Movie: Chelsea no Gyakushuu/Akuei to Mahou no Hammer',
#   'Robot Pulta',
#   'AAA de Ikou!!: Yuuna & Akiko',
#   'Amigo Tomodachi',
#   'Momonga-mon',
#   'Aladdin to Mahou no Lamp no Koutsuu Anzen',
#   'Ai no Kiseki: Doctor Norman Monogatari',
#   'Liv & Bell',
#   'Teach',
#   'Akuei to Gacchinpo: Tenkomori'],
#  35242: ['Akita Kenritsu Iburi Gakkou Chuutou-bu',
#   'Liv & Bell',
#   'Akuei to Gacchinpo: Tenkomori',
#   'Ama Gli Animali',
#   'Chibi Maruko-chan: Hi no Youjin',
#   'Nintama Rantarou no Shouboutai',
#   'Ajjishin da Tsunami wa? Jibun no Inochi wa Jibun de Mamoru',
#   'Nintama Rantarou no Uchuu Daibouken with Cosmic Front☆Next',
#   'Momonga-mon',
#   'Amigo Tomodachi'],
#  40148: ['BanG Dream! 3rd Season',
#   'BanG Dream! 2nd Season',
#   'Anima Yell!',
#   'Assault Lily: Bouquet',
#   'BanG Dream!',
#   'Adachi to Shimamura',
#   'Action Heroine Cheer Fruits',
#   'Akanesasu Shoujo',
#   'D4DJ All Mix',
#   'D4DJ First Mix'],
#  40924: ['Garugaku.: Sei Girls Square Gakuin',
#   'Adachi to Shimamura Mini Anime',
#   'Blue Reflection Ray!',
#   'AAside',
#   'Banzai Rizing!',
#   'Puzzle & Dragon',
#   'Daylight (2020)',
#   'Ninja Box 3rd Season',
#   'Akachan Honbuchou 3rd Season',
#   'Teikou Penguin'],
#  47426: ['Aimai na Mama',
#   'Ai W-kun',
#   '3341',
#   'A Walk With the Colors',
#   'Ai to Yuuto: Hajimete no Otsukai',
#   'Ai no Sato',
#   '100-nichikan Ikita Wani X Bourbon',
#   '5-tsu no Yubi no Niwa',
#   '38-39°C',
#   '23rd Japan Media Arts Festival Introduction'],
#  42845: ['Aimai na Mama',
#   '11-gatsu Umare no Otokonoko no Tame ni.',
#   'A Walk With the Colors',
#   'Akai Hoshi Aoi Hoshi: Tenmon Carat no Hoshi kara',
#   'Akui Sensou',
#   'Akkenaku, Sekai wa',
#   '12 Zhi Wenzi He 5 Geren',
#   '38-39°C',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   'Air Folktale'],
#  15527: ["90's Love (SQUAR Remix)",
#   'Mogu Mogu',
#   'Wamono',
#   '9-gatsu',
#   'Kimi wa Sou Kimeta',
#   'After Man',
#   '12 Zhi Wenzi He 5 Geren',
#   'Algernon',
#   '12-wol',
#   '38-39°C'],
#  36840: ['Amai Choubatsu: Watashi wa Kanshu Senyou Pet',
#   'Shuudengo, Capsule Hotel de, Joushi ni Binetsu Tsutawaru Yoru.',
#   'Omiai Aite wa Oshiego, Tsuyoki na, Mondaiji.',
#   'Yubisaki kara Honki no Netsujou: Osananajimi wa Shouboushi',
#   'Araiya-san!: Ore to Aitsu ga Onnayu de!?',
#   'Ore no Yubi de Midarero.: Heitengo Futarikiri no Salon de...',
#   'XL Joushi.',
#   'Eternity: Shinya no Nurekoi Channel ♡',
#   'Ookami-san wa Taberaretai',
#   'Otona nya Koi no Shikata ga Wakaranee!'],
#  49005: ['6 Songs',
#   'Akai Yama Aoi Yama Shiroi Yama',
#   '32',
#   'A Woman in a Fashion Building',
#   'Ai no Tabidachi',
#   '2005',
#   'Aishiteru (2010)',
#   'Ab-rah',
#   'Ake-Vono',
#   "A Doodlin' Song"],
#  2864: ['69 Pink Riders 2',
#   '69 Pink Riders',
#   'Ayatsuri Ningyou',
#   'Aoi Kokuhaku',
#   'Age Man to Fuku Chin',
#   'Auction: Bijo Dorei',
#   'Binetsu Hime: Zange no Shou',
#   'Isourou Tengoku',
#   'Nonomura Byouin no Hitobito',
#   'G.T.R G-cup Teacher Rei'],
#  12589: ['Akuei to Gacchinpo The Movie: Chelsea no Gyakushuu/Akuei to Mahou no Hammer',
#   'Robot Pulta',
#   'AAA de Ikou!!: Yuuna & Akiko',
#   'Amigo Tomodachi',
#   'Momonga-mon',
#   'Ai no Kiseki: Doctor Norman Monogatari',
#   'Aladdin to Mahou no Lamp no Koutsuu Anzen',
#   'Ama Gli Animali',
#   'Akuei to Gacchinpo: Tenkomori',
#   '21-seiki wa Minna ga Shuyaku'],
#  2467: ['3 Choume no Tama: Onegai! Momo-chan wo Sagashite!!',
#   'Anime Yasei no Sakebi',
#   'Robotan (1986)',
#   'Ultraman Kids no Kotowaza Monogatari',
#   'Umi Da! Funade Da! Nikoniko, Pun',
#   'Salad Juu Yuushi Tomatoman',
#   'Ultraman Kids: M7.8 Sei no Yukai na Nakama',
#   'Saezuru Doubutsu wa Yarushikanai! Specials',
#   'Shirahata no Shoujo Ryuuko',
#   'Tondemo Nezumi Daikatsuyaku'],
#  24783: ['6 Songs',
#   'Ai no Tabidachi',
#   'Ake-Vono',
#   'Akai Hoshi Aoi Hoshi: Tenmon Carat no Hoshi kara',
#   '21 Seiki',
#   '12-wol',
#   '32',
#   'Aishiteru',
#   '2005',
#   'Ab-rah'],
#  24181: ['A Play',
#   '7-kakan.',
#   '2',
#   'Ai Uta: Since 2007',
#   '9',
#   '3-D Heaven',
#   'Alluptoyou',
#   '27th',
#   'Ashita e Mukau Hito',
#   'A Christmas Song'],
#  33975: ['Aiseki Mogol Girl',
#   'Teikou Penguin',
#   'Akachan Honbuchou 2nd Season',
#   'Akachan Honbuchou 3rd Season',
#   'Ninja Box 3rd Season',
#   'Ai Datta n da yo',
#   'Acerola-chan',
#   '3-bu de Wakaru Koizumi Yakumo no Kaidan',
#   'Chinzei Hachirou Tametomo',
#   'Agukaru: Play with Ibaraki-hen'],
#  37666: ['Kuroi Neko',
#   'KiyaKiya',
#   'The Crater',
#   'Shiroi Niji',
#   'Nagisa no Peppy',
#   'Drawing!!',
#   'Superfluid',
#   'Kaakaa Karasu no Kanzaburou',
#   'Manga Ijin Monogatari',
#   'Manga Kodomo Bunko'],
#  50208: ['Ai W-kun',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Congming de Yixiu Zhi Fan Dou Gongzhu',
#   'Daisougen to Hakuba',
#   'Hazedon',
#   'Goesu Daejeonjaeng'],
#  31646: ['Barakamon',
#   'Boku dake ga Inai Machi',
#   'Amaama to Inazuma',
#   'Boku no Hero Academia 2nd Season',
#   'Boku no Hero Academia',
#   'Ballroom e Youkoso',
#   '91 Days',
#   'Boku no Hero Academia 3rd Season',
#   'Chihayafuru 2',
#   'Death Parade'],
#  35180: ['Chihayafuru 3',
#   'Ballroom e Youkoso',
#   'Barakamon',
#   'Amaama to Inazuma',
#   'Boku dake ga Inai Machi',
#   'Boku no Hero Academia 2nd Season',
#   'Boku no Hero Academia 3rd Season',
#   'Chihayafuru 2',
#   'Boku no Hero Academia',
#   '91 Days'],
#  34647: ['3-gatsu no Lion meets Bump of Chicken',
#   'Answer (2016)',
#   '91 Days: Mijikai Rousoku',
#   '3-gatsu no Lion: Ugoku! Nya Shogi',
#   'Arslan Senki (TV): Tsuioku no Shou - Dakkan no Yaiba',
#   'Chihayafuru 3: Ima Hitotabi no',
#   'Boku dake ga Inai Machi Recaps',
#   '86 Special Edition: Senya ni Akaku Hinageshi no Saku',
#   'Air Recap',
#   '86 Part 2 Recaps'],
#  28789: ['Answer (2016)',
#   '3-gatsu no Lion Recap',
#   'Beautiful World',
#   '3-Nen C-Gumi 14-Ban Kubozono Chiyoko no Nyuukaku',
#   'Aftermath',
#   '3-gatsu no Lion: Ugoku! Nya Shogi',
#   '7-kakan.',
#   '1989',
#   '20-dai no Heya-hen',
#   '6♥Princess'],
#  38154: ['Agukaru: Play with Ibaraki-hen Episode 0',
#   'Acca-kun no ACCA Kouza',
#   'Kanashiki Debu Neko-chan',
#   'Tales of HR',
#   'Kinyoru, Abe Reiji: Heikinteki na Salaryman no Ijou na Nichijou',
#   '2.43 Mini Anime: Fukui-ben Kouza',
#   'Chan Chiho Challenge Channel',
#   'Wonder-kun no Hatsu Yume Uchuu Ryokou',
#   'Risu no Matoi',
#   'Jashin-chan Mame Anime'],
#  35070: ['Kamiusagi Rope (ONA)',
#   'Kamiusagi Rope x TOHO Cinemas (Movies)',
#   'au x Rope',
#   'Kana Kana Kazoku',
#   'Felix x Kamiusagi Rope',
#   'Kamiusagi Rope: Warau Asa ni wa Fukuraitaru tte Maji ssuka!?',
#   'Kamiusagi Rope x TOHO Cinemas',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad'],
#  54761: ['Ai to Yuuto: Hajimete no Otsukai',
#   'Tonari no Kaibutsu-kun Special',
#   'After-School Emotion',
#   'Akkenaku, Sekai wa',
#   '38-39°C',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   'Kami nomi zo Shiru Sekai PV',
#   'Sajou no Yumekui Shoujo',
#   'Ai no Sato',
#   '12 Zhi Wenzi He 5 Geren'],
#  8774: ['Stone',
#   'Shin Saru Kani Gassen',
#   'Nintama Rantarou no Uchuu Daibouken with Cosmic Front☆Next',
#   'Nintama Rantarou no Shouboutai',
#   'Chibi Maruko-chan: Hi no Youjin',
#   'Ajjishin da Tsunami wa? Jibun no Inochi wa Jibun de Mamoru',
#   'Ama Gli Animali',
#   'Liv & Bell',
#   'Akuei to Gacchinpo: Tenkomori',
#   'Teach'],
#  7809: ['Samero',
#   'Yoru no Okite',
#   '4.Eyes',
#   'Kiekaketa Monogatari-tachi no Tame ni',
#   'Akuma no Kairozu',
#   'Chirico',
#   'Yami wo Mitsumeru Hane',
#   'Norakuro Gochou',
#   'Osaru no Sankichi: Boukuusen',
#   'Natsu no Shisen 1942'],
#  30829: ['Love Live! School Idol Project Recap',
#   "Love Live! School Idol Project: μ's →NEXT LoveLive! 2014 - Endless Parade Encore Animation",
#   'Love Live! Kouhaku Special Anime',
#   'Hirano to Kagiura',
#   'Osomatsu-san: Hipipo-Zoku to Kagayaku Kajitsu',
#   'Love Live! The School Idol Movie: Gekijou Manner CM',
#   'Tama & Friends: Uchi no Tama Shirimasen ka?',
#   'PLUG, THe NeW WORLD',
#   'Azur Lane Valentine Special Mission',
#   'Tanuki to Kitsune: Dai 5-kan Hatsubai Kinen Animation'],
#  41188: ['Azur Lane Valentine Special Mission',
#   'Apron Hero',
#   'Shiny Racers',
#   'Heroine Tarumono! Kiraware Heroine to Naisho no Oshigoto Mini Anime',
#   'Wish You Luck',
#   'BIGOTRE Capture Mission',
#   'Pororo Daemoheom',
#   'Chan Chiho Challenge Channel',
#   'Kidou Senshi Gundam: Tekketsu no Orphans - Urdr Hunt',
#   'Pokemon Kids TV Douyou'],
#  52010: ['Apron Hero',
#   'BIGOTRE Capture Mission',
#   'Kidou Senshi Gundam: Tekketsu no Orphans - Urdr Hunt',
#   'Sylvanian Families: Freya no Happy Diary',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Congming de Yixiu Zhi Fan Dou Gongzhu'],
#  9624: ['Astarotte no Omocha!',
#   'HenSemi (TV)',
#   'A-Channel',
#   'B-gata H-kei',
#   'Denpa Onna to Seishun Otoko',
#   'Boku wa Tomodachi ga Sukunai',
#   'Amagami SS',
#   'Acchi Kocchi',
#   'Arakawa Under the Bridge x Bridge',
#   'Arakawa Under the Bridge'],
#  12131: ['Auto Mommy',
#   'Yamaguchi Sanchi no Tsutomu-kun',
#   'Sajou no Yumekui Shoujo',
#   'Swan',
#   '3-nen D-gumi Glass no Kamen: Tobidase! Watashitachi no Victory Road',
#   'Watashi no Kamifuusen (1983)',
#   'Tsuru no Ongaeshi',
#   'Poron Guitar',
#   'Kidou Senshi Gundam 00 CB Chara',
#   'Kozaru no Buranko'],
#  33993: ['A-Size Classmate',
#   'Ecchi na Shintai Sokutei Anime Edition',
#   'Chicchana Onaka',
#   'Ichinen Buri no The Animation',
#   'Teakamamire no Tenshi The Animation',
#   'Momoiro Bouenkyou Anime Edition',
#   'Seikatsu Shidou!! Anime Edition',
#   'Seiso de Majime na Kanojo ga, Saikyou Yaricir ni Kanyuu Saretara...? The Animation',
#   'Bokura no Sex',
#   'Swamp Stamp Anime Edition'],
#  7113: ['All That Gundam',
#   'Gundam: Mission to the Rise',
#   'Ring of Gundam',
#   'Gundam Evolve',
#   'Chou Deneiban SD Gundam Sangokuden Brave Battle Warriors',
#   'Mokei Senshi Gunpla Builders Beginning G',
#   'Kidou Senshi Gundam SEED MSV Astray',
#   'Kidou Senshi Gundam F91',
#   'Kidou Senshi Gundam MS IGLOO: 1-nen Sensou Hiroku',
#   'Kidou Senshi Gundam MS IGLOO 2: Juuryoku Sensen'],
#  53789: ['2005',
#   "A Doodlin' Song",
#   'Acnes no Uta',
#   'ABC-Mart Grand Stage CMs',
#   '1985',
#   'Alone',
#   'A Viva Non Non',
#   'Algernon',
#   'About You',
#   'Aishang Zhi Di'],
#  53771: ['Ai W-kun',
#   'Akai Fuusen',
#   '100-nichikan Ikita Wani X Bourbon',
#   'Akubi Neko',
#   '12 Zhi Wenzi He 5 Geren',
#   'Aa Okashii ne',
#   '38-39°C',
#   'Akuyaku Mahou Shoujo Midoro',
#   'Ai ga Oshigoto',
#   'Ai wo Kite'],
#  41744: ['6 Songs',
#   'Ake-Vono',
#   'Adobe Student and Teacher Edition',
#   'Ai no Tabidachi',
#   'Afraid To Be Cool / Raise Me Up',
#   '27th',
#   'Ai ga Tarinai yo',
#   'A Woman in a Fashion Building',
#   '3-D Heaven',
#   'Akai Yama Aoi Yama Shiroi Yama'],
#  52767: ['Akkenaku, Sekai wa',
#   '12 Zhi Wenzi He 5 Geren',
#   '3341',
#   'Ai to Yuuto: Hajimete no Otsukai',
#   'Aishiteru',
#   'Ai W-kun',
#   'Akashi',
#   "90's Love (SQUAR Remix)",
#   'Aimai na Mama',
#   '100-nichikan Ikita Wani X Bourbon'],
#  55375: ['1985',
#   'Accept',
#   'Albino',
#   '9-gatsu',
#   'After Man',
#   'Aishang Zhi Di',
#   'Akogare',
#   '2005',
#   '100 Manten☆Pax Salomena',
#   'Amai Koibito'],
#  36793: ['5-toubun no Hanayome',
#   'Bokutachi wa Benkyou ga Dekinai',
#   'Boku no Kanojo ga Majimesugiru Sho-bitch na Ken',
#   'Bokutachi wa Benkyou ga Dekinai!',
#   'Domestic na Kanojo',
#   'Akkun to Kanojo',
#   'Arifureta Shokugyou de Sekai Saikyou',
#   '5-toubun no Hanayome ∬',
#   'Araburu Kisetsu no Otome-domo yo.',
#   'Bokutachi no Remake'],
#  37956: ['Bokutachi wa Benkyou ga Dekinai!',
#   '5-toubun no Hanayome',
#   'Bokutachi wa Benkyou ga Dekinai',
#   'Domestic na Kanojo',
#   '5-toubun no Hanayome ∬',
#   'Araburu Kisetsu no Otome-domo yo.',
#   'Bokutachi no Remake',
#   'Assassins Pride',
#   'Boku no Kanojo ga Majimesugiru Sho-bitch na Ken',
#   'Arifureta Shokugyou de Sekai Saikyou'],
#  33696: ['Konnichiwa Onara Gorou',
#   'Time for Christmas',
#   'Teienu Theater in Kobe Opening',
#   'Halloween Pajama',
#   'Cake Sushi',
#   'Pankis! 2-jigen',
#   'Zone: Intro',
#   'Chein Kuro-Nikuru!!',
#   'Peeping Life: Gekijou Original-ban',
#   '21 Seiki'],
#  53425: ['Fushigi no Kuni no Succubus',
#   'Rakuen Shinshoku: Island of the Dead',
#   'Renseijutsushi Colette no H na Sakusei Monogatari',
#   'Maid Kyouiku: Botsuraku Kizoku Rurikawa Tsubaki The Animation',
#   'Goblin no Suana',
#   'Aoharu Snatch',
#   'Nightmare x Deathscythe: Hangyaku no Resonance',
#   'Majo wa Kekkyoku Sono Kyaku to... The Animation',
#   'Fuufu Koukan: Modorenai Yoru',
#   'Imouto wa Gal Kawaii'],
#  29809: ['Allargando The Animation',
#   'Aniki no Yome-san nara, Ore ni Hamerarete Hiihii Itteru Tokoro da yo',
#   'Ana no Oku no Ii Tokoro',
#   'Ane Yome Quartet',
#   'Boy Meets Harem The Animation',
#   'Aku no Onna Kanbu: Full Moon Night',
#   'Ano Ko to Ii Koto',
#   'Colosseum no Senki: Another Story',
#   'Amanee!: Tomodachinchi de Konna Koto ni Naru Nante!',
#   'Amakano'],
#  300: ['Bastard!! Ankoku no Hakaishin',
#   'Armitage III',
#   'Blue Seed',
#   'Bubblegum Crisis',
#   'Aa! Megami-sama!',
#   'Gunnm',
#   'Armitage III: Dual-Matrix',
#   'Bannou Bunka Neko-Musume',
#   'Black Magic M-66',
#   'Appleseed'],
#  1225: ['Bastard!! Ankoku no Hakaishin',
#   'Armitage III',
#   'Armitage III: Dual-Matrix',
#   'Black Magic M-66',
#   'AD Police',
#   'Blue Seed',
#   'Bannou Bunka Neko-Musume',
#   'Aa! Megami-sama!',
#   'Gunnm',
#   'Appleseed'],
#  3685: ['Extra',
#   'Connected',
#   'Survival',
#   'Dimension Loop',
#   'Atarashii Sekai',
#   'Love to Live By',
#   'Aoi Chou',
#   'Fluximation',
#   'Yume no Kakera',
#   'Dr.'],
#  51464: ['Alice Gear Aegis Expansion',
#   'Akebi-chan no Sailor-fuku',
#   'Ars no Kyojuu',
#   'Do It Yourself!!',
#   'Akiba Meido Sensou',
#   'Alice Gear Aegis: Doki! Actress Darake no Mermaid Grand Prix♥',
#   'Teppen!!!!!!!!!!!!!!!',
#   'Aharen-san wa Hakarenai',
#   'Kawaisugi Crisis',
#   'Edomae Elf'],
#  36624: ['Akuyaku Mahou Shoujo Midoro',
#   '100-nichikan Ikita Wani X Bourbon',
#   'Himitsukessha Taka no Tsume x Glass no Kamen desu ga',
#   'After Hours',
#   '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM',
#   'Anata no wo Uchi ga Eigakan',
#   'A Walk With the Colors',
#   '12 Zhi Wenzi He 5 Geren',
#   '38-39°C',
#   '3341'],
#  30665: ['Chirico',
#   'Kaze no Kokyuu: Animation ni Yoru Oufuku Shokan',
#   'Majin Sentai Death Ranger: Ubawareta Pudding!',
#   'Shashinki',
#   "Shashinki '87",
#   'Why Re-Mix 2002',
#   'Memories: Younenki no Joukei',
#   'Youshi Kei: Mou Hitotsu no Nijiiro Toshi',
#   'Utsukushii Hoshi',
#   'Hyaku-nengo no Aru Hi'],
#  38869: ['Affordance',
#   '0 Man',
#   '21-seiki',
#   '(a long day of) Mr. Calpaccio',
#   'Aotenjou no Clown',
# ...
#   'At Atelier',
#   'Bao Mu',
#   'Banana Bread Pudding',
#   'Ashita wa Nichiyoubi',
#   'Backkom Mission Impossible',
#   'Backkom Specials',
#   'Au Tabi ni, Atarashii',
#   'Beat in Love'],
#  5673: ['Sense Honma ni Honma',
#   'Kao ni Denai Kashiwada-san to Kao ni Deru Oota-kun CM',
#   'Tokyo Kouya',
#   'Study',
#   'Psycho',
#   'Summer Time',
#   'Plantopia',
#   'Mondainai Tripper!',
#   'Tanabata no Oto',
#   'In Full Bloom'],
#  4099: ['Mushiba Tetsudou',
#   'Norakuro Gochou',
#   "Deniroo's Circus",
#   'Nanja Monja Obake',
#   'Fushigi Sekai Atagoul Monogatari',
#   'Kirin the Noop',
#   'Pâtisserie no Monster',
#   'Star Wars/Force no Kakusei',
#   'Miira no Yume',
#   "Norabbits' Minutes"],
#  35171: ['Anime Roukyoku Kikou Shimizu no Jirochouden',
#   'Ao Fei Q Chong',
#   'Aotenjou no Clown',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Congming de Yixiu Zhi Fan Dou Gongzhu',
#   'Daisougen to Hakuba',
#   'Goesu Daejeonjaeng',
#   'Hazedon'],
#  40532: ['Deca-Dence',
#   'Akudama Drive',
#   'Arte',
#   'BNA',
#   'Babylon',
#   'Angolmois: Genkou Kassenki',
#   'Cop Craft',
#   'Akiba Meido Sensou',
#   'Araburu Kisetsu no Otome-domo yo.',
#   'Burn the Witch'],
#  51799: ['Boku Kakkoii deshou',
#   "Ca' Foscari Cinema",
#   'Boku no Nikkichou',
#   'Bonus Track: Atarashii Yoru no Hanami',
#   'Asa wo Kitan',
#   "Cat's Eye Love",
#   'Chanto Kao ni Kaite Aru',
#   'Crater no Naru Ki',
#   'Between Showers',
#   'Bingtai Jianzhu Zhengouqun'],
#  937: ['Appleseed Saga Ex Machina',
#   'Armitage III',
#   'Bubblegum Crisis',
#   'Dominion',
#   'Black Magic M-66',
#   'Armitage III: Dual-Matrix',
#   'AD Police',
#   'Gunnm',
#   'Blood: The Last Vampire',
#   'Bubblegum Crash'],
#  54: ['Appleseed Saga Ex Machina',
#   'Innocence',
#   'Akira',
#   'Koukaku Kidoutai',
#   'Blood: The Last Vampire',
#   'Final Fantasy: The Spirits Within',
#   'Final Fantasy VII: Advent Children',
#   'Cowboy Bebop: Tengoku no Tobira',
#   'Koukaku Kidoutai: Stand Alone Complex',
#   'Cowboy Bebop'],
#  22677: ['Appleseed XIII',
#   'Appleseed XIII Remix Movie 2: Yogen',
#   'Appleseed XIII Remix Movie 1: Yuigon',
#   'Appleseed Saga Ex Machina',
#   'Captain Herlock',
#   'Biohazard: Vendetta',
#   'Appleseed (Movie)',
#   'Biohazard: Damnation',
#   'Bayonetta: Bloody Fate',
#   'Blame! Movie'],
#  2969: ['Appleseed (Movie)',
#   'Appleseed',
#   'Vexille: 2077 Nihon Sakoku',
#   'Innocence',
#   'Final Fantasy: The Spirits Within',
#   'Blood: The Last Vampire',
#   'Koukaku Kidoutai',
#   'Akira',
#   'Black Lagoon',
#   'Black Lagoon: The Second Barrage'],
#  9737: ['Appleseed XIII Remix Movie 2: Yogen',
#   'Appleseed XIII Remix Movie 1: Yuigon',
#   'Appleseed Alpha',
#   'Appleseed Saga Ex Machina',
#   'AWOL',
#   'Gunparade Orchestra OVA',
#   'Time Bokan Series: Zenderman',
#   'Gegege no Kitarou: Youkai Daisensou',
#   'Gegege no Kitarou: Obake Nighter',
#   'Gegege no Kitarou: Gekitotsu!! Ijigen Youkai no Daihanran'],
#  10689: ['Tiger Mask (Movie)',
#   'Tiger Mask Fuku Men League Sen',
#   'Gun-dou Musashi Recap',
#   'Decadence: Remix',
#   'BUCK-TICK x HAL',
#   'Mulan: Heng Kong Chu Shi',
#   'Anpanman to Hajimeyou! Iro, Kazu, Katachi Wakaru ka na Iro, Katachi',
#   'Xinghe Zhizun 2nd Season',
#   'Kamiusagi Rope x TOHO Cinemas',
#   'Jiu Tian Xuan Di Jue 3rd Season'],
#  10693: ['Tiger Mask Fuku Men League Sen',
#   'Tiger Mask (Movie)',
#   'Decadence: Remix',
#   'BUCK-TICK x HAL',
#   'Mulan: Heng Kong Chu Shi',
#   'Gun-dou Musashi Recap',
#   'Anpanman to Hajimeyou! Iro, Kazu, Katachi Wakaru ka na Iro, Katachi',
#   'Xinghe Zhizun 2nd Season',
#   'Jiu Tian Xuan Di Jue 3rd Season',
#   'Tongari Boushi no Memole: Marielle no Housekibako'],
#  36292: ['BIGOTRE Capture Mission',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Daisougen to Hakuba',
#   'Congming de Yixiu Zhi Fan Dou Gongzhu',
#   'Hazedon',
#   'Goesu Daejeonjaeng'],
#  1268: ['Aquarian Age: Sign for Evolution',
#   'Apache Yakyuugun',
#   'Oh! Super Milk-chan Special',
#   'Mulan: Heng Kong Chu Shi',
#   'GO-GO Tamagotchi!',
#   'Super Titans 15',
#   'Neko Neko Nihonshi 2nd Season',
#   'Bai Yue Er',
#   'Rescue YoYo',
#   'Haipa Bei Peng Chu de Nuhai'],
#  1224: ["Aquarian Age: Saga II - Don't Forget Me...",
#   'Arc the Lad',
#   'Argento Soma',
#   'Avenger',
#   "E's Otherwise",
#   'Blue Seed 2',
#   'Blue Seed',
#   'Bakuretsu Hunters',
#   'Asagiri no Miko',
#   'Choujuushin Gravion'],
#  10447: ['Brave 10',
#   'Campione! Matsurowanu Kamigami to Kamigoroshi no Maou',
#   'Accel World',
#   'Buddy Complex',
#   'Ano Natsu de Matteru',
#   'Guilty Crown',
#   'Ben-To',
#   'Aldnoah.Zero',
#   'Arcana Famiglia',
#   'C: The Money of Soul and Possibility Control'],
#  30382: ['Sousei no Aquarion Evol',
#   'Active Raid: Kidou Kyoushuushitsu Dai Hachi Gakari 2nd',
#   'Aquarion Evol',
#   'Active Raid: Kidou Kyoushuushitsu Dai Hachi Gakari',
#   'Ange Vierge',
#   'Chaos Dragon: Sekiryuu Seneki',
#   'Aquarion Movie: Ippatsu Gyakuten-hen',
#   'Captain Earth',
#   'Bubuki Buranki: Hoshi no Kyojin',
#   'Garo: Guren no Tsuki'],
#  6032: ['Sousei no Aquarion OVA',
#   'Soosee no Aquarion: Dai 27-wa Parallel-ban',
#   'Gunparade Orchestra OVA',
#   'Ttori wa Zeta Robot',
#   'Baku Tech! Bakugan Gachi',
#   'Ganbare Goemon: Chikyuu Kyuushutsu Daisakusen',
#   'Tiger Mask (Movie)',
#   'Tiger Mask Fuku Men League Sen',
#   'Prison Lab',
#   'Captain Tsubasa no Koutsuu Anzen'],
#  1202: ['Baldr Force Exe Resolution',
#   '.hack//G.U. Trilogy',
#   'Akane Maniax',
#   '.hack//G.U. Returner',
#   'Air in Summer',
#   'Eien no Aselia',
#   'Brave Story',
#   'Air Movie',
#   '.hack//Roots',
#   'Hoshizora Kiseki'],
#  34779: ['Aozora',
#   'Anata no wo Uchi ga Eigakan',
#   'Daitan Futeki ni Koi Shitai',
#   "An Atheist's Christmas",
#   '100 Manten☆Pax Salomena',
#   'Chen-Kuro Gakuen',
#   'Alita De Shi Lian',
#   'Anon Sentai Ranger 5',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong'],
#  7786: ['Shounen Jack to Mahoutsukai',
#   'Goichi Jiisan',
#   'Chikyuu Monogatari Telepath 2500',
#   'Chanda Gou',
#   'Hana to Chou',
#   'Ga Kan',
#   'Kagi Hime Monogatari: Eikyuu Alice Rondo - Extra Song',
#   'Go-hiki no Kozaru-tachi',
#   'Kitsune to Circus',
#   'Punpun Polka'],
#  2825: ['Jungle Book Shounen Mowgli',
#   'Tekken Chinmi',
#   'Takarajima',
#   'Honoo no Toukyuuji: Dodge Danpei',
#   'Chirorin Mura Monogatari',
#   'Tsurikichi Sanpei',
#   'Akachan to Boku',
#   'Nanatsu no Umi no Tico',
#   '3 Choume no Tama: Uchi no Tama Shirimasen ka?',
#   'Trapp Ikka Monogatari'],
#  38753: ['Asobi Asobase',
#   '5-toubun no Hanayome',
#   'Bokutachi wa Benkyou ga Dekinai',
#   'Bokutachi wa Benkyou ga Dekinai!',
#   'Akebi-chan no Sailor-fuku',
#   'Dumbbell Nan Kilo Moteru?',
#   'Chio-chan no Tsuugakuro',
#   '3-gatsu no Lion 2nd Season',
#   'Carole & Tuesday',
#   'Bocchi the Rock!'],
#  4657: ['Basquash!',
#   "Asura Cryin'",
#   'Chrome Shelled Regios',
#   "Asura Cryin' 2",
#   'Ayakashi',
#   'Druaga no Tou: The Sword of Uruk',
#   'Akikan!',
#   'Guin Saga',
#   'Asu no Yoichi!',
#   'Druaga no Tou: The Aegis of Uruk'],
#  38416: ['Azur Lane Valentine Special Mission',
#   'Mu Wang Zhi Wang: You Du Zhan',
#   'Fengzi Wuyu: Xian Luo Pian',
#   'Si Hai Jing Qi 2nd Season',
#   'Mu Wang Zhi Wang: Xuan Guan Si',
#   'Mu Wang Zhi Wang: Han Tie Dou',
#   'Zhen Dao Ge: Chenshi Hang',
#   'Moshi Juexing: Ruqin 2nd Season',
#   'Moshi Juexing: Suyuan',
#   'Si Hai Jing Qi'],
#  38413: ['Arad: Gyakuten no Wa',
#   'Azur Lane Valentine Special Mission',
#   'Guan Hai Ce',
#   'Moshi Juexing: Ruqin',
#   'Moshi Juexing: Ruqin 2nd Season',
#   'Chi Yan Jinyiwei',
#   'Zhen Dao Ge: Tebie Pian',
#   'Si Hai Jing Qi',
#   'Moshi Juexing: Suyuan',
#   'Wu Ying Sanqian Dao'],
#  34974: ['Umiyuri Kaiteitan',
#   'PekoMiko Daisensou!!',
#   'Kanchigaisei Han Kiboushou feat. Hatsune Miku',
#   'Gin no Yuri',
#   'Paper Moon',
#   'Hitojichi Koukan feat. Hatsune Miku',
#   'Peko Random Brain!',
#   'Neo-Neon',
#   'Yumekui Shirokuro Baku',
#   'Melty Land Nightmare'],
#  2576: ['Yama Nezumi Rocky Chuck',
#   'Manga Hajimete Omoshiro Juku',
#   'Ahiru no Pekkle no Ahiru no Drakestail',
#   'Tsukiusa. Gekijou',
#   'Tondemo Nezumi Daikatsuyaku',
#   'Ie Naki Ko Remy Specials (2001)',
#   'Ikinari Dagon',
#   'Mahoutsukai Haley no Speed Story',
#   'Takarajima Movie',
#   'Agigongryong Doolie (2009)'],
#  25089: ['Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Congming de Yixiu Zhi Fan Dou Gongzhu',
#   'Daisougen to Hakuba',
#   'Goesu Daejeonjaeng',
#   'Hazedon',
#   'Cofun Gal no Coffy'],
#  39337: ['Boku to Nurse no Kenshuu Nisshi The Animation',
#   '25-sai no Joshikousei',
#   '#Ima made de Ichiban Yokatta Sex The Animation',
#   'Aikagi The Animation',
#   'Amai Choubatsu: Watashi wa Kanshu Senyou Pet',
#   'Ane Chijo♥Max Heart',
#   'Bitch na Inane-sama',
#   'Anette-san to Liliana-san The Animation',
#   'Imouto wa Gal Kawaii',
#   'Boku ni Sexfriend ga Dekita Riyuu'],
#  7647: ['Bakemonogatari',
#   'Durarara!!',
#   'Angel Beats!',
#   'Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.',
#   'Baka to Test to Shoukanjuu',
#   'Danshi Koukousei no Nichijou',
#   'Bakuman.',
#   'Denpa Onna to Seishun Otoko',
#   'Baccano!',
#   'Boku wa Tomodachi ga Sukunai'],
#  9074: ['Bakemonogatari',
#   'Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.',
#   'Danshi Koukousei no Nichijou',
#   'Denpa Onna to Seishun Otoko',
#   'Bakuman.',
#   'Baka to Test to Shoukanjuu',
#   'Durarara!!',
#   'Angel Beats!',
#   'Baka to Test to Shoukanjuu Ni!',
#   'Boku wa Tomodachi ga Sukunai'],
#  33282: ['Meitantei Gordon',
#   'Mukidashi no Mitsuko',
#   'Nude Batter Tetsuo',
#   'Shigeo wa Handsome',
#   'Kabushikigaisha Aokishouji',
#   'Essential Free & Easy',
#   'Dappys',
#   'Warui no wo Taose!! Salaryman Man',
#   'Oshiri Mae Man',
#   'Represent Chikyuu Collab Anime'],
#  4074: ['Tsushima Maru: Sayounara Okinawa',
#   'Lan Mao',
#   'Dotanba no Manners',
#   'Fuwa Aoyun Manyouji',
#   'Kankara Sanshin',
#   'Solar I.II.III',
#   'Taekwon Dongja Maruchi Arachi',
#   'Johnny Cypher',
#   'Space Gundam V',
#   'Cheol-in 007'],
#  35709: ['Youkai Ninpouchou Jiraiya!',
#   'Fly',
#   'Spring has come!',
#   'At Atelier',
#   'Aru Otoko no Ikikata',
#   'NoisyCell x Ponkotsu Quest',
#   'Katasumi no Uroko',
#   'Usa Weather Show',
#   'JA Kumamoto Keizairen',
#   'Straw-saurus Neo'],
#  1961: ['Chirin no Suzu',
#   'Brave Story',
#   'Cheonnyeon-yeowoo Yeowoobi',
#   "Chi's Sweet Home",
#   'Aru Tabibito no Nikki',
#   'Damekko Doubutsu',
#   'Arete Hime',
#   'Ayakashi: Japanese Classic Horror',
#   'Ged Senki',
#   'Ginga Nagareboshi Gin'],
#  13029: ['A Tang Qi Yu',
#   'Mao Yu Tao Hua Yuan',
#   'Sylvanian Families: Mini Story 2nd Season',
#   'Dongwu Tegong Ju',
#   'Sigan Yeohaengja Luke',
#   'Wan Ou Qibing',
#   'Ju Bing Chang Cheng Zhuan',
#   'MapleStory Special',
#   'Monkey Punch: Manga Katsudou Daishashin - Crime Mate Special',
#   'Jinguizi'],
#  16518: ['Devil Survivor 2 The Animation',
#   'Dansai Bunri no Crime Edge',
#   'Code:Breaker',
#   'Arcana Famiglia',
#   'Hakkenden: Touhou Hakken Ibun',
#   'Blood Lad',
#   'Buddy Complex',
#   'Brave 10',
#   'Hakkenden: Touhou Hakken Ibun 2nd Season',
#   'Black Bullet'],
#  19447: ['Sylvanian Families: Mini Story 2nd Season',
#   'Dongwu Tegong Ju',
#   'Wan Ou Qibing',
#   'Sigan Yeohaengja Luke',
#   'Mao Yu Tao Hua Yuan',
#   'A Tang Qi Yu',
#   'Ju Bing Chang Cheng Zhuan',
#   'Jinguizi',
#   'Monkey Punch: Manga Katsudou Daishashin - Crime Mate Special',
#   'Tiger Mask (Movie)'],
#  14373: ['Arve Rezzle: Kikaijikake no Yousei-tachi',
#   'Another: The Other - Inga',
#   'Aiura',
#   'Computer Kakumei: Saikyou x Saisoku no Zunou Tanjou',
#   'Dareka no Manazashi',
#   'Ai Mai! Moe Can Change!',
#   'Aura: Maryuuin Kouga Saigo no Tatakai',
#   '"Bungaku Shoujo" Memoire',
#   '"Bungaku Shoujo" Movie',
#   'Chuunibyou demo Koi ga Shitai! Lite'],
#  15979: ['Konna Watashitachi ga Nariyuki de Heroine ni Natta Kekka www (TV)',
#   'Decadence: Remix',
#   'BUCK-TICK x HAL',
#   'Out of Sight',
#   'Shu Tian Fu Mo Lu',
#   'Ninjala Episode 0',
#   'Mulan: Heng Kong Chu Shi',
#   'Platonic Chain: Ansatsu Jikkouchuu',
#   'Crayon Shin-chan Specials',
#   'Robot Atom'],
#  8652: ['Bakunyuu Bomb',
#   'Bakunyuu Maid Kari',
#   'Auction: Bijo Dorei',
#   'Age Man to Fuku Chin',
#   'Aoi Kokuhaku',
#   'Binkan Athlete',
#   'Ayatsuri Haramase DreamNote',
#   'BaBuKa: Gokudou no Tsuma',
#   'Issho ni Ecchi',
#   'Bi-chiku Beach: Nangoku Nyuujoku Satsueikai'],
#  55: ['Wild Arms: Twilight Venom',
#   'Hakaima Sadamitsu',
#   'Blue Gender: The Warrior',
#   'Blue Gender',
#   'Gallery Fake',
#   'Argento Soma',
#   'Bakuretsu Hunters',
#   'Aquarian Age: Sign for Evolution',
#   'Avenger',
#   'D.I.C.E.'],
#  1596: ['Jinryoku Senkan!? Shiokaze Sawakaze',
#   'Ultraman M78 Gekijou: Love and Peace',
#   'Hare Tokidoki Buta',
#   'Kakyuusei (TV): Hajimemashite Tina!',
#   'SSSS.Gridman Movie',
#   'SSSS.Dynazenon Movie',
#   'Halloween Pajama',
#   "Medama Oyaji no April Fools'",
#   'Heavy Object: Dai 37 Kidou Seihi Daitai - Sakusen Kiroku',
#   'Ari to Kirigirisu'],
#  5715: ['Ultraman M78 Gekijou: Love and Peace',
#   'Hone Hone Rock',
#   'Kenka no Ato wa',
#   'Katsuobushi da yo Jinsei wa',
#   'Super Titans 15',
#   'Urashima Tarou (1952)',
#   'Rescue YoYo',
#   'FIFA',
#   'Haipa Bei Peng Chu de Nuhai',
#   'Taberu Hito-tachi'],
#  12967: ['Code:Breaker',
#   'Brave 10',
#   'Amnesia',
#   'Blood Lad',
#   'Btooom!',
#   'K',
#   'Campione! Matsurowanu Kamigami to Kamigoroshi no Maou',
#   'Ao no Exorcist',
#   'Accel World',
#   'Devil Survivor 2 The Animation'],
#  15411: ['Amnesia OVA',
#   'Brothers Conflict: Setsubou',
#   'Brothers Conflict OVA',
#   'Code:Breaker OVA',
#   'Aoharu x Kikanjuu: Kemono-tachi no Senjou da na!',
#   'Ao no Exorcist: Kyoto Fujouou-hen OVA',
#   'Ame-iro Cocoa',
#   'Bonjour♪Koiaji Pâtisserie',
#   'Ao Haru Ride OVA',
#   'Blood Lad: Wagahai wa Neko de wa Nai'],
#  29791: ['Hana no Hanashi',
#   'Roba Chotto Suneta',
#   'Osamishi Tani no Wakare Uta',
#   'Mori no Kuma-san (2009)',
#   'Paper Film',
#   'Petit Manga',
#   'Sakura Yori Ai wo Nosete',
#   'Yakusoku',
#   'Nani ga Dekiru ka na',
#   'Beautiful Name'],
#  1488: ['Crusher Joe',
#   'Crusher Joe OVA',
#   '11-nin Iru!',
#   'Dallos',
#   'Black Magic M-66',
#   'Assemble Insert',
#   'AD Police',
#   'California Crisis: Tsuigeki no Juuka',
#   'Bubblegum Crisis',
#   'Arion'],
#  284: ['Aozora Shoujo-tai',
#   'Argento Soma',
#   'A.D. Police (TV)',
#   '009-1',
#   'Chikyuu Bouei Kigyou Dai-Guard',
#   'Big Wars: Kami Utsu Akaki Kouya ni',
#   'Sentou Yousei Yukikaze',
#   'Blue Gender',
#   'AD Police',
#   'Ao no 6-gou'],
#  33232: ['Hana to Shounen',
#   'Kidou Senshi Gundam: Tekketsu no Orphans - Urdr Hunt',
#   'Ao Fei Q Chong',
#   'Aotenjou no Clown',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Daisougen to Hakuba',
#   'Congming de Yixiu Zhi Fan Dou Gongzhu',
#   'Goesu Daejeonjaeng'],
#  11697: ['Ginga e Kickoff!!',
#   'Baby Steps',
#   'Diamond no Ace',
#   'Brave 10',
#   'Baby Steps 2nd Season',
#   'Bakuman. 2nd Season',
#   'Giant Killing',
#   'Bakuman. 3rd Season',
#   'Arcana Famiglia',
#   'Kuroko no Basket'],
#  7156: ['Marine Snow no Densetsu',
#   'Saint Elmo: Hikari no Raihousha',
#   'Bakusou Circuit Roman Twin',
#   'Chogattai Majutsu Robot Ginguiser Specials',
#   'Ginga Tetsudou 999 (ONA)',
#   'Mizuki Shigeru no Toono Monogatari',
#   'Shoujo Fight: Norainu-tachi no Odekake',
#   'Manga Naruhodo Monogatari',
#   'Fusuma no Oku',
#   'Shirouto Club: Hamedori Anime Kanzen Mushuusei!!'],
#  39048: ['Animal 1',
#   'Aaron He Lili',
#   'Aotenjou no Clown',
#   'Ao Fei Q Chong',
#   'Crystal-yojeong Z-Squad',
#   'Chaplin to Coogan',
#   'Ikiteirutte Subarashii!',
#   'Congming de Yixiu Zhi Fan Dou Gongzhu',
#   'Daisougen to Hakuba',
#   'Hazedon'],
#  1028: ['Cello Hiki no Gauche (1982)',
#   'Eikyuu Kazoku',
#   'Aru Tabibito no Nikki',
#   'Atama Yama',
#   '1001 Nights',
#   'Aru Machi Kado no Monogatari',
#   'Ginga Tetsudou no Yoru',
#   'Aru Tabibito no Nikki Specials',
#   '11-nin Iru!',
#   'Arion'],
#  285: ['Gasaraki',
#   'Avenger',
#   'Arc the Lad',
#   'Aquarian Age: Sign for Evolution',
#   'Armitage III',
#   'Ao no 6-gou',
#   'A.D. Police (TV)',
#   'Blue Gender',
#   'Brain Powerd',
#   'Armitage III: Dual-Matrix'],
#  1789: ['Tokusou Kihei Dorvack',
#   'Ribbon no Kishi Pilot',
#   'Utsunomiko: Heaven Chapter',
#   'Chou Kidou Densetsu DinaGiga',
#   'Sakugasaku',
#   'Tetsuwan Atom: Kagayakeru Hoshi - Anata wa Aoku, Utsukushii...',
#   'Ginga Hyouryuu Vifam 13',
#   'Tetsuwan Atom: Ao Kishi no Kan',
#   'Tetsuwan Atom: Chikyuu Saigo no Hi',
#   'Next Senki Ehrgeiz'],
#  ...}

# %%
import pickle

# File path to save the dictionary
file_path = "anime_recommendations.pkl"

# Save the dictionary using pickle
with open(file_path, 'wb') as f:
    pickle.dump(anime_recommendations_dict, f)
